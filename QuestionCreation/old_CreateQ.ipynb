# %%
import json
import pickle
import pandas
from collections import namedtuple
from glob import glob
from datetime import datetime
from statistics import mean

# %%
import look_up_utils
import classes
import metrics

# %%
from tabulate import tabulate
from IPython.core.display import display, HTML

# %% [markdown]
# ## Load frames

# %%
frames = ['mass_shootings',
          'mass_shootings_2013',
          'mass_shootings_2014',
          'mass_shootings_2015']
look_up, parameters2incident_uris = look_up_utils.create_look_up(frames)

# %%
df = pandas.concat([pandas.read_pickle('../EventRegistries/GunViolence/frames/' + frame)
                    for frame in frames])

# %% [markdown]
# ## Set parameter values

# %%
CONFUSION_TUPLE=('location', 'participant')
#CONFUSION_TUPLE=('location', 'time')
#CONFUSION_TUPLE=('participant', 'time')
MIN_CONFUSION=3

# %%
def lookup_and_merge(look_up, 
                     parameters2incident_uris, 
                     confusion_key,
                     debug=False):
    """
    
    :param dict look_up: see look_up_utils.py
    :param dict parameters2incident_uris: see look_up_utils.py
    :param tuple confusion_key: see constant CONFUSION_TUPLE
    
    :rtype: list
    :return list of namedtuple instances (each representing a candidate)
    """
    all_questions=[]
    
    for granularity in (look_up[confusion_key]):
        for sf in look_up[confusion_key][granularity]:
            num_answer_e=len(look_up[confusion_key][granularity][sf])
            if num_answer_e >= MIN_CONFUSION:
                meanings=look_up[confusion_key][granularity][sf]

                # obtain answers uris
                answer_incident_uris = parameters2incident_uris[confusion_key][granularity][sf]

                # obtain noise uris
                total_incident_uris={0:set(), 1:set()}
                noise_incident_uris={0:set(), 1:set()}
                oa={0:set(), 1:set()}
                
                #total_incident_uris_part=set()
                for index in [0,1]:
                    confusion=confusion_key[index]
                    all_meanings=look_up[(confusion,)][(granularity[index],)][(sf[index],)]
                    oa[index]=metrics.get_observed_ambiguity(all_meanings)
                    for set_of_m in all_meanings.values():
                        total_incident_uris[index].update(set_of_m)
                    noise_incident_uris[index] = total_incident_uris[index] - answer_incident_uris

                c=classes.Candidate(
                            confusion_factors=CONFUSION_TUPLE,
                            granularity=granularity,
                            sf=sf, 
                            meanings=meanings,
                            answer=num_answer_e, 
                            answer_incident_uris=answer_incident_uris,
                            noise_incident_uris=noise_incident_uris,
                            oa_list=oa
                )
                all_questions.append(c)
    return all_questions

candidates=lookup_and_merge(look_up, parameters2incident_uris,
                            CONFUSION_TUPLE,
                            debug=False)
print({c.granularity for c in candidates})
# Out:
# {('state', 'last'), ('state', 'full_name'), ('city', 'full_name'), ('city', 'first'), ('state', 'first'), ('city', 'last')}

# %%
def incident_uris_stats(df, set_of_uris,compute_time_metrics=True):
    """
    compute stats for set of uris:
    
    :param df: gunviolence dataframe
    :param set set_of_uris: uris of gunviolence incidents
    
    :rtype: tuple
    :return (num_of_incidents,
             num_of_sources,
             avg_num_of_sources,
             urls,
             )
    """
    if type(set_of_uris) == dict:
        set_of_uris = set_of_uris[0].union(set_of_uris[1])
    num_of_incidents = len(set_of_uris)
    
    results = df.query('incident_uri in @set_of_uris')
    sources = set()

    for index, row in results.iterrows():
        sources.add(row['source_url'])
        sources.update(row['incident_sources'])

    num_sources = len(sources)
    avg = -1
    if len(set_of_uris):
        avg = num_sources / len(set_of_uris)

    date_spreads=[]    
    if compute_time_metrics:
        for incident_uri in set_of_uris:
            dates=set()
            path='../EventRegistries/GunViolence/the_violent_corpus/%s/*.json' % incident_uri
            for json_file in glob(path):
                document=json.load(open(json_file))
                try:
                    dates.add(datetime.strptime(document['dct'], '%a, %d %b %Y %H:%M:%S GMT'))
                except ValueError: # NODATE documents
                    pass
            date_spreads.append(metrics.get_dct_spread(dates))

    return (num_of_incidents, num_sources, avg, sources, mean(date_spreads) if len(date_spreads) else -1)

# %%
def compute_confusion_metrics(candidates, df):
    
    for q_id, c in enumerate(candidates, 1):
        n=incident_uris_stats(df, c.noise_incident_uris, False) # computes noise stats
        a=incident_uris_stats(df, c.answer_incident_uris, 'time' in CONFUSION_TUPLE) # computes answer stats
        
        c.a_avg_num_sources=a[2]
        c.a_sources=a[3]
        c.dct_spread=a[4]
        
        c.n_avg_num_sources=n[2]
        c.n_sources=n[3]
        
        
        c.n2s_ratio = metrics.get_ratio___noise_e2answer_e(c.noise_incident_uris[0] | c.noise_incident_uris[1], c.answer_incident_uris)
#        n2s = (len(c.noise_incident_uris[0])+len(c.noise_incident_uris[1]))/len(c.answer_incidents_uris)
                
        c.qid=q_id
        
    return candidates

candidates = compute_confusion_metrics(candidates, df)

# %%
def display_candidates_in_df(candidates):
    list_of_lists = []
    headers = ['q_id',
               'question',
               'answer',
               'OA_' + candidates[0].confusion_factors[0],
               'OA_' + candidates[0].confusion_factors[1],
               #'A_num_of_incidents', 'A_#_sources', 
               'A_avg_#_sources', 
               #'N_num_of_incidents', 'N_#_sources', 
               'N_avg_#_sources',
               'N2S',
              'A_sources',
              'N_sources',
               'A_avg_DCT_spread'
               ]
    for c in candidates:
        one_row = [
                c.qid,
                c.question,
                c.answer,
                c.oa_list[0],
                c.oa_list[1],
                #a[0],
                #a[1],
                c.a_avg_num_sources,
                #n[0],
                #n[1],
                c.n_avg_num_sources,
                c.n2s_ratio,
                c.a_sources,
                c.n_sources,
                c.dct_spread
                ]
        list_of_lists.append(one_row)
            
    question_df = pandas.DataFrame(list_of_lists, columns=headers)
    return question_df
    
question_df=display_candidates_in_df(candidates)

# %%
len(question_df)
# Out:
# 101

# %%
question_df
# Out:
#      q_id                                           question  answer  \
# 0       1  How many events happened in California that in...       5
# 1       2  How many events happened in Georgia that invol...       3
# 2       3  How many events happened in Florida that invol...       3
# 3       4  How many events happened in Tennessee that inv...       3
# 4       5  How many events happened in Louisiana that inv...       5
# 5       6  How many events happened in California that in...       4
# 6       7  How many events happened in Illinois that invo...       4
# 7       8  How many events happened in Florida that invol...       4
# 8       9  How many events happened in Florida that invol...       3
# 9      10  How many events happened in Florida that invol...       7
# 10     11  How many events happened in Indiana that invol...       3
# 11     12  How many events happened in Georgia that invol...       5
# 12     13  How many events happened in Tennessee that inv...       6
# 13     14  How many events happened in Virginia that invo...       3
# 14     15  How many events happened in Maryland that invo...       3
# 15     16  How many events happened in Alabama that invol...       3
# 16     17  How many events happened in Florida that invol...       3
# 17     18  How many events happened in Texas that involve...       3
# 18     19  How many events happened in New York that invo...       4
# 19     20  How many events happened in California that in...       3
# 20     21  How many events happened in California that in...       3
# 21     22  How many events happened in California that in...       4
# 22     23  How many events happened in New York that invo...       3
# 23     24  How many events happened in Illinois that invo...       3
# 24     25  How many events happened in Georgia that invol...       3
# 25     26  How many events happened in California that in...       3
# 26     27  How many events happened in South Carolina tha...       3
# 27     28  How many events happened in Georgia that invol...       3
# 28     29  How many events happened in North Carolina tha...       3
# 29     30  How many events happened in California that in...       3
# ..    ...                                                ...     ...
# 71     72  How many events happened in Texas that involve...       3
# 72     73  How many events happened in Ohio that involve ...       4
# 73     74  How many events happened in Texas that involve...       3
# 74     75  How many events happened in Tennessee that inv...       3
# 75     76  How many events happened in Florida that invol...       3
# 76     77  How many events happened in Florida that invol...       3
# 77     78  How many events happened in New York that invo...       3
# 78     79  How many events happened in Louisiana that inv...       3
# 79     80  How many events happened in Florida that invol...       3
# 80     81  How many events happened in Virginia that invo...       3
# 81     82  How many events happened in Texas that involve...       3
# 82     83  How many events happened in Georgia that invol...       4
# 83     84  How many events happened in New York that invo...       3
# 84     85  How many events happened in Florida that invol...       3
# 85     86  How many events happened in New York that invo...       3
# 86     87  How many events happened in Louisiana that inv...       3
# 87     88  How many events happened in Illinois that invo...       3
# 88     89  How many events happened in California that in...       3
# 89     90  How many events happened in Michigan that invo...       3
# 90     91  How many events happened in North Carolina tha...       3
# 91     92  How many events happened in Florida that invol...       3
# 92     93  How many events happened in Tennessee that inv...       5
# 93     94  How many events happened in Ohio that involve ...       4
# 94     95  How many events happened in Florida that invol...       8
# 95     96  How many events happened in Jacksonville that ...       3
# 96     97  How many events happened in Daytona Beach that...       3
# 97     98  How many events happened in Orlando that invol...       3
# 98     99  How many events happened in Dallas that involv...       3
# 99    100  How many events happened in Baltimore that inv...       3
# 100   101  How many events happened in Miami that involve...       3
#
#      OA_location  OA_participant  A_avg_#_sources  N_avg_#_sources        N2S  \
# 0              1              16         2.400000         2.143713  33.400000
# 1              1              29         3.000000         2.965116  28.666667
# 2              1               4         2.000000         2.918605  28.666667
# 3              1              43         3.333333         3.071429  28.000000
# 4              1              52         3.800000         3.444444  18.000000
# 5              1              43         2.250000         2.352041  49.000000
# 6              1               7         2.000000         1.991150  28.250000
# 7              1              43         3.750000         3.056911  30.750000
# 8              1              15         3.000000         2.865979  32.333333
# 9              1              52         2.857143         3.007937  18.000000
# 10             1              15         3.333333         2.560976  13.666667
# 11             1              43         2.800000         2.906250  19.200000
# 12             1              28         3.666667         2.619048  10.500000
# 13             1              33         2.666667         3.070175  19.000000
# 14             1              34         3.333333         2.684211  19.000000
# 15             1              15         2.000000         2.625000  10.666667
# 16             1               6         1.333333         2.977273  29.333333
# 17             1              16         3.000000         3.545455  29.333333
# 18             1              52         5.250000         2.768519  27.000000
# 19             1               9         4.666667         2.000000  54.666667
# 20             1              29         2.666667         2.326087  61.333333
# 21             1              28         2.000000         2.171271  45.250000
# 22             1               4         3.333333         2.677419  20.666667
# 23             1              43         3.000000         2.384106  50.333333
# 24             1              15         2.666667         2.527778  24.000000
# 25             1              38         3.000000         2.585492  64.333333
# 26             1              52         2.666667         3.081081  24.666667
# 27             1               5         2.000000         2.483871  20.666667
# 28             1              38         3.333333         3.865672  22.333333
# 29             1               7         2.666667         2.061728  54.000000
# ..           ...             ...              ...              ...        ...
# 71             1              19         3.333333         3.681319  30.333333
# 72             1              36         5.500000         4.088235  17.000000
# 73             1               4         2.666667         3.500000  25.333333
# 74             1              14         2.666667         2.709091  18.333333
# 75             1              20         9.666667         2.696078  34.000000
# 76             1               5         7.666667         2.712644  29.000000
# 77             1              20         2.333333         3.025641  26.000000
# 74   {http://www.dnj.com/story/news/2016/05/02/shoo...                -1
# 75   {, http://www.wsvn.com/story/29681933/police-a...                -1
# 76   {http://www.local10.com/news/south-florida-wom...                -1
# 77   {http://www.local10.com/news/south-florida-wom...                -1
# 78   {http://www.nola.com/crime/index.ssf/2016/10/p...                -1
# 79   {, https://www.justice.gov/usao-edmi/pr/six-vi...                -1
# 80   {http://www.wdbj7.com/content/news/Shooting-re...                -1
# 81   {http://www.mysanantonio.com/news/local/crime/...                -1
# 82   {, http://www.orlandosentinel.com/news/breakin...                -1
# 83   {http://www.timesunion.com/local/article/Alert...                -1
# 84   {, http://www.local10.com/news/south-florida-w...                -1
# 85   {http://www.local10.com/news/south-florida-wom...                -1
# 86   {http://www.nola.com/crime/index.ssf/2016/10/p...                -1
# 87   {http://kwqc.com/ap/5-teens-shot-in-drive-by-s...                -1
# 88   {http://www.local10.com/news/south-florida-wom...                -1
# 89   {, http://www.local10.com/news/south-florida-w...                -1
# 90   {http://www.wwltv.com/story/news/crime/2015/11...                -1
# 91   {, http://www.local10.com/news/south-florida-w...                -1
# 92   {http://gazette.com/live-coverage-police-engag...                -1
# 93   {http://www.wlwt.com/news/1-dead-several-other...                -1
# 94   {, http://www.orlandosentinel.com/news/breakin...                -1
# 95   {http://www.blythevillecourier.com/story/22480...                -1
# 96   {http://www.thetimesnews.com/20130925/four-sho...                -1
# 97   {http://www.kiiitv.com/story/32310954/shooting...                -1
# 98   {https://www.justice.gov/usao-edmi/pr/six-vice...                -1
# 99   {http://www.nola.com/crime/index.ssf/2016/10/p...                -1
# 100  {http://www.wwltv.com/story/news/crime/2015/11...                -1
#
# [101 rows x 11 columns]

# %%
#table = tabulate(question_df, headers='keys', tablefmt='html')
#display(HTML(table))
for index, row in question_df.iterrows():
    print()
    print(row['question'])
    print(row)
    for source_url in row['A_sources']:
        print(source_url)
    break
# Out:
# How many events happened in California that involve Hernandez ?
# q_id                                                                1
# question            How many events happened in California that in...
# answer                                                              5
# OA_location                                                         1
# OA_participant                                                     16
# A_avg_#_sources                                                   2.4
# N_avg_#_sources                                               2.14371
# N2S                                                              33.4
# A_sources           {https://www.lawa.org/uploadedFiles/LAX/LAWA%2...
# N_sources           {http://www.local10.com/news/south-florida-wom...
# A_avg_DCT_spread                                                   -1
# Name: 0, dtype: object
# https://www.lawa.org/uploadedFiles/LAX/LAWA%20T3%20After%20Action%20Report%20March%2018%202014.pdf
# http://www.ksbw.com/news/central-california/salinas/double-homicide-in-salinas/21334240
# http://www.losbanosenterprise.com/2013/04/03/205615/teens-in-los-banos-homicide-case.html
# http://www.nbclosangeles.com/news/local/Three-Homicides-San-Fernando-Valley-May-Be-Linked-272485031.html
# http://www.nbclosangeles.com/news/local/Man-Charged-With-Murder-in-Series-of-Shootings-272790231.html
# http://www.pe.com/articles/jurupa-795749-valley-shooting.html
# http://www.latimes.com/local/lanow/la-me-ln-death-penalty-sought-in-lax-shooting-spree-20150102-story.html
# http://www.montereyherald.com/article/ZZ/20140530/NEWS/140539692
# http://www.mercedsunstar.com/news/local/article3288744.html
# http://www.riversidesheriff.org/press/chu16-0228.asp
# http://www.mercedsunstar.com/news/local/article3286805.html
# http://www.nbclosangeles.com/news/local/SoCal-Teacher-Survives-LAX-Shooting-Rampage-230385911.html
