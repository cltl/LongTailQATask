# %%
import pickle
import pandas
from collections import Counter
import operator

# %%
df_paths = [#'frames/mass_shootings_2013',
            #'frames/mass_shootings_2014',
            'frames/mass_shootings_2015']
frames = []
for df_path in df_paths:
    with open(df_path, 'rb') as infile:
        df = pickle.load(infile)
        frames.append(df)
df = pandas.concat(frames)

# %%
all_incidents={}
for index, row in df.iterrows():
    print()
    print(index)
    print(row)
    all_incidents[index] = row['incident_sources']
    all_incidents[index].add(row['source_url'])
    # all_sources contain all the html links
    if index==9:
        break
# Out:
# 0
# date                                                December 31, 2015
# state                                                       Louisiana
# city_or_county                                            New Orleans
# address                                   1900 block of Amelia Street
# num_killed                                                          0
# num_injured                                                         6
# incident_url        http://www.gunviolencearchive.org/incident/476321
# source_url          http://www.nola.com/crime/index.ssf/2016/03/su...
# incident_sources    {http://www.fox8live.com/story/30864852/shooti...
# participants        [{'Status': ' Injured', 'Age': ' 15', 'Type': ...
# Name: 0, dtype: object
#
# 1
# date                                                December 27, 2015
# state                                                       Tennessee
# city_or_county                                                Jackson
# address                                                 North Parkway
# num_killed                                                          0
# num_injured                                                         4
# incident_url        http://www.gunviolencearchive.org/incident/473882
# source_url          http://www.wbbjtv.com/video/four-injured-in-ba...
# incident_sources    {http://www.wbbjtv.com/video/four-injured-in-b...
# participants        [{'Status': ' Injured', 'Type': ' Victim'}, {'...
# Name: 1, dtype: object
#
# 2
# date                                                December 26, 2015
# state                                                    Pennsylvania
# city_or_county                                           Philadelphia
# address                                            4210 Macalester St
# num_killed                                                          0
# num_injured                                                         4
# incident_url        http://www.gunviolencearchive.org/incident/472268
# source_url          http://www.philly.com/philly/news/Four_injured...
# incident_sources    {http://philadelphia.cbslocal.com/2015/12/26/3...
# participants        [{'Status': ' Injured', 'Age': ' 21', 'Type': ...
# Name: 2, dtype: object
#
# 3
# date                                                December 25, 2015
# state                                                         Florida
# city_or_county                                           Jacksonville
# address                                           Franklin and Odessa
# num_killed                                                          0
# num_injured                                                         4
# incident_url        http://www.gunviolencearchive.org/incident/471867
# source_url          http://www.actionnewsjax.com/news/news/local/i...
# incident_sources    {http://jacksonville.com/news/crime/2015-12-25...
# participants        [{'Status': ' Injured', 'Name': ' Bailey Price...
# Name: 3, dtype: object
#
# 4
# date                                                December 25, 2015
# state                                                         Alabama
# city_or_county                                                 Mobile
# address                                          785 Schillinger Rd S
# num_killed                                                          0
# num_injured                                                         4
# incident_url        http://www.gunviolencearchive.org/incident/471860
# source_url          http://m.wtvm.com/wtvm/db/376055/content/cDjbcCrb
# incident_sources    {http://m.wtvm.com/wtvm/db/376055/content/cDjb...
# participants        [{'Status': ' Injured', 'Age': ' 14', 'Type': ...
# Name: 4, dtype: object
#
# 5
# date                                                December 21, 2015
# state                                                      California
# city_or_county                                            San Leandro
# address                               14600 block of East 14th Street
# num_killed                                                          0
# num_injured                                                         4
# incident_url        http://www.gunviolencearchive.org/incident/469468
# source_url          http://www.sfgate.com/crime/article/2-arrested...
# incident_sources    {https://www.google.com/url?sa=t&rct=j&q=&esrc...
# participants        [{'Status': ' Injured', 'Type': ' Victim', 'Ag...
# Name: 5, dtype: object
#
# 6
# date                                                December 20, 2015
# state                                                  North Carolina
# city_or_county                                             Wilmington
# address                                        11th and Castle Street
# num_killed                                                          1
# num_injured                                                         4
# incident_url        http://www.gunviolencearchive.org/incident/468968
# source_url          http://www.wect.com/story/30795602/happening-t...
# incident_sources    {http://www.hickoryrecord.com/news/state/ap/po...
# participants        [{'Status': ' Killed', 'Name': ' Shane Simpson...
# Name: 6, dtype: object
#
# 7
# date                                                December 20, 2015
# state                                                         Florida
# city_or_county                                         Miami (Goulds)
# address                                  21630 Southwest 120th Avenue
# num_killed                                                          1
# num_injured                                                         4
# incident_url        http://www.gunviolencearchive.org/incident/468787
# source_url          http://www.miamiherald.com/news/local/communit...
# incident_sources    {http://miami.cbslocal.com/2015/12/20/five-peo...
# participants        [{'Status': ' Killed', 'Name': ' Raheem Shanno...
# Name: 7, dtype: object
#
# 8
# date                                                December 20, 2015
# state                                                         Florida
# city_or_county                                    Miami-dade (county)
# address             Northeast Seventh Avenue and Northeast 166th S...
# num_killed                                                          0
# num_injured                                                         4
# incident_url        http://www.gunviolencearchive.org/incident/469614
# source_url          http://www.nbcmiami.com/news/local/Four-Injure...
# incident_sources    {http://www.nbcmiami.com/news/local/Four-Injur...
# participants        [{'Status': ' Injured', 'Type': ' Victim'}, {'...
# Name: 8, dtype: object
#
# 9
# date                                                December 14, 2015
# state                                                        Illinois
# city_or_county                                     Lovejoy (Brooklyn)
# address                                              307 Jefferson St
# num_killed                                                          1
# num_injured                                                         3
# incident_url        http://www.gunviolencearchive.org/incident/465117
# source_url          http://www.bnd.com/news/local/crime/article509...
# incident_sources    {http://www.bnd.com/news/local/crime/article50...
# participants        [{'Status': ' Killed', 'Name': ' Salahudin Mal...
# Name: 9, dtype: object

# %%
import utils

ERRORS_FILE="errors.txt"
errors=open(ERRORS_FILE, "a+")
utils.reset_files()
for index in all_incidents:
    my_dir=utils.reset_dir(index)
    for source in all_incidents[index]:
        article=utils.whats_behind_a_uri(source)
        if article:
            utils.dump_to_file(article, my_dir)
        else:
            errors.write(source + '\n')
# Out:
# Article http://www.fox8live.com/story/30864852/shooting-injures-5-on-new-years-eve-in-nola written!
# Article http://www.wwltv.com/story/news/crime/2016/01/01/new-years-eve-shooting-raises-questions-city-crime/78190114/ written!
# Article http://www.nola.com/crime/index.ssf/2016/03/suspect_arrested_in_new_years.html#incart_river_index written!
# Article http://www.wbbjtv.com/video/four-injured-in-bar-shooting/ written!
# Article http://philadelphia.cbslocal.com/2015/12/26/3-people-shot-in-northeast-philly/ written!
# Article http://www.philly.com/philly/news/Four_injured_in_Feltonville_shooting.html written!
# Article http://jacksonville.com/news/crime/2015-12-25/story/christmas-night-shooting-leaves-2-year-old-3-others-shot-jacksonvilles?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+JacksonvillecomNews+%28Jacksonville+Local+News+%E2%80%93+Jacksonville.com written!
# Article http://www.actionnewsjax.com/news/news/local/identities-christmas-night-quadruple-shooting-vict/npsT7/ written!
# Article http://m.wtvm.com/wtvm/db/376055/content/cDjbcCrb written!
# Article http://wkrg.com/2015/12/25/shooting-at-wynnsong-16-in-mobile/ written!
# Article https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=1&cad=rja&uact=8&ved=0ahUKEwiYwcOC-PLJAhVLHT4KHTkLDZYQFggdMAA&url=http%3A%2F%2Fwww.nbcbayarea.com%2Fnews%2Flocal%2FTwo-Suspects-in-Custody-After-Quadruple-Shooting-at-Club-Caliente-in-San-Leand written!
# Article http://www.sfgate.com/crime/article/2-arrested-for-shooting-4-people-outside-San-6717634.php written!
# Article http://www.insidebayarea.com/breaking-news/ci_29292169/san-leandro-four-shot-outside-club-caliente-night written!
# Article http://www.wect.com/story/30795602/happening-today-wpd-to-discuss-fatal-shooting-investigation written!
# Article http://www.starnewsonline.com/article/20151220/NEWS/151229998/1177?Title=UPDATE-Vigil-honors-teen-slain-in-shooting-that-injured-four-others written!
# Article http://miami.cbslocal.com/2015/12/20/five-people-shot-outside-grocery-store-in-south-miami/ written!
# Article http://www.miamiherald.com/news/local/community/miami-dade/homestead/article50776055.html written!
# Article http://www.nbcmiami.com/news/local/Four-Injured-in-NE-Miami-Dade-Drive-By-Shooting-Police-363112801.html written!
# Article http://www.bnd.com/news/local/crime/article50905855.html written!
# Article http://www.pjstar.com/article/20151214/NEWS/151219768 written!
