# %%
import requests
from lxml import etree
import pickle
import pandas
from datetime import datetime

# %%
def get_gunviolence_page(url):
    """
    create pandas.dataframe from one page of gunviolence e.g.
    http://www.gunviolencearchive.org/reports/mass-shootings/2014
    
    :param str url: gunviolence output page
    http://www.gunviolencearchive.org/reports/mass-shootings/2014
    
    :rtype: pandas.core.frame.DataFrame
    :return: info from the violence page in a dataframe
    
    """
    call = requests.get(url)
    doc = etree.HTML(call.text)
    
    headers = ['incident_uri',
               'date', 'state', 'city_or_county',
               'address', 'num_killed', 'num_injured',
               'incident_url', 'source_url', 'incident_sources',
               'participants']
    list_of_reports = []

    for tr_el in doc.xpath('//tr[@class="even" or @class="odd"]'):
        td_els = tr_el.getchildren()

        date = td_els[0].text
        state = td_els[1].text
        city_or_county = td_els[2].text
        address = td_els[3].text
        num_killed = int(td_els[4].text)
        num_injured = int(td_els[5].text)

        operations_el = td_els[6]
        a_els = operations_el.findall('ul/li/a')

        # get incident url
        incident_base = 'http://www.gunviolencearchive.org'
        incident_ending = a_els[0].get('href')
        incident_url = incident_base + incident_ending
        incident_uri = incident_url.split('/')[-1]

        # get source url
        source_url = ''
        if len(a_els) == 2:
            source_url = a_els[1].get('href')

        # get incident sources
        incident_call = requests.get(incident_url)
        incident_doc = etree.HTML(incident_call.text)

        incident_sources = set()
        for li_el in incident_doc.xpath('//li'):
            if li_el.text is not None:
                if 'URL:' in li_el.text:
                    for a_el in li_el.xpath('a'):
                        incident_sources.add(a_el.get('href'))
                        
        # get participants information
        div_els = incident_doc.xpath('//div[h2[text()="Participants"]]')
        div_el = div_els[0]
        participants = []

        for ul_el in div_el.iterfind('div/ul'):
            participant = dict()
            for li_el in ul_el.iterfind('li'):
                attr, value = li_el.text.split(':')
                participant[attr] = value
            participants.append(participant)
            
            
        incident_report = [incident_uri,
                           date, state, city_or_county,
                           address, num_killed, num_injured,
                           incident_url, source_url, incident_sources, participants]
        list_of_reports.append(incident_report)
    
    df = pandas.DataFrame(list_of_reports, columns=headers)
    return df

# %%
def paginate(base_url, debug=False):
    """
    paginate over gunviolence urls
    
    :param str base_url: paginate over gunviolence urls
    
    :rtype: pandas.core.frame.DataFrame
    :return: all results from one category
    
    """
    frames = []
    previous_df = get_gunviolence_page(base_url)
    frames.append(previous_df)

    keep_going = True
    counter = 1
    while keep_going:
        url = base_url + '?page=' + str(counter)
        print(url)
        
        df = get_gunviolence_page(url)
        counter += 1

        if df.equals(previous_df):
            keep_going = False
        else:
            frames.append(df)
            previous_df = df

    df = pandas.concat(frames)
    return df

# %%
urls_and_paths = [#('frames/children_killed', 'http://www.gunviolencearchive.org/children-killed'),
                  #('frames/children_injured', 'http://www.gunviolencearchive.org/children-injured'),
                  ('frames/teens_killed', 'http://www.gunviolencearchive.org/teens-killed'),
                  ('frames/teens_injured', 'http://www.gunviolencearchive.org/teens-injured'),
                  ('frames/accidental_deaths', 'http://www.gunviolencearchive.org/accidental-deaths'),
                  ('frames/accidental_injuries', 'http://www.gunviolencearchive.org/accidental-injuries'),
                  ('frames/accidental_deaths_children', 'http://www.gunviolencearchive.org/accidental-child-deaths'),
                  ('frames/accidental_injuries_children', 'http://www.gunviolencearchive.org/accidental-child-injuries'),
                  ('frames/accidental_deaths_teens', 'http://www.gunviolencearchive.org/accidental-teen-deaths'),
                  ('frames/accidental_injuries_teens', 'http://www.gunviolencearchive.org/accidental-teen-injuries'),
                  ('frames/officer_involved_shootings', 'http://www.gunviolencearchive.org/officer-involved-shootings'),
                  ('frames/mass_shootings_2013', 'http://www.gunviolencearchive.org/reports/mass-shootings/2013'),
                  ('frames/mass_shootings_2014', 'http://www.gunviolencearchive.org/reports/mass-shootings/2014'),
                  ('frames/mass_shootings_2015', 'http://www.gunviolencearchive.org/reports/mass-shootings/2015'),
                  ('frames/mass_shootings', 'http://www.gunviolencearchive.org/mass-shooting')]
for output_path, base_url in urls_and_paths:
    print()
    print('starting', output_path, datetime.now())
    df = paginate(base_url)
    with open(output_path, 'wb') as outfile:
        pickle.dump(df, outfile)
    print('done', output_path, datetime.now())
# Out:
# starting frames/teens_killed 2017-01-27 16:50:03.906894
# http://www.gunviolencearchive.org/teens-killed?page=1
# http://www.gunviolencearchive.org/teens-killed?page=2
# http://www.gunviolencearchive.org/teens-killed?page=3
# http://www.gunviolencearchive.org/teens-killed?page=4
# http://www.gunviolencearchive.org/teens-killed?page=5
# http://www.gunviolencearchive.org/teens-killed?page=6
# http://www.gunviolencearchive.org/teens-killed?page=7
# http://www.gunviolencearchive.org/teens-killed?page=8
# http://www.gunviolencearchive.org/teens-killed?page=9
# http://www.gunviolencearchive.org/teens-killed?page=10
# http://www.gunviolencearchive.org/teens-killed?page=11
# http://www.gunviolencearchive.org/teens-killed?page=12
# http://www.gunviolencearchive.org/teens-killed?page=13
# http://www.gunviolencearchive.org/teens-killed?page=14
# http://www.gunviolencearchive.org/teens-killed?page=15
# http://www.gunviolencearchive.org/teens-killed?page=16
# http://www.gunviolencearchive.org/teens-killed?page=17
# http://www.gunviolencearchive.org/teens-killed?page=18
# done frames/teens_killed 2017-01-27 16:53:13.807809
#
# starting frames/teens_injured 2017-01-27 16:53:13.807892
# http://www.gunviolencearchive.org/teens-injured?page=1
# http://www.gunviolencearchive.org/teens-injured?page=2
# http://www.gunviolencearchive.org/teens-injured?page=3
# http://www.gunviolencearchive.org/teens-injured?page=4
# http://www.gunviolencearchive.org/teens-injured?page=5
# http://www.gunviolencearchive.org/teens-injured?page=6
# http://www.gunviolencearchive.org/teens-injured?page=7
# http://www.gunviolencearchive.org/teens-injured?page=8
# http://www.gunviolencearchive.org/teens-injured?page=9
# http://www.gunviolencearchive.org/teens-injured?page=10
# http://www.gunviolencearchive.org/teens-injured?page=11
# http://www.gunviolencearchive.org/teens-injured?page=12
# http://www.gunviolencearchive.org/teens-injured?page=13
# http://www.gunviolencearchive.org/teens-injured?page=14
# http://www.gunviolencearchive.org/teens-injured?page=15
# http://www.gunviolencearchive.org/teens-injured?page=16
# http://www.gunviolencearchive.org/teens-injured?page=17
# http://www.gunviolencearchive.org/teens-injured?page=18
# done frames/teens_injured 2017-01-27 16:56:04.365985
#
# starting frames/accidental_deaths 2017-01-27 16:56:04.366121
# http://www.gunviolencearchive.org/accidental-deaths?page=1
# http://www.gunviolencearchive.org/accidental-deaths?page=2
# http://www.gunviolencearchive.org/accidental-deaths?page=3
# http://www.gunviolencearchive.org/accidental-deaths?page=4
# http://www.gunviolencearchive.org/accidental-deaths?page=5
# http://www.gunviolencearchive.org/accidental-deaths?page=6
# http://www.gunviolencearchive.org/accidental-deaths?page=7
# http://www.gunviolencearchive.org/accidental-deaths?page=8
# http://www.gunviolencearchive.org/accidental-deaths?page=9
# http://www.gunviolencearchive.org/accidental-deaths?page=10
# http://www.gunviolencearchive.org/accidental-deaths?page=11
# http://www.gunviolencearchive.org/accidental-deaths?page=12
# http://www.gunviolencearchive.org/accidental-deaths?page=13
# http://www.gunviolencearchive.org/accidental-deaths?page=14
# http://www.gunviolencearchive.org/accidental-deaths?page=15
# http://www.gunviolencearchive.org/accidental-deaths?page=16
# http://www.gunviolencearchive.org/accidental-deaths?page=17
# http://www.gunviolencearchive.org/accidental-deaths?page=18
# done frames/accidental_deaths 2017-01-27 16:58:09.412970
#
# starting frames/accidental_injuries 2017-01-27 16:58:09.413133
# http://www.gunviolencearchive.org/accidental-injuries?page=1
# http://www.gunviolencearchive.org/accidental-injuries?page=2
# http://www.gunviolencearchive.org/accidental-injuries?page=3
# http://www.gunviolencearchive.org/accidental-injuries?page=4
# http://www.gunviolencearchive.org/accidental-injuries?page=5
# http://www.gunviolencearchive.org/accidental-injuries?page=6
# http://www.gunviolencearchive.org/accidental-injuries?page=7
# http://www.gunviolencearchive.org/accidental-injuries?page=8
# http://www.gunviolencearchive.org/accidental-injuries?page=9
# http://www.gunviolencearchive.org/accidental-injuries?page=10
# http://www.gunviolencearchive.org/accidental-injuries?page=11
# http://www.gunviolencearchive.org/accidental-injuries?page=12
# http://www.gunviolencearchive.org/accidental-injuries?page=13
# http://www.gunviolencearchive.org/accidental-injuries?page=14
# http://www.gunviolencearchive.org/accidental-injuries?page=15
# http://www.gunviolencearchive.org/accidental-injuries?page=16
# http://www.gunviolencearchive.org/accidental-injuries?page=17
# http://www.gunviolencearchive.org/accidental-injuries?page=18
# done frames/accidental_injuries 2017-01-27 17:00:33.284204
#
# starting frames/accidental_deaths_children 2017-01-27 17:00:33.284340
# http://www.gunviolencearchive.org/accidental-child-deaths?page=1
# http://www.gunviolencearchive.org/accidental-child-deaths?page=2
# http://www.gunviolencearchive.org/accidental-child-deaths?page=3
# http://www.gunviolencearchive.org/accidental-child-deaths?page=4
# http://www.gunviolencearchive.org/accidental-child-deaths?page=5
# http://www.gunviolencearchive.org/accidental-child-deaths?page=6
# http://www.gunviolencearchive.org/accidental-child-deaths?page=7
# http://www.gunviolencearchive.org/accidental-child-deaths?page=8
# http://www.gunviolencearchive.org/accidental-child-deaths?page=9
# done frames/accidental_deaths_children 2017-01-27 17:01:13.937002
#
# starting frames/accidental_injuries_children 2017-01-27 17:01:13.937224
# http://www.gunviolencearchive.org/accidental-child-injuries?page=1
# http://www.gunviolencearchive.org/accidental-child-injuries?page=2
# http://www.gunviolencearchive.org/accidental-child-injuries?page=3
# http://www.gunviolencearchive.org/accidental-child-injuries?page=4
# http://www.gunviolencearchive.org/accidental-child-injuries?page=5
# http://www.gunviolencearchive.org/accidental-child-injuries?page=6
# http://www.gunviolencearchive.org/accidental-child-injuries?page=7
# http://www.gunviolencearchive.org/accidental-child-injuries?page=8
# http://www.gunviolencearchive.org/accidental-child-injuries?page=9
# http://www.gunviolencearchive.org/accidental-child-injuries?page=10
# http://www.gunviolencearchive.org/accidental-child-injuries?page=11
# http://www.gunviolencearchive.org/accidental-child-injuries?page=12
# http://www.gunviolencearchive.org/accidental-child-injuries?page=13
# http://www.gunviolencearchive.org/accidental-child-injuries?page=14
# http://www.gunviolencearchive.org/accidental-child-injuries?page=15
# http://www.gunviolencearchive.org/accidental-child-injuries?page=16
# http://www.gunviolencearchive.org/accidental-child-injuries?page=17
# http://www.gunviolencearchive.org/accidental-child-injuries?page=18
# done frames/accidental_injuries_children 2017-01-27 17:03:05.017819
#
# starting frames/accidental_deaths_teens 2017-01-27 17:03:05.017906
# http://www.gunviolencearchive.org/accidental-teen-deaths?page=1
# http://www.gunviolencearchive.org/accidental-teen-deaths?page=2
# http://www.gunviolencearchive.org/accidental-teen-deaths?page=3
# http://www.gunviolencearchive.org/accidental-teen-deaths?page=4
# http://www.gunviolencearchive.org/accidental-teen-deaths?page=5
# http://www.gunviolencearchive.org/accidental-teen-deaths?page=6
# http://www.gunviolencearchive.org/accidental-teen-deaths?page=7
# http://www.gunviolencearchive.org/accidental-teen-deaths?page=8
# http://www.gunviolencearchive.org/accidental-teen-deaths?page=9
# http://www.gunviolencearchive.org/accidental-teen-deaths?page=10
# http://www.gunviolencearchive.org/accidental-teen-deaths?page=11
# http://www.gunviolencearchive.org/accidental-teen-deaths?page=12
# http://www.gunviolencearchive.org/accidental-teen-deaths?page=13
# done frames/accidental_deaths_teens 2017-01-27 17:04:24.217174
#
# starting frames/accidental_injuries_teens 2017-01-27 17:04:24.217247
# http://www.gunviolencearchive.org/accidental-teen-injuries?page=1
# http://www.gunviolencearchive.org/accidental-teen-injuries?page=2
# http://www.gunviolencearchive.org/accidental-teen-injuries?page=3
# http://www.gunviolencearchive.org/accidental-teen-injuries?page=4
# http://www.gunviolencearchive.org/accidental-teen-injuries?page=5
# http://www.gunviolencearchive.org/accidental-teen-injuries?page=6
# http://www.gunviolencearchive.org/accidental-teen-injuries?page=7
# http://www.gunviolencearchive.org/accidental-teen-injuries?page=8
# http://www.gunviolencearchive.org/accidental-teen-injuries?page=9
# http://www.gunviolencearchive.org/accidental-teen-injuries?page=10
# http://www.gunviolencearchive.org/accidental-teen-injuries?page=11
# http://www.gunviolencearchive.org/accidental-teen-injuries?page=12
# http://www.gunviolencearchive.org/accidental-teen-injuries?page=13
# http://www.gunviolencearchive.org/accidental-teen-injuries?page=14
# http://www.gunviolencearchive.org/accidental-teen-injuries?page=15
# http://www.gunviolencearchive.org/accidental-teen-injuries?page=16
# http://www.gunviolencearchive.org/accidental-teen-injuries?page=17
# http://www.gunviolencearchive.org/accidental-teen-injuries?page=18
# done frames/accidental_injuries_teens 2017-01-27 17:06:29.110156
#
# starting frames/officer_involved_shootings 2017-01-27 17:06:29.110233
# http://www.gunviolencearchive.org/officer-involved-shootings?page=1
# http://www.gunviolencearchive.org/officer-involved-shootings?page=2
# done frames/officer_involved_shootings 2017-01-27 17:06:47.406818
#
# starting frames/mass_shootings_2013 2017-01-27 17:06:47.406948
# http://www.gunviolencearchive.org/reports/mass-shootings/2013?page=1
# http://www.gunviolencearchive.org/reports/mass-shootings/2013?page=2
# http://www.gunviolencearchive.org/reports/mass-shootings/2013?page=3
# http://www.gunviolencearchive.org/reports/mass-shootings/2013?page=4
# http://www.gunviolencearchive.org/reports/mass-shootings/2013?page=5
# http://www.gunviolencearchive.org/reports/mass-shootings/2013?page=6
# http://www.gunviolencearchive.org/reports/mass-shootings/2013?page=7
# http://www.gunviolencearchive.org/reports/mass-shootings/2013?page=8
# http://www.gunviolencearchive.org/reports/mass-shootings/2013?page=9
# http://www.gunviolencearchive.org/reports/mass-shootings/2013?page=10
# http://www.gunviolencearchive.org/reports/mass-shootings/2013?page=11
# done frames/mass_shootings_2013 2017-01-27 17:08:32.436223
#
# starting frames/mass_shootings_2014 2017-01-27 17:08:32.436313
# http://www.gunviolencearchive.org/reports/mass-shootings/2014?page=1
# http://www.gunviolencearchive.org/reports/mass-shootings/2014?page=2
# http://www.gunviolencearchive.org/reports/mass-shootings/2014?page=3
# http://www.gunviolencearchive.org/reports/mass-shootings/2014?page=4
# http://www.gunviolencearchive.org/reports/mass-shootings/2014?page=5
# http://www.gunviolencearchive.org/reports/mass-shootings/2014?page=6
# http://www.gunviolencearchive.org/reports/mass-shootings/2014?page=7
# http://www.gunviolencearchive.org/reports/mass-shootings/2014?page=8
# http://www.gunviolencearchive.org/reports/mass-shootings/2014?page=9
# http://www.gunviolencearchive.org/reports/mass-shootings/2014?page=10
# http://www.gunviolencearchive.org/reports/mass-shootings/2014?page=11
# done frames/mass_shootings_2014 2017-01-27 17:10:24.044536
#
# starting frames/mass_shootings_2015 2017-01-27 17:10:24.044656
# http://www.gunviolencearchive.org/reports/mass-shootings/2015?page=1
# http://www.gunviolencearchive.org/reports/mass-shootings/2015?page=2
# http://www.gunviolencearchive.org/reports/mass-shootings/2015?page=3
# http://www.gunviolencearchive.org/reports/mass-shootings/2015?page=4
# http://www.gunviolencearchive.org/reports/mass-shootings/2015?page=5
# http://www.gunviolencearchive.org/reports/mass-shootings/2015?page=6
# http://www.gunviolencearchive.org/reports/mass-shootings/2015?page=7
# http://www.gunviolencearchive.org/reports/mass-shootings/2015?page=8
# http://www.gunviolencearchive.org/reports/mass-shootings/2015?page=9
# http://www.gunviolencearchive.org/reports/mass-shootings/2015?page=10
# http://www.gunviolencearchive.org/reports/mass-shootings/2015?page=11
# http://www.gunviolencearchive.org/reports/mass-shootings/2015?page=12
# http://www.gunviolencearchive.org/reports/mass-shootings/2015?page=13
# http://www.gunviolencearchive.org/reports/mass-shootings/2015?page=14
# done frames/mass_shootings_2015 2017-01-27 17:12:31.625948
#
# starting frames/mass_shootings 2017-01-27 17:12:31.626100
# http://www.gunviolencearchive.org/mass-shooting?page=1
# http://www.gunviolencearchive.org/mass-shooting?page=2
# http://www.gunviolencearchive.org/mass-shooting?page=3
# http://www.gunviolencearchive.org/mass-shooting?page=4
# http://www.gunviolencearchive.org/mass-shooting?page=5
# http://www.gunviolencearchive.org/mass-shooting?page=6
# http://www.gunviolencearchive.org/mass-shooting?page=7
# http://www.gunviolencearchive.org/mass-shooting?page=8
# http://www.gunviolencearchive.org/mass-shooting?page=9
# http://www.gunviolencearchive.org/mass-shooting?page=10
# http://www.gunviolencearchive.org/mass-shooting?page=11
# http://www.gunviolencearchive.org/mass-shooting?page=12
# http://www.gunviolencearchive.org/mass-shooting?page=13
# http://www.gunviolencearchive.org/mass-shooting?page=14
# http://www.gunviolencearchive.org/mass-shooting?page=15
# http://www.gunviolencearchive.org/mass-shooting?page=16
# http://www.gunviolencearchive.org/mass-shooting?page=17
# http://www.gunviolencearchive.org/mass-shooting?page=18
# done frames/mass_shootings 2017-01-27 17:15:23.261838
