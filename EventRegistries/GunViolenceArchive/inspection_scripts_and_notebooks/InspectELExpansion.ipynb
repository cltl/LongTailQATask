# %%
import pickle
import pandas
from collections import Counter, defaultdict
import operator
import utils
from geopy.geocoders import Nominatim

# %%
urls_and_paths = [('frames/children_killed', 'http://www.gunviolencearchive.org/children-killed'),
                  ('frames/children_injured', 'http://www.gunviolencearchive.org/children-injured'),
                  ('frames/teens_killed', 'http://www.gunviolencearchive.org/teens-killed'),
                  ('frames/teens_injured', 'http://www.gunviolencearchive.org/teens-injured'),
                  ('frames/accidental_deaths', 'http://www.gunviolencearchive.org/accidental-deaths'),
                  ('frames/accidental_injuries', 'http://www.gunviolencearchive.org/accidental-injuries'),
                  ('frames/accidental_deaths_children', 'http://www.gunviolencearchive.org/accidental-child-deaths'),
                  ('frames/accidental_injuries_children', 'http://www.gunviolencearchive.org/accidental-child-injuries'),
                  ('frames/accidental_deaths_teens', 'http://www.gunviolencearchive.org/accidental-teen-deaths'),
                  ('frames/accidental_injuries_teens', 'http://www.gunviolencearchive.org/accidental-teen-injuries'),
                  ('frames/officer_involved_shootings', 'http://www.gunviolencearchive.org/officer-involved-shootings'),
                  ('frames/mass_shootings_2013', 'http://www.gunviolencearchive.org/reports/mass-shootings/2013'),
                  ('frames/mass_shootings_2014', 'http://www.gunviolencearchive.org/reports/mass-shootings/2014'),
                  ('frames/mass_shootings_2015', 'http://www.gunviolencearchive.org/reports/mass-shootings/2015'),
                  ('frames/mass_shootings', 'http://www.gunviolencearchive.org/mass-shooting')]
CORPUS_NAME = 'the_violent_corpus'

# %%
frames = []
for df_path, url in urls_and_paths:
    with open(df_path, 'rb') as infile:
        df = pickle.load(infile)
        frames.append(df)
df = pandas.concat(frames)
len(df)
# Out:
# 5485

# %%
total_participants=set()
alltokens=defaultdict(int)
for index, row in df.iterrows():
    if len(row['participants']):
        full_text=utils.concat_all_sources(row['incident_uri'])
        names=set()
        for p in row['participants']:
            if 'Name' in p and not p['Name'].strip().isdigit():
                names.add(p['Name'].strip())
        if all([n in full_text for n in names]):
            for name in names:
                total_participants.add(tuple([row['incident_uri'], name]))
                tokens=name.split()
                for t in tokens:
                    alltokens[t]+=1
print(len(total_participants))
#    if row['incident_uri'] not in uris:
#        pass # do the magic here
#        uris.add(row['incident_uri'])
# Out:
# 3880

# %%
total_participants
# Out:
# {('386225', 'Mark Weekly'),
#  ('724900', 'Alex Dixon'),
#  ('590659', 'Brandon Ramirez'),
#  ('491438', 'Gabriel Daniels'),
#  ('610584', 'Tavaris Gilbert'),
#  ('608614', 'Denise Couplin'),
#  ('723429', 'Joel Rodriguez'),
#  ('280068', 'Robert Thomas'),
#  ('591674', 'Mary Bryan'),
#  ('440743', 'Barbara Scott'),
#  ('510769', 'Rakim Watson'),
#  ('201648', 'Juan Pedro Garcia'),
#  ('709650', 'Logan Ron Augustine'),
#  ('680444', 'Marcos Antonio Jimenez'),
#  ('651434', 'Stephon Harris'),
#  ('174965', 'Tradon Crawford'),
#  ('583067', 'Curtlon Panoske'),
#  ('711803', 'Sang Kim'),
#  ('726737', 'Deputy Ricky Scott'),
#  ('351958', 'Audley Burrell'),
#  ('531173', 'Qadarus Javon Grimes'),
#  ('723825', 'David Shore'),
#  ('727258', 'Levi Harrison'),
#  ('640899', 'James Page'),
#  ('579490', 'Maleah Ellis'),
#  ('748066', 'Sheahonnie Davis'),
#  ('579065', 'Juprie Wadley'),
#  ('102719', 'James Carson Smith'),
#  ('669118', 'Gregory Lambert'),
#  ('465117', 'Salahudin Malik Robbins'),
#  ('593238', 'Anna Sanchez'),
#  ('539890', 'Branden Davis'),
#  ('711973', 'John Lander'),
#  ('483835', 'Jose M. Carballido'),
#  ('491416', 'Rashid Pryor'),
#  ('476321', 'Tuwan Minor'),
#  ('546818', 'Nghia Trong Tran'),
#  ('478231', 'Jeremiah Danta-Benjamin Horsley'),
#  ('120303', 'Rodney Rodriguez Reid'),
#  ('727759', 'Shacora Jackson'),
#  ('401031', 'Austin Dewayne Stapp'),
#  ('757042', 'Avion Weaver'),
#  ('503571', 'Dominic Smith'),
#  ('488992', 'Aynis Vargas'),
#  ('659663', 'Faith Green'),
#  ('733492', 'Matthew Wilson'),
#  ('376920', 'Julian Roary'),
#  ('624551', 'Carstie Clausen'),
#  ('744836', 'Seth Easley'),
#  ('657151', 'Antonio Kelley'),
#  ('733645', 'Ariel Flores'),
#  ('680632', 'Jahee Tycari Hoke'),
#  ('759689', 'Kelin Ray'),
#  ('108112', 'Christopher Roupe'),
#  ('367780', 'Tavin Yeakey'),
#  ('675769', 'Kenneth Schmidt'),
#  ('693758', 'Shawn Turner'),
#  ('625582', 'Officer'),
#  ('726568', 'Karin Castro'),
#  ('493893', 'Terrell L. Skinner'),
#  ('226534', 'Raheem E. Cobbins'),
#  ('146565', 'Emmanuel Arrington'),
#  ('138282', 'Katherine Cooper'),
#  ('580111', 'Ajeanae Frazer'),
#  ('409101', 'Geovany Garcia'),
#  ('170351', 'Jon Gigantiello'),
#  ('402674', 'Thomas Horn'),
#  ('402108', 'Kentrell Jones'),
#  ('654566', 'Leroy "LJ" Rutherford Friedel'),
#  ('595069', 'Jamal Dixon-Lackey'),
#  ('580414', 'Christian Penaloza'),
#  ('735685', 'Eduardo Alvarez'),
#  ('610093', 'Rickey McGowan'),
#  ('659663', 'Kara Allen'),
#  ('144565', 'Kavavis Cole'),
#  ('692519', 'Harry Syndor Willis Jr.'),
#  ('677316', 'Dontay Jordan'),
#  ('492276', 'Lewis Mabrey Jr.'),
#  ('369014', 'Nicholas Jiles'),
#  ('365320', 'Jerry Atkinson'),
#  ('634787', 'Chris Rafael'),
#  ('657863', 'Kevin J. Foxx'),
#  ('123891', 'Jon E. Morris'),
#  ('158589', 'Darren Bornet'),
#  ('648867', 'Daquarion Hunter'),
#  ('562315', 'Ackeem Davis'),
#  ('556731', 'DaMarcia Clark'),
#  ('391919', 'Halee Marshall'),
#  ('438178', 'Waylon Dennington'),
#  ('223729', 'Marquise McPherson'),
#  ('647865', 'Harvey Maynard Burnette'),
#  ('480669', "Ja'Colby Brown"),
#  ('571859', 'Dejuan Jones'),
#  ('562141', 'David Morse'),
#  ('689518', 'Briana Roberson'),
#  ('287031', 'Chavar Gilliam'),
#  ('703493', 'Alexis Davis'),
#  ('484307', 'Carlos Rodriguez-Espinoza'),
#  ('154721', 'Antell Garnett'),
#  ('481220', 'Markell Kelly'),
#  ('611309', 'Louis Byrd III'),
#  ('275986', 'Alex DoSouto'),
#  ('491162', 'Devin Spann'),
#  ('680890', 'Tahj Harris'),
#  ('719623', 'Shannon Heath Bell'),
#  ('490793', 'Rashaad Payne'),
#  ('623632', 'Susan Toothman'),
#  ('744182', 'Randy Iler'),
#  ('259825', 'Patrick Spitler'),
#  ('272016', 'Ladarius Berry'),
#  ('623581', 'Brandon Colbert'),
#  ('491698', 'Dasmine Mitchell'),
#  ('596980', 'Sherrell McNeill'),
#  ('629789', 'Rodney Anderson'),
#  ('617976', 'Abigail Creamer'),
#  ('150299', 'Nakiel Jackson'),
#  ('352628', 'SirTerry L. Stevenson'),
#  ('138282', 'Veronika Weiss'),
#  ('491937', 'Taylor McCormick'),
#  ('384748', 'Charlie Martin'),
#  ('448653', 'Sylvia Duffy'),
#  ('464665', 'Thomas Johnson'),
#  ('680697', 'Lia Urena'),
#  ('483467', 'Romell L. Jones'),
#  ('300530', 'Walesha Williams'),
#  ('760472', 'Quintavious Barber'),
#  ('656192', 'Tarel Dontay Felder'),
#  ('546244', 'Roderick L. Nelms'),
#  ('610584', 'Mondale Goens'),
#  ('495506', 'Christopher Campbell'),
#  ('754656', 'Au’mircle Mcelwee'),
#  ('445489', 'Jeremy McGeowan'),
#  ('486586', 'Chris Watts'),
#  ('591475', 'Marcus Boyd'),
#  ('325445', 'Tyree Green'),
#  ('740447', 'Kristen Wiggins'),
#  ('537687', 'Dionte Robinson'),
#  ('490793', 'Joshua Childs'),
#  ('486611', 'Robert “Chuckie” Fields'),
#  ('127413', 'Jamanta White'),
#  ('403669', 'Oliver Legaspi'),
#  ('657151', 'Elishama Pierre'),
#  ('461476', 'Jonathan Austin'),
#  ('674300', 'Matthew Rodgers'),
#  ('727171', 'Trevor Bernardoni'),
#  ('689518', 'Tracy Brown'),
#  ('619714', 'Jamarie London'),
#  ('624273', 'Jessica Nelson'),
#  ('713466', 'Officer'),
#  ('479293', 'Ovell Jones'),
#  ('352628', 'Dominque Marchbanks'),
#  ('587995', 'Damien Tesfai'),
#  ('325166', 'Marqueas T. Hasty'),
#  ('549052', 'James Bryant'),
#  ('156125', 'Ricky Hudson'),
#  ('491992', 'Meghan Kerrigan'),
#  ('724139', 'Emarjae Watkins'),
#  ('351196', 'Isaac Kingue-Noah'),
#  ('710732', 'Dequan M. Barnett'),
#  ('601399', 'Rachel Hinson'),
#  ('314000', 'Corey Graham'),
#  ('492366', 'Albert Dickerson'),
#  ('369014', 'Treveon Wilson'),
#  ('751561', 'Michael Dale'),
#  ('348979', 'Leah Rogers'),
#  ('571859', 'Deashaun Turrentine'),
#  ('674740', 'Hakim Ali'),
#  ('620738', 'Donovan Wade Puckett'),
#  ('663624', 'Myrick Malone Dodd'),
#  ('448419', 'Nathan Kamp'),
#  ('405666', 'Josiah Taylor'),
#  ('757158', 'Maria Paredes-Paz'),
#  ('273773', 'Ryan Welch'),
#  ('685713', 'Catrina Butler'),
#  ('517520', 'Lana Rae Meisner'),
#  ('479757', 'Delonta Hendrix'),
#  ('591958', 'Tyreque China Slaughter'),
#  ('577792', 'Codie Powell'),
#  ('566171', 'Khalil Abdullah Lavon Burt'),
#  ('620217', 'Melvin Brady'),
#  ('625624', 'Jesse Romero'),
#  ('287521', 'Pamela Gillilan'),
#  ('490922', 'Inna Xiomara Gonzalez'),
#  ('138370', 'German Booker'),
#  ('369014', 'Shontae Armstrong'),
#  ('638105', 'Dominique Coleman'),
#  ('741751', 'Seve Volpone'),
#  ('703565', 'Knijah Amore Bibb'),
#  ('635289', 'Trooper'),
#  ('692483', 'Ashton Crowther'),
#  ('412487', 'William James'),
#  ('638232', 'Deonta Ramon Mullins'),
#  ('495566', 'Cody James Sharlow'),
#  ('672988', 'Nathan Buccos'),
#  ('368727', 'Malerie Britton'),
#  ('121629', 'Joshua Lee Nun'),
#  ('727030', 'Jawon Braswell'),
#  ('403084', 'Dannielle Rangel'),
#  ('172724', 'Karl Hills'),
#  ('203933', 'Sania Cunningham'),
#  ('480981', 'Romello Dewain Steward'),
#  ('457037', 'Jamond Heyward'),
#  ('401051', 'Kingsley Smith'),
#  ('490963', 'Aaron Wayne Brown'),
#  ('480747', 'Danielle Ross'),
#  ('468968', 'Shane Simpson'),
#  ('681075', 'Daniel Gehling'),
#  ('412557', 'Cario Davis'),
#  ('326792', 'Kysha D. Edmond-Gray'),
#  ('287529', 'Rebecca Spossey'),
#  ('224855', 'Kenya Evans'),
#  ('736277', 'Daniel McNulty'),
#  ('263376', 'Derrick Collie'),
#  ('695460', 'Jona Rosson'),
#  ('485885', 'Darren Burton'),
#  ('174544', 'Lacy McIntire'),
#  ('317165', 'Rakim Watson'),
#  ('677451', 'Jada Rankin'),
#  ('663026', 'Tyson Lucas'),
#  ('616008', 'Denise Gayle'),
#  ('190615', 'Hayden Mayes'),
#  ('740447', 'Dennie Reeves'),
#  ('438651', 'Elward Williams'),
#  ('714108', 'Alan Blanchard'),
#  ('513613', 'Gavin Pittman'),
#  ('585035', 'Jonathan Wayne Scott'),
#  ('678245', 'Keagan Schweikle'),
#  ('734408', 'Hunter Richardson'),
#  ('525329', 'Senquez Jackson'),
#  ('156245', 'Delshawn Lowery'),
#  ('444458', 'David Sanders'),
#  ('525223', 'Anthony Pereira'),
#  ('325001', 'Malik Thomas'),
#  ('490395', 'Chauncey Laray Mitchell'),
#  ('754899', 'Leroy Brown'),
#  ('491162', 'Gerald Robinson'),
#  ('675783', 'Amanda Paladino'),
#  ('327455', 'Kim Karns'),
#  ('484333', 'Ceasar Valdovinos'),
#  ('483872', 'Matthew Dennis Wilson'),
#  ('597176', 'David Whitman Davis'),
#  ('551053', 'Tedarrian Deshawn Tipton'),
#  ('695963', 'Jesse Dobbs'),
#  ('503983', 'Jeremiah Cormier'),
#  ('441681', 'Trayvon Deshay Lundy'),
#  ('566168', 'Deonta Bennett'),
#  ('333592', 'Izabella Votta'),
#  ('479573', 'Mary'),
#  ('699340', 'Patrick Dixon'),
#  ('700182', 'James Metts'),
#  ('479613', 'Tavares Antwan Mack'),
#  ('124146', 'Maurice Boatman'),
#  ('547639', 'Nathaniel Webb'),
#  ('701837', 'Andria Richardson'),
#  ('399503', 'Dale Cochran'),
#  ('700363', 'Maryanna Pennington'),
#  ('640955', 'Jonathan Gamez'),
#  ('751177', 'Isaac Stinemitz'),
#  ('601037', 'Paxton Shannon'),
#  ('523212', 'Tony McLaughlin'),
#  ('531149', 'Traveon Marquess Paulk'),
#  ('621109', 'Thomas Guitierrez'),
#  ('154721', 'Lawrence Jones'),
#  ('370187', 'Demagio Callahan'),
#  ('653077', 'Earnest McKnight'),
#  ('700232', 'Juan Carlos Fernandez'),
#  ('546022', 'Roosevelt Burns'),
#  ('578238', 'Montez Brown'),
#  ('390774', 'Delushun Greene'),
#  ('311535', 'Brandon Jividen'),
#  ('188332', 'Demetria Childers'),
#  ('454747', 'Adam D. Bays'),
#  ('146565', 'Cristobal Guerroro'),
#  ('451495', 'Shawn "Shooter" Ruffin'),
#  ('611125', 'Jason Griffin'),
#  ('527429', 'Bobby'),
#  ('546999', 'Alysee Defee'),
#  ('487435', 'Demetris Harris'),
#  ('491937', 'Ronald Smith'),
#  ('541987', 'Lavon Shinn'),
#  ('753058', 'Justin Anderson'),
#  ('482018', 'Tegan White'),
#  ('686312', 'Keith Gibson'),
#  ('481029', 'Boua Xiong'),
#  ('413001', 'Nathaniel Kendrick'),
#  ('448419', 'Cindy Johnson'),
#  ('739459', 'Fidel Rodriguez Canchola'),
#  ('570142', 'Manuel Watson'),
#  ('471331', 'Haylee Parker'),
#  ('481213', 'Shane Thomas Moore'),
#  ('494215', 'Luis Alejandro Torres-Sanchez'),
#  ('494155', 'Randy Ethridge'),
#  ('751561', 'Kelsey Nicole Brady'),
#  ('333750', 'Sergio Valencia del Toro'),
#  ('615133', 'Antonio Mason'),
#  ('713056', 'Matthew Kimmie'),
#  ('724900', 'Melanie Johnson'),
#  ('361708', 'Kwame El-Amin'),
#  ('489185', 'Quan Jackson'),
#  ('296215', 'Lydia Farina'),
#  ('608168', 'James Robert Dowty'),
#  ('488833', 'Donyae Jones'),
#  ('422064', 'Anthony Jackson'),
#  ('178149', 'Darin Booker'),
#  ('695239', 'Cashaan “Dink” Williams'),
#  ('685713', 'William Butler'),
#  ('742846', 'Benwah Wilson'),
#  ('618188', 'Carmello Ibarguen'),
#  ('625564', 'Avery Contreras'),
#  ('187928', 'Thomas Elberling'),
#  ('727304', 'Payton J. Beck-Glessner'),
#  ('681384', 'Jabree Hines'),
#  ('688429', 'Ryan Davis'),
#  ('492872', 'Adolphus Riggs III'),
#  ('263769', 'Brila'),
#  ('711597', 'Ben Allison'),
#  ('703542', 'Sean Antwan Clayborne'),
#  ('322898', 'Breana Gaskell'),
#  ('401051', 'Tandra Williams'),
#  ('741322', 'Roland Von Whitaker'),
#  ('738041', 'Jaquan Jabree Durrell'),
#  ('402674', 'Joseph Horn'),
#  ('583854', 'Devon Quinn'),
#  ('497253', 'Raymundo Fuentes'),
#  ('491698', 'Tasmia Allen'),
#  ('603807', 'Christopher Scurry Jr'),
#  ('483788', 'Joseph Brown'),
#  ('370100', 'Prudencio Juan Fragos-Ramirez'),
#  ('649889', 'Francisco Cortina'),
#  ('495800', 'Aiden Michael McClendon'),
#  ('689020', 'Todd James Webb Jr.'),
#  ('585821', 'Gerald M. Berkey'),
#  ('365153', 'Duane Clarkson Sylvester'),
#  ('481029', 'Naocha Xiong'),
#  ('282186', 'Mike Chiapperini'),
#  ('605475', 'Edward Long'),
#  ('489129', 'Rashawn R. Dukes'),
#  ('526648', 'Arieana Pettaway'),
#  ('108145', 'Hank Bradley Bollen'),
#  ('723643', 'Jeffery Webb'),
#  ('491037', 'Mark Armstrong'),
#  ('693184', 'Damien Scott Finch'),
#  ('743743', 'Lawan Elliott'),
#  ('574339', 'Marc Andrews Jr'),
#  ('749453', 'Dominique Alexander'),
#  ('462496', 'Christopher Garcia'),
#  ('671717', 'Ivan Jimenez'),
#  ('603469', 'Carolyn Wright'),
#  ('587523', 'Christy Sheats'),
#  ('707153', 'William Ronald Pulliam'),
#  ('388816', 'Willie J. Wilkinson Jr'),
#  ('680697', 'Anfernee Olivo'),
#  ('139703', 'Adrian Rojo'),
#  ('735269', 'April Masias'),
#  ('491001', 'Shane Landrum'),
#  ('390774', 'Candace Jackson'),
#  ('563091', 'Melina Haze Torres'),
#  ('742169', 'Kelvin Sylvester Couser'),
#  ('480669', 'Jamel Kawon Quinney'),
#  ('480765', 'Dejuan Gladney'),
#  ('480669', 'Antonio Keshawn Raglin'),
#  ('639510', 'Brian Lebron-Rivera'),
#  ('548431', 'Roney Wilson Jr'),
#  ('488677', 'Daniel K. Julian'),
#  ('734023', 'Jessica Marie Thompson'),
#  ('653500', 'Jacob Pommerehn'),
#  ('325166', 'Damian J.B. Mitchell'),
#  ('634819', 'Robert Lee Brown'),
#  ('488992', 'Angel Valerio'),
#  ('699070', 'Caden Randolph'),
#  ('732588', 'Nikobra Stringer'),
#  ('452362', 'Adrian Isaac Williams'),
#  ('633436', 'Dontay Gordon'),
#  ('653500', 'Anthony Rios'),
#  ('190599', 'Dorothy Tialino'),
#  ('669118', 'Kaleb Davis'),
#  ('408204', 'Layton Cochran'),
#  ('632020', 'Torrey Craft'),
#  ('491001', 'Marquel Dean'),
#  ('105596', 'James Frazier'),
#  ('488970', 'Oeun Sak'),
#  ('565640', 'Christopher Mullins'),
#  ('435144', 'Cameron Selmon'),
#  ('346097', 'Mishari A. Halbrook'),
#  ('738953', 'Shamoya McKenzie'),
#  ('524675', 'Nefi Reyes'),
#  ('623083', 'Megan Jaronski'),
#  ('481229', 'Joshua Hurst'),
#  ('752880', 'Destiny Nelson'),
#  ('573656', 'Kymici Brown'),
#  ('698315', 'Justin Malone'),
#  ('701439', 'Artist Thomas, Junior'),
#  ('510918', 'Dustin Edward Griffin'),
#  ('145667', 'William Pagan'),
#  ('154844', 'Walter Barnes'),
#  ('641871', 'Nhi Nguyen'),
#  ('619891', 'Mason Powell'),
#  ('339805', 'Caden Nicole McCullum'),
#  ('699534', 'David Burns'),
#  ('364715', 'Sofia Chiddo'),
#  ('694280', 'Kwanze Fluker'),
#  ('158387', 'Frank Jackson'),
#  ('733176', 'Dominique Nicole Privette'),
#  ('652642', 'Consuela Arrington'),
#  ('756010', 'Brandon Smithson'),
#  ('570135', 'Murjan Issack Abdi'),
#  ('490793', 'Christopher Singleton'),
#  ('508510', 'Roy Stephens'),
#  ('678438', 'Timothy Agnew'),
#  ('512073', 'Donna Reed'),
#  ('714426', 'Pedro Calvillo'),
#  ('730223', 'Kevonta Williams'),
#  ('344798', 'Deborah Christner'),
#  ('427621', 'Colin Brough'),
#  ('663624', 'Earnest Dean Dodd'),
#  ('541987', 'Wendell Edwards Jr'),
#  ('144565', 'James Danshay Edwards'),
#  ('734794', 'Angel De La Cruz'),
#  ('419826', 'David Talamantes'),
#  ('752672', 'Rebekah Weeks'),
#  ('348209', 'Mekiyah Davis'),
#  ('661322', 'Diego Gomez-Martinez'),
#  ('712796', 'Mario Pulido'),
#  ('707587', 'Neafor Randozzo'),
#  ('710472', 'Terrance Goins'),
#  ('712620', 'Johnny McCarthy, III'),
#  ('219303', 'David Wilson'),
#  ('734157', 'Steven Freeman'),
#  ('595877', 'Jonathan Ivan Padilla-Lopez'),
#  ('692931', 'Juan Romero-Sanchez'),
#  ('659663', 'Chadney Allen'),
#  ('376267', 'Aryah Leigh Lipford'),
#  ('531556', 'Ebony Harmon'),
#  ('328779', 'Melissa Ball'),
#  ('525301', 'Roderick Jones'),
#  ('757017', 'Jalin Palmer'),
#  ('647814', 'Miles Heizer'),
#  ('727759', 'Elijah Jackson'),
#  ('681768', 'Jael Valencia'),
#  ('683045', "D'kai Vanlandingham"),
#  ('736941', 'Khalileel Wilkins'),
#  ('167649', 'Sherita Dickens'),
#  ('669945', 'Larry Charles Carter, IV'),
#  ('470023', 'Luis Palacios-Romero'),
#  ('422064', 'Antian Hardmon'),
#  ('647657', 'Taivon Reed'),
#  ('590627', 'Jemmelle Raymond'),
#  ('699605', 'Kadejah Williams'),
#  ('134052', 'Veondus Dennis'),
#  ('403669', 'Felicidad Legaspi'),
#  ('493842', 'Willie Young'),
#  ('355267', 'Jennifer Dorsey'),
#  ('646808', 'Michael Adams Jr'),
#  ('491473', 'Alejandro Lorenzo Hernandez'),
#  ('628178', 'Kenyata Williams'),
#  ('590958', 'Oliver Kennedy'),
#  ('493591', 'Lesean Rozumialski'),
#  ('647374', 'Hanayah Woods'),
#  ('741322', 'Rahsaan Smith'),
#  ('222932', 'Jeaninne LePage'),
#  ('572696', 'Christopher Moran Jr'),
#  ('156813', 'Ismael Moreno Jr.'),
#  ('748066', 'Curtis Paige III'),
#  ('692315', 'Marcus Milien'),
#  ('643909', 'Blake Shurling'),
#  ('573967', 'Darrell Reid'),
#  ('687174', 'Calem Copeland'),
#  ('529105', 'Marquez Jones'),
#  ('385824', 'Spencer Stewart'),
#  ('626316', 'Abdullahi Omar Sheikh'),
#  ('687768', 'Malik Rashad Crawford'),
#  ('545114', 'Colby Fouch'),
#  ('293829', 'David Paulson'),
#  ('669945', 'Emarion Williams'),
#  ('603472', 'Jacob Lara'),
#  ('387334', 'Darnel Mundy'),
#  ('404238', 'Lena Rose'),
#  ('401091', 'Isaiah Charles Neiderhiser'),
#  ('647865', 'Terrell Dwayne Bradburn'),
#  ('338580', 'Jatarius Tolbert'),
#  ('401031', 'Hunter Harbin'),
#  ('111416', 'Matt Anderson'),
#  ('493863', 'Abraham Ntiamoah'),
#  ('584824', 'Sergey Makarenko'),
#  ('590464', 'Axel Kenneth Loera'),
#  ('655517', 'John Keith Lusk'),
#  ('702305', 'James Tate'),
#  ('710933', 'Ishmael D. Brown'),
#  ('205726', 'Betty Mclean'),
#  ('704076', 'Josephine Roby-Skinner'),
#  ('406848', 'Eurel Wilford'),
#  ('682143', 'Dan Caron'),
#  ('321156', 'Carl Johnson'),
#  ('702958', 'Abigail Buckley'),
#  ('314044', 'Kearria Freed'),
#  ('460386', 'Kachelle Roby'),
#  ('470512', 'Marcus Seichter'),
#  ('717231', 'Fabriccio Patti'),
#  ('703245', 'Latonia Hunt'),
#  ('333576', 'Dwayne Curtis'),
#  ('758373', 'Valentino Ray McBride'),
#  ('180813', 'Charles Vacca'),
#  ('289146', 'William Gonzalez'),
#  ('572696', 'Christopher Moran'),
#  ('567788', 'Pierre Devlin'),
#  ('486434', 'Devin Anderson'),
#  ('716346', 'Patricia Pendleton'),
#  ('223284', 'Jeremiah Ross'),
#  ('282561', 'Min Huang'),
#  ('112056', 'Chazz Jenkins'),
#  ('707911', 'Michael Hill'),
#  ('483589', 'Georta Mack'),
#  ('525329', 'Dennis Warren'),
#  ('276536', 'Ishmael Bryant'),
#  ('688979', 'Antonyo Demarlo-Jennings'),
#  ('674971', 'Jeremiah Lovelle Banks'),
#  ('525767', 'John Henry Burnsworth III'),
#  ('586625', 'Kadijah Adkinson'),
#  ('662638', 'Davonte Bobo'),
#  ('708392', 'Anthony Holder'),
#  ('376920', 'Julian Roary Jr.'),
#  ('644622', 'Paul Rederer'),
#  ('479613', 'David Washington'),
#  ('491292', 'Jerry Teel'),
#  ('595996', 'Zanyrah Taylor'),
#  ('533658', "Ja'Terreon Thorne"),
#  ('495347', 'Tiarra Ashonda Grant'),
#  ('599033', 'Samathy Mahan'),
#  ('607153', 'Logan Anderson'),
#  ('273298', 'AnnaRae Ponce'),
#  ('491749', 'Aron Turner'),
#  ('715238', 'Tyran Collins'),
#  ('692025', 'Natasha Stewart'),
#  ('350952', 'Daniel Prasinos'),
#  ('749769', 'Alejandro Ramirez'),
#  ('575607', 'Aaron Martinez'),
#  ('492393', 'Lee Marvin Harris Jr'),
#  ('489061', 'Ladarrel Bradley'),
#  ('476661', 'Brett Hartman'),
#  ('525705', 'Myles David Penix'),
#  ('681768', 'Melani Valencia'),
#  ('325445', 'Michael Rakeem Spencer'),
#  ('226600', 'Jaden Rahm'),
#  ('492151', 'Deshaun Jones'),
#  ('412557', 'Chris Ardrey'),
#  ('709370', 'Michael L. Carter'),
#  ('744473', 'Egardo “Coco” Perez'),
#  ('713125', 'Leny Cervantes'),
#  ('555126', 'Riogberto Jose'),
#  ('589488', 'Edmundo Amaro-Bajonero'),
#  ('515506', 'Robert Shaw'),
#  ('707976', 'Andrew T. Semuskie'),
#  ('484317', 'Kem Delaney'),
#  ('652857', 'Larriana Hughes'),
#  ('468787', 'Jermaine Lee'),
#  ('490954', 'Pamela Moore'),
#  ('553803', 'Tyrone Coley'),
#  ('665815', 'Quinten Brown'),
#  ('737290', 'Spenson Bennett Jr.'),
#  ('481254', 'Chelcher'),
#  ('469723', 'Kadeem Williams'),
#  ('742995', 'Jonathan Leonel Aviles'),
#  ('222792', 'Tyris Ferguson'),
#  ('486027', 'Felicia Jones'),
#  ('681023', 'Leonard Moses'),
#  ('583421', 'Cordarius Deandre Stinner'),
#  ('591218', 'Ryan Rodriguez'),
#  ('560782', 'Armani Mungin'),
#  ('476661', 'Skylar Monroe Hartman'),
#  ('733811', 'Adbikadir Mohammed'),
#  ('652863', 'Jhakwan Williams'),
#  ('539890', 'Constance Heintz'),
#  ('470044', 'Dronald Washington'),
#  ('150299', 'Devon McNeal'),
#  ('742995', 'Diego Martinez'),
#  ('369014', 'Tramarceia Ruffins'),
#  ('706835', 'Thomas Devore'),
#  ('338034', 'Robert Warren'),
#  ('324424', 'Driss Diaeddinn'),
#  ('206959', 'Angel Hooper'),
#  ('481198', 'Margaret White-Tuff'),
#  ('325618', 'Armoni Sexton'),
#  ('593242', 'Lernard Bonner'),
#  ('578238', 'Anthony Shannon'),
#  ('484287', 'Malcolm Williams'),
#  ('491546', 'Marcus Lyman'),
#  ('546022', 'Shelly Williams'),
#  ('276459', 'Manuel O’Neal'),
#  ('700272', 'Stephen Kasperzyk'),
#  ('726822', 'Paul Gianni'),
#  ('606167', 'Milous Keith II'),
#  ('525119', 'Destiny Bargman'),
#  ('525767', 'Kristopher Lewis'),
#  ('425402', 'Zackery James Alexander'),
#  ('590123', 'Frank Woodford'),
#  ('713219', 'Samir Price'),
#  ('109599', 'Kennedra Miles'),
#  ('494033', 'Braveon Terry'),
#  ('757845', 'Victor Rangel Orozco'),
#  ('555126', 'Osiel Benitez'),
#  ('405133', 'Aaron “Fifty” Blankenship'),
#  ('745112', 'Calvin Powers'),
#  ('104218', 'Markeyo Carr'),
#  ('563086', 'Eric Moore'),
#  ('715101', 'Troy Smothers'),
#  ('383331', 'Cruisito Leiba'),
#  ('589470', 'Michael Thomas'),
#  ('747183', 'Ericka Bellamy Joseph'),
#  ('475827', 'Aaron Harcum'),
#  ('132455', 'Chad Olm'),
#  ('641499', 'Dakota Schriefer'),
#  ('174725', 'Marcus Allen Garrett'),
#  ('485821', 'Daryl Rehm'),
#  ('749453', 'Leonard Temple'),
#  ('734198', 'Darius Owens'),
#  ('724096', 'Ryan Perrizo'),
#  ('541557', 'Richard Phillip Spradling'),
#  ('486611', 'Standrekas “Stan” Woods'),
#  ('752278', 'Khamoi Petersen'),
#  ('734198', 'Portia Ashley'),
#  ('571859', 'Devonne Burton'),
#  ('668497', 'Frank Olson'),
#  ('685713', 'Katelyn Butler'),
#  ('492366', 'Adrian Bennett'),
#  ('468787', 'Tawaig Perpall'),
#  ('399503', 'Ty Conly'),
#  ('188332', 'Thomas May'),
#  ('353536', 'Alonzo Scott'),
#  ('169326', 'Martavis Cooper'),
#  ('700411', 'Dejaun Clay'),
#  ('485811', 'Nolan Ralston'),
#  ('331663', 'Rasheem Scriven'),
#  ('546022', 'Rheva Mae Dent'),
#  ('291784', 'Alexis Mercer'),
#  ('563751', 'Kayla Blakley'),
#  ('563751', 'Michael Shaw'),
#  ('571835', 'Kyree Greene'),
#  ('357590', 'Donald Walters'),
#  ('367750', 'Lashawn Stephenson'),
#  ('717712', 'Xyahir Davis'),
#  ('679466', 'Jamy Patterson'),
#  ('400091', 'Zachary McGee'),
#  ('224131', 'Kevie Durham'),
#  ('492393', 'Derrikes Lamonte McRae'),
#  ('602810', 'Joseph Chappell'),
#  ('719608', 'Dominic Johnson'),
#  ('447584', 'Marlin Banks Jr'),
#  ('700468', 'Philip Battles'),
#  ('163930', 'Keyona McKinney'),
#  ('693401', 'Cleavon Oneal Dantzler'),
#  ('350182', 'Judith Pitts'),
#  ('295961', 'Adonis Forbes'),
#  ('163930', 'Equavious Breshon Osby'),
#  ('585265', 'Don Demetrius Brown, Jr.'),
#  ('201648', 'Alvaro Casillas Becerra'),
#  ('341465', 'Brian Echols'),
#  ('580414', 'Rufino Perez Villa'),
#  ('444458', 'Dontae Shields'),
#  ('481198', 'Derek Lamar Rushing'),
#  ('654087', 'Demario Laquan Burnett'),
#  ('226018', 'Jose Hernandez Benitez'),
#  ('567262', 'Alexandria Francis'),
#  ('694358', 'George R. Turrentine'),
#  ('696667', 'Zachary Cory'),
#  ('481900', 'Raymon Blount'),
#  ('551053', 'Saqer Saeed Alzahrani'),
#  ('412487', 'Imani Williams'),
#  ('714840', 'Augustine Rivera'),
#  ('727759', 'Nateyah Yafah Hines'),
#  ('734779', 'Julius Gray'),
#  ('647865', 'Jordan Tyree Bondhill'),
#  ('522401', 'Christoper Kelley'),
#  ('742826', 'Charles Ulery'),
#  ('386699', 'Elijah Walker'),
#  ('669552', 'Joel Patayo'),
#  ('638105', 'Troyvonte Hurt'),
#  ('603253', 'Gavin Stiles'),
#  ('591958', 'Joseph Contreras'),
#  ('752947', 'Elisabeth Faye Cannon'),
#  ('481029', 'Meng Lee'),
#  ('169024', 'Aubrey Amos'),
#  ('757158', 'Carlos Antonio Garcia-Cerna'),
#  ('321156', 'Jordan Clayton'),
#  ('719608', 'David Grunwald'),
#  ('680841', 'Demetrioun L. Boaz'),
#  ('479709', 'Da’Vaughn Pitts'),
#  ('486153', 'Kenneth Barnett'),
#  ('123891', 'Caleb N. Boozer'),
#  ('755306', 'Davaughn Jackson'),
#  ('589488', 'Bonifacio Oseguera-Gonzalez'),
#  ('739466', 'Taylor Nelson'),
#  ('486142', 'Aaron T. Cross'),
#  ('564869', 'Matthew Hughes'),
#  ('647865', 'Rahmel Lawrence Williams'),
#  ('668279', 'Dangelo Neal'),
#  ('709686', 'Darian Lee Freeman'),
#  ('573759', 'Jaylene Bermeo'),
#  ('512875', 'Nicholas Matthews'),
#  ('488426', 'Rene Segundo Soto'),
#  ('437323', 'Logan Orth'),
#  ('741460', 'Wayne Edmund Flues'),
#  ('689465', 'Joseph Rodriguez'),
#  ('757845', 'James Garcia'),
#  ('611809', 'Payton Esterline'),
#  ('429695', 'Brian Banks'),
#  ('638232', 'Chrishun Smith'),
#  ('270733', 'Bill Thao'),
#  ('492546', 'Wyatt Whitaker'),
#  ('547639', 'Javious Chatman'),
#  ('393418', 'Malcolm Antonio Lumpkin'),
#  ('488505', 'Darren Lamont Roberts'),
#  ('113665', 'Jamell Webb'),
#  ('583907', 'Jett Osburn'),
#  ('560782', 'Betty Mungin'),
#  ('529105', 'Tyricco Simmons'),
#  ('704796', 'Gregory Bernard Chalmers Jr'),
#  ('739459', 'Regina Hernandez'),
#  ('480700', 'Jaheem Watson'),
#  ('752249', 'Santos Navares'),
#  ('625735', 'Juan Carlos Saenz-Ponce'),
#  ('665115', 'Iyontai Tovarise Walker'),
#  ('471867', 'David K. Jones'),
#  ('692118', 'Officer'),
#  ('496634', 'Mark Womack'),
#  ('723429', 'Aaron Valle'),
#  ('561321', 'Dominic Tra’Juan Castro'),
#  ('748479', 'Lucero Badillo Castillo'),
#  ('720484', 'Logan Clark'),
#  ('473661', 'Bradley Shines'),
#  ('296215', 'Larry Guzman'),
#  ('585035', 'Mustafa Bearfield Jr.'),
#  ('579762', 'Timothy Boyd'),
#  ('589470', 'Keshawn Brown'),
#  ('638622', 'Jayden Norton'),
#  ('159569', 'Delaney R. Singleton'),
#  ('719841', 'Elijah Jones'),
#  ('587523', 'Taylor Sheats'),
#  ('652360', 'Trevon Coleman'),
#  ('733995', 'Dontaris Thomas'),
#  ('709141', 'Conor Wing'),
#  ('631695', 'Cade Hartwig'),
#  ('491265', 'Merly S. Niebles'),
#  ('614922', 'Marquez Reed'),
#  ('295919', 'Kaylee Reyes'),
#  ('664531', 'Ireshia Parks'),
#  ('634238', 'Heshimu Barker'),
#  ('733492', 'Heather King'),
#  ('512073', 'David Wayne Campbell'),
#  ('586159', 'Eric Wright'),
#  ('417963', 'Erin Coffey'),
#  ('163930', 'Quanderia Bentley'),
#  ('721818', 'Scott Brooks'),
#  ('561245', 'Jada Jolivette'),
#  ('425119', 'Benjamin Nicolas Tiller'),
#  ('650025', 'Marqui Williams'),
#  ('686335', 'Michael Gilbert'),
#  ('492366', 'Nijia Ward'),
#  ('682645', 'Fabian Russell'),
#  ('724498', 'Kai Smith'),
#  ('441681', 'Anthony Ray'),
#  ('273766', 'Warren Everette Thomas'),
#  ('606624', 'Darrell Peden'),
#  ('721895', 'William Cooley'),
#  ('736729', 'Michael Harmon'),
#  ('658736', 'Tymon Reed'),
#  ('426809', 'Luke Burns'),
#  ('657246', 'Malik Ethridge'),
#  ('652759', 'Nina Green'),
#  ('397214', 'Divine Vaniah Chambliss'),
#  ('459880', 'JaQuavious Landers'),
#  ('619156', 'Christopher Rodriguez'),
#  ('405133', 'D’Mio “Duck” Ingram'),
#  ('625724', 'Officer Lee Coel'),
#  ('580998', 'Darryl Ferguson'),
#  ('746529', 'Ivy Love'),
#  ('601119', 'London Truman-Arnold'),
#  ('707735', 'Amanda M. Wetli'),
#  ('675289', 'Vaughn Lester Draper'),
#  ('446569', 'Zion Willis'),
#  ('487645', 'Daquez Palmer'),
#  ('652642', 'Trinity Hairston'),
#  ('349456', 'Demetrius Lmar McDonald'),
#  ('708392', 'Winston Trotman'),
#  ('128871', 'Eric Whitaker'),
#  ('591184', 'Kavan Collins'),
#  ('480981', 'Billy Charles Carey'),
#  ('590958', 'Alac Jackson'),
#  ('501256', 'Isiah Major III'),
#  ('481229', 'Laquintin Carter'),
#  ('748479', 'Rodolfo Barcenas Badillo, Jr.'),
#  ('628635', 'Karen Mech'),
#  ('379440', 'Dillon Vogt'),
#  ('222932', 'Nadia Harriman'),
#  ('732281', 'Jade "Bubba" Jones'),
#  ('496634', 'Jamieon Chatman'),
#  ('602299', 'Derrick Vaughn'),
#  ('486142', 'Samuel Earl Sallee'),
#  ('351936', 'Stephanie Almedina Rivera'),
#  ('551053', 'Dynasty Freeman'),
#  ('287529', 'Douglas Spossey'),
#  ('713004', 'Thomas R. Carlson'),
#  ('393341', 'Tracy Davis'),
#  ('592629', 'Mario Garza'),
#  ('646203', 'Javante Stockard'),
#  ('399564', 'Mere Contreras'),
#  ('225903', 'Marcus M. Gay'),
#  ('510769', 'Mercedes McMillan'),
#  ('651957', 'Jacob Derr'),
#  ('404238', 'James Millhorn'),
#  ('739042', 'Marquita Hill'),
#  ('460386', 'Destacia Straughn'),
#  ('704621', 'William Daniel Glosson'),
#  ('692025', 'Darius Gulley'),
#  ('435144', 'Christopher Gatewood'),
#  ('485821', 'Ariana Brown'),
#  ('452362', 'Daqjan Gilliard'),
#  ('745236', "Kevonte O'Neal Washington"),
#  ('541987', 'Christopher Miller'),
#  ('457037', 'Brandy Council'),
#  ('699605', 'Quadrae Breyon Johnson'),
#  ('710885', 'Linda Hutton'),
#  ('672988', 'Christopher Lee Buccos'),
#  ('275907', 'Nicholas Cardillo'),
#  ('143951', 'Braxton Bourda'),
#  ('461105', 'Julian Sims'),
#  ('360780', 'Destin Burks'),
#  ('490351', 'Wilfred Lee Donalson'),
#  ('736485', 'Arvis Brown'),
#  ('724088', 'Oliver Portieles'),
#  ('724566', 'Ibn Perry'),
#  ('472078', 'Luke Andrew Bowman'),
#  ('486027', 'Elias Sanders'),
#  ('598192', 'Officer Randall Hancock'),
#  ('715024', 'Jacob Remaley'),
#  ('752249', 'Gaudalupe Cervantes'),
#  ('386699', 'Curry D. Bryson'),
#  ('486998', 'Ryan Taybron'),
#  ('272869', 'Jaxon Slaight'),
#  ('190599', 'Randi Popalii'),
#  ('752278', 'Tyrik Charles Solomon'),
#  ('328779', 'Grayden Lee Whitmore'),
#  ('634269', 'Breanna Nicole Fluitt'),
#  ('481029', 'Tong Lee'),
#  ('601352', 'James Moore'),
#  ('333750', 'Jonathan Stoffel'),
#  ('704906', 'Luke Smith'),
#  ('494155', 'Charlie Dean Dake Jr.'),
#  ('628791', 'Montell Ross'),
#  ('349211', 'Kester "Tony" Browne III'),
#  ('734402', 'Sarah Bonner'),
#  ('680203', 'Mekel Antwon Crumbly'),
#  ('399564', 'Candace Holloway'),
#  ('719128', 'Ian Mascarenas'),
#  ('601032', 'Austin Gordon'),
#  ('484287', 'Steven Reynolds'),
#  ('666232', 'Deontae Jones'),
#  ('713125', 'Jamie Cervantes'),
#  ('741714', 'Robert Sterling'),
#  ('112415', 'Wanda Renee Anderson'),
#  ('153275', 'Kieara Green'),
#  ('634819', 'Justin Kaleb Reed'),
#  ('209478', 'John Hambaugh II'),
#  ('304897', 'Marcus Johnson Jr.'),
#  ('691205', 'Jared Mothershed'),
#  ('479734', 'Raashon Jackson'),
#  ('154721', 'Joshua Kyner'),
#  ('652919', 'Ava Schowalter'),
#  ('689159', 'Edwin Bryant'),
#  ('663838', 'Fredis Albaybro-Rodriguez'),
#  ('732260', 'Dominic Carlos Pedro'),
#  ('546022', 'Lizzy Williams'),
#  ('496030', 'Sergio Canales-Vasquez'),
#  ('610584', 'Kalif Goens'),
#  ('107403', 'Peter Andrade'),
#  ('598192', 'Stephen Paul Beck'),
#  ('680444', 'Marco Antonio Ruiz'),
#  ('583067', 'Seth Johnson'),
#  ('640203', 'Anthony Johnson'),
#  ('402113', 'Kortney Blake'),
#  ('663624', 'Richaad Deon Dodd'),
#  ('295502', 'Michael Strickland'),
#  ('588918', 'Jorge Hernandez'),
#  ('364715', 'Nilda Sheffield'),
#  ('741536', 'Tillie Turner'),
#  ('95313', 'Thomas Elliott Hjelmeland'),
#  ('703381', 'Jennifer Renee Dickerson'),
#  ('490917', 'Daemoan Patterson'),
#  ('290626', 'Justin Huckeby'),
#  ('723429', 'Elijah Montas'),
#  ('484317', 'Kiana Welch'),
#  ('757017', 'Nicholas Butler'),
#  ('563091', 'Daniel W. Roberts'),
#  ('652937', 'Jahday Twisdale'),
#  ('413001', 'Benetria Robinson'),
#  ('677083', 'Sunny Ravi Patel'),
#  ('122136', 'Jordan Harris'),
#  ('519487', 'James Davis'),
#  ('603424', 'Robert Michael Reaves'),
#  ('421014', 'Demarcus Laquan Norman'),
#  ('143723', 'Ariel Morgan'),
#  ('339805', 'Cylie Nicole McCullum'),
#  ('486434', 'Ahmad Antoine'),
#  ('646995', 'Wakeel Stewart'),
#  ('702958', 'Lance Buckley'),
#  ('670812', 'Lawrence E. Barr'),
#  ('622440', 'Malik McIntee'),
#  ('712796', 'Frailian Garza'),
#  ('427621', 'Steven Jones'),
#  ('693642', 'Thomas LaVon Peterson Jr'),
#  ('593981', 'Antiqouns Beatty'),
#  ('518368', 'Shawndell Partin'),
#  ('721430', 'Nicholas Helget'),
#  ('655512', 'Mariah Loredo'),
#  ('481029', 'Pao Vue'),
#  ('382413', 'Elijah Jackson'),
#  ('566863', 'James Casullo'),
#  ('702004', 'Jovaris Jose Lundy'),
#  ('665127', 'Lee Lao'),
#  ('682959', 'Morris Charpentier'),
#  ('693186', 'Antonio Rucker, Jr.'),
#  ('551295', 'Peter Noack'),
#  ('724118', 'Sherry Grainger'),
#  ('356090', 'Marques Green'),
#  ('152600', 'David Otoniel Charar Yac'),
#  ('597531', 'John Lee Hennington'),
#  ('597603', 'Mario Cervantes-Angel'),
#  ('618297', 'Jordan Gray'),
#  ('646139', 'Kevin Anthony Jackson'),
#  ('668071', 'Leroy Carrizales'),
#  ('694642', "De'angelique McRath"),
#  ('111416', 'Brady Osborne'),
#  ('538028', 'Jesse Alan Flemister'),
#  ('739413', 'Charlotte Zaremba'),
#  ('455595', 'Howard Reno'),
#  ('743103', 'Ian Sevostjanov'),
#  ('668407', 'Qumari Spencer'),
#  ('692195', 'Alfonza Campbell Jr.'),
#  ('493893', 'Amanda Depasquale'),
#  ('583421', 'KeMiyah Jimison'),
#  ('751367', 'Samuel Reed'),
#  ('581611', 'Sandtrece Latoya Raliff'),
#  ('485821', 'Barry Barney'),
#  ('399864', 'Roderick Salas'),
#  ('709370', 'William D. McKee'),
#  ('667979', 'Shane Francisco'),
#  ('595877', 'Fortunato Nato Villagrana'),
#  ('216737', 'Arlis Gordon'),
#  ('714426', 'Anthony Rivas'),
#  ('726937', 'Timothy James Rivera'),
#  ('608614', 'Kathrine Baucom Cowick'),
#  ('710885', 'Teagan Hutton'),
#  ('657396', 'Ryan Mayhew'),
#  ('479734', 'David Anderson'),
#  ('694280', 'Ariana Wilson'),
#  ('308156', 'Brodie Williams'),
#  ('352628', 'Sulif Wilkins'),
#  ('171425', 'Brenda Moore Rucker'),
#  ('377189', 'Latay Devon Darden'),
#  ('687375', 'Andrew Nance'),
#  ('698629', 'Audrianna Stone'),
#  ('541987', 'Ricky Harrison'),
#  ('752051', 'Michael Barr'),
#  ('509897', 'Alex Arthur Buckner'),
#  ('754619', 'Robert Durrum'),
#  ('439873', 'Vitaliy Velkin'),
#  ('700363', 'Deandre M. Jackson'),
#  ('587995', 'Elijah Morgan'),
#  ('686371', 'Jermone Green'),
#  ('676686', 'Marcello Brown'),
#  ('98836', 'Akbar Muhammad'),
#  ('282186', 'Joseph Hofsetter'),
#  ('406848', 'Antwone J. Price'),
#  ('369014', 'Gerod T. Ward'),
#  ('588867', 'Fernando Wingfield'),
#  ('722219', 'Sean Thomas'),
#  ('412718', 'Gabryon Walker'),
#  ('697349', 'Michael Walls'),
#  ('715024', 'Dana Remaley'),
#  ('720656', 'Destiny McNichols'),
#  ('413001', "Laquan Ria'Mel Barrow"),
#  ('723830', 'Chief Deputy John Campbell'),
#  ('701837', 'Ryan Gilliken'),
#  ('149598', 'Jakairion Spikes'),
#  ('168307', 'Kenneth Harrison'),
#  ('754403', 'Brennon Davis'),
#  ('598977', 'Ryan William Eakin'),
#  ('488547', 'Lakim Anthony Faust'),
#  ('444458', 'Jonte Johnson'),
#  ('399564', 'Damon B. Oswald-Newman'),
#  ('483765', 'Alonzo D. Ruff'),
#  ('138282', 'Christopher Martinez'),
#  ('686312', 'Destiny Olinger'),
#  ('486611', 'Codarrell Lee Yates'),
#  ('628599', 'Breyon Rooks'),
#  ('735955', 'Deion Dewayne Jones'),
#  ('455601', 'Walter Everett Charwood'),
#  ('477398', 'Kaylieb Gaston'),
#  ('310586', 'Damian Walsh'),
#  ('457037', 'Jarrett Myers'),
#  ('687174', 'Brandon Phillips'),
#  ...}

# %% [markdown]
# # Full names stats

# %%
d=defaultdict(int)
for incident, participant in total_participants:
    d[participant]+=1
print(sorted(d.items(), key=operator.itemgetter(1)))
# Out:
# [('Zackery James Alexander', 1), ('Roman Kellough', 1), ('Deondre Kinney', 1), ('Houston Grant', 1), ('Devon Quinn', 1), ('Derrick Jackson', 1), ('Chris Mackey', 1), ('Donald Ethan Lawlis', 1), ('Fabriccio Patti', 1), ('Steven Dolan', 1), ('Dewaun Rockingham', 1), ('Lesly Paredes', 1), ('Daniel Lusk', 1), ('Kenneth Moore', 1), ('Lontrell Brantley', 1), ('Rick Foster', 1), ('Hubert Allen Jr.', 1), ('Sherie Lash, a.k.a. Sherie Rhoades', 1), ('Darmequaye Cohill', 1), ('Christopher Rutledge', 1), ('Ginger Reeves', 1), ('Romell L. Jones', 1), ('Frederick Seymore Jr.', 1), ('Jason Jonathan Acosta-Ramos', 1), ('Makayla Smith', 1), ('Taiquan Moss', 1), ('Jacoreian Jennings', 1), ('Brandon Cunningham', 1), ('Leyton McNabb', 1), ('Christopher Miller', 1), ('Darnae Christon', 1), ('Mario Cervantes-Angel', 1), ('Curtis Leon Williams', 1), ('Santos Navares', 1), ('Trevor Bernardoni', 1), ('Kenza Benzakour', 1), ('Kajmere Burton', 1), ('Jayquon Johnson', 1), ('Benjamin Bond', 1), ('Martavis Cooper', 1), ('Jesse Romero', 1), ('Sandtrece Latoya Raliff', 1), ('Jamil Bolden', 1), ('Deputy Ricky Scott', 1), ('Payton Esterline', 1), ('Deion Robair', 1), ('James E. Lonaker', 1), ('Anthony Reyes', 1), ('Gary Shelton', 1), ('Melky Rodriguez', 1), ('Timothy Harewood', 1), ('Elwin Coste', 1), ('Dexter Beard', 1), ('Maleah Ellis', 1), ('Brett Hartman', 1), ('Courtney Hatch', 1), ('Eugene Roberts', 1), ('Jason Kimble', 1), ('Kadijah Adkinson', 1), ('Deandrew Lee Jennings Walker-Webster II', 1), ('Thomas Meisenheimer', 1), ('Marco N. Bobo', 1), ('Jaden Rahm', 1), ('Kody Lott', 1), ('Jason Farmer', 1), ('Salvador Lopez Aguilera', 1), ('Jaquelle Dinkins', 1), ('Antonio Rhines', 1), ('Sarah Bonner', 1), ('Benetria Robinson', 1), ('Lydell McLaurin', 1), ('Jaimill Kenney', 1), ('Norman Simmons Jr.', 1), ('William Ronald Pulliam', 1), ('Anthony D. Holley', 1), ('Jen Knarr', 1), ('Tillie Turner', 1), ('Adolphus Riggs III', 1), ('Officer Randall Hancock', 1), ('Robert “Little Rob” Williams', 1), ('Demontray Mackey', 1), ('Oscar Willoughby Jr.', 1), ('Anthony Pereira', 1), ('Donal Pugh', 1), ('Roger Dale Phillips III', 1), ('Luis Alejandro Torres-Sanchez', 1), ("Del'Vonte Jenkins", 1), ('Vashon Dukes', 1), ('Christopher Lee Buccos', 1), ('Danvinist Blunt', 1), ('Kyle Alexander Miller', 1), ('Juan Becerra', 1), ('Ariel Ratliff', 1), ('Jesus Angel Estrada', 1), ('John Smith', 1), ('Richie Millien', 1), ('Johan Holder', 1), ('Keatron Walls', 1), ('Jacob Hambaugh', 1), ('Kadin Tige Mann', 1), ('Sean Strickland', 1), ('Rockella Moore', 1), ('Antoine Dewayne Sutphen Jr.', 1), ('Sergio Valencia del Toro', 1), ('Zecary Banks', 1), ('Chris', 1), ('Jalisa Love', 1), ('Paul G. Kendall', 1), ('Rasheem Scriven', 1), ('Xeryus Tate', 1), ('Sheldon Cleavon Salter', 1), ('Jacob Derr', 1), ('Lonell Echols', 1), ('Tyrell Lamont Smith', 1), ('JaPaul Williams', 1), ('Tristen Odell Bennett', 1), ('Nolan Ralston', 1), ('Mekiyah Davis', 1), ('Michael Smith', 1), ('Thy Ho', 1), ('Anthony Vankirk II', 1), ('Eric Whitaker', 1), ('unborn child', 1), ('Chanita Yancy', 1), ('Andrew Graeter', 1), ('Matthew Toothman', 1), ('Branon Vaughan', 1), ('Ishmael Haywood', 1), ('Joshua Van Winkle', 1), ('Sherri Downs-Tipton', 1), ('Rita Langworthy', 1), ('Zina Bowser', 1), ('Calvin Williams', 1), ('Clarence Gatewood', 1), ('Jahleel Potts', 1), ('Mario Desmond', 1), ('Jalen Jeffries', 1), ('Brandon Varlow', 1), ('Michael Dixon', 1), ('Selby Gene Outland', 1), ('Byron Turner', 1), ('Kevin Aguillard', 1), ('Demetrius Broadnax', 1), ('Jerrell Jackson', 1), ('Hector Garcia Jr.', 1), ('Will Kramer', 1), ('Sania Cunningham', 1), ('Brandon Colbert', 1), ('Tavares Antwan Mack', 1), ('Lewis Mabrey Jr.', 1), ('Kyle Berry', 1), ('Randi Popalii', 1), ('Joel Patayo', 1), ('Cory Cook II', 1), ('Ronquavis James Howard', 1), ('Carolyn Wright', 1), ('Brandon Fryer', 1), ('Kishawn Jackson', 1), ('Ben Allison', 1), ('Au’mircle Mcelwee', 1), ('Chuck Eagan', 1), ('Davante Robertson', 1), ('George Daniel Wechsler', 1), ('Jack ...

# %% [markdown]
# ### Distribution

# %%
freq = Counter([value for value in d.values()])
freq
# Out:
# Counter({1: 3817, 2: 24, 3: 2, 9: 1})

# %% [markdown]
# ### MOA

# %%
num_forms=len(d.items())
num_form_instances=len(total_participants)
estimated_moa_full=num_form_instances/num_forms
print(estimated_moa_full)
# Out:
# 1.0093652445369408

# %% [markdown]
# # Tokens stats

# %% [markdown]
# ### Distribution

# %%
freq_token = Counter([value for value in alltokens.values()])
freq_token
# Out:
# Counter({1: 2567,
#          2: 675,
#          3: 360,
#          4: 150,
#          5: 97,
#          6: 77,
#          7: 42,
#          8: 37,
#          9: 29,
#          10: 18,
#          11: 18,
#          12: 14,
#          13: 11,
#          14: 13,
#          15: 5,
#          16: 7,
#          17: 3,
#          18: 5,
#          19: 6,
#          20: 4,
#          21: 8,
#          23: 4,
#          24: 3,
#          26: 5,
#          27: 1,
#          28: 3,
#          29: 1,
#          30: 1,
#          31: 2,
#          32: 1,
#          34: 1,
#          36: 2,
#          40: 2,
#          47: 1,
#          48: 1,
#          50: 1,
#          52: 1,
#          54: 1,
#          55: 2,
#          57: 1,
#          58: 1,
#          59: 1,
#          63: 1,
#          68: 1,
#          70: 1,
#          71: 1,
#          85: 1,
#          94: 1})

# %% [markdown]
# ### MOA

# %%
len(alltokens)
# Out:
# 4188

# %%
s=0
for k,v in alltokens.items():
    s+=v
estimated_moa_tokens=s/len(alltokens)
print(estimated_moa_tokens)
# Out:
# 2.5515759312320916

# %% [markdown]
# # Expansion against existing EL corpora

# %%
result=utils.check_overlap(d.keys()) # are full entity names found
result
# Out:
# {('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Bobby',
#   'http://en.wikipedia.org/wiki/Bobby_Charlton\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Carlos Delgado',
#   'http://en.wikipedia.org/wiki/Carlos_Delgado\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'David Wilson',
#   'http://en.wikipedia.org/wiki/Dave_Wilson_(rugby_union)\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Frank Thomas',
#   'http://en.wikipedia.org/wiki/Frank_Thomas_(baseball,_born_1968)\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Juan Gonzalez',
#   'http://en.wikipedia.org/wiki/Juan_González_(baseball)\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Kim', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Michael Johnson',
#   'http://en.wikipedia.org/wiki/Michael_Johnson_(athlete)\n'),
#  ('el_corpora/neel2014-test.tsv',
#   'Chris',
#   'http://dbpedia.org/resource/Chris_Griffin\n'),
#  ('el_corpora/neel2014-test.tsv',
#   'Princeton',
#   'http://dbpedia.org/resource/Princeton_University\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Steve Smith',
#   'http://dbpedia.org/resource/Steve_Smith_(wide_receiver,_born_1985)\n'),
#  ('el_corpora/neel2014.tsv',
#   'Chris',
#   'http://dbpedia.org/resource/Chris_Griffin\n'),
#  ('el_corpora/neel2014.tsv',
#   'Princeton',
#   'http://dbpedia.org/resource/Princeton_University\n'),
#  ('el_corpora/neel2014.tsv',
#   'Steve Smith',
#   'http://dbpedia.org/resource/Steve_Smith_(wide_receiver,_born_1985)\n'),
#  ('el_corpora/neel2015-dev.tsv',
#   'Joe',
#   'http://dbpedia.org/resource/Joe_Spencer_(Hollyoaks)\n'),
#  ('el_corpora/neel2015-test.tsv', 'Chris', 'NIL247\n'),
#  ('el_corpora/neel2015-test.tsv', 'Joe', 'NIL443\n'),
#  ('el_corpora/neel2015-test.tsv', 'Kim', 'NIL490\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Chris',
#   'http://dbpedia.org/resource/Chris_Griffin\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Princeton',
#   'http://dbpedia.org/resource/Princeton_University\n'),
#  ('el_corpora/neel2015.tsv', 'Chris', 'NIL247\n'),
#  ('el_corpora/neel2015.tsv',
#   'Chris',
#   'http://dbpedia.org/resource/Chris_Griffin\n'),
#  ('el_corpora/neel2015.tsv', 'Joe', 'NIL443\n'),
#  ('el_corpora/neel2015.tsv',
#   'Joe',
#   'http://dbpedia.org/resource/Joe_Spencer_(Hollyoaks)\n'),
#  ('el_corpora/neel2015.tsv', 'Kim', 'NIL490\n'),
#  ('el_corpora/neel2015.tsv',
#   'Princeton',
#   'http://dbpedia.org/resource/Princeton_University\n'),
#  ('el_corpora/oke-testset.tsv',
#   'Michael Smith',
#   'http://dbpedia.org/resource/Michael_Smith_(chemist)\n'),
#  ('el_corpora/oke.tsv',
#   'Michael Smith',
#   'http://dbpedia.org/resource/Michael_Smith_(chemist)\n'),
#  ('el_corpora/rss500-unicode.tsv',
#   'Kim',
#   'http://aksw.org/notInWiki/Kim_Seung-youn\n'),
#  ('el_corpora/rss500-unicode.tsv', 'Mary', 'http://aksw.org/notInWiki/Mary\n'),
#  ('el_corpora/rss500-unicode.tsv',
#   'Steve Smith',
#   'http://aksw.org/notInWiki/Steve_Smith_(wide_receiver,_born_1979)\n'),
#  ('el_corpora/rss500.tsv',
#   'Kim',
#   'http://aksw.org/notInWiki/Kim_Seung-youn\n'),
#  ('el_corpora/rss500.tsv', 'Mary', 'http://aksw.org/notInWiki/Mary\n'),
#  ('el_corpora/rss500.tsv',
#   'Steve Smith',
#   'http://aksw.org/notInWiki/Steve_Smith_(wide_receiver,_born_1979)\n'),
#  ('el_corpora/wes2015.tsv',
#   'Princeton',
#   'http://dbpedia.org/resource/Princeton,_New_Jersey\n'),
#  ('el_corpora/wes2015.tsv',
#   'Princeton',
#   'http://dbpedia.org/resource/Princeton_University\n'),
#  ('el_corpora/wikinews.tsv',
#   'John Smith',
#   'http://dbpedia.org/resource/John_F._Smith,_Jr.\n')}

# %%
result2=utils.check_overlap(alltokens.keys()) # are full entity names found
result2
# Out:
# {('el_corpora/neel2014.tsv',
#   'Paige',
#   'http://dbpedia.org/resource/Paige_(band)\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Henry',
#   'http://en.wikipedia.org/wiki/Thierry_Henry\n'),
#  ('el_corpora/rss500-unicode.tsv',
#   'John',
#   'http://dbpedia.org/resource/John_Calipari\n'),
#  ('el_corpora/wes2015.tsv',
#   'Cornell',
#   'http://dbpedia.org/resource/Cornell_University\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Simmons',
#   'http://en.wikipedia.org/wiki/Phil_Simmons\n'),
#  ('el_corpora/neel2015-test.tsv', 'Maria', 'NIL545\n'),
#  ('el_corpora/neel2014.tsv', 'Jesus', 'http://dbpedia.org/resource/Jesus\n'),
#  ('el_corpora/neel2014.tsv',
#   'Joey',
#   'http://dbpedia.org/resource/Joey_Tribbiani\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Dayton',
#   'http://en.wikipedia.org/wiki/Dayton_Agreement\n'),
#  ('el_corpora/wes2015.tsv',
#   'Elizabeth',
#   'http://dbpedia.org/resource/Elizabeth_Montagu\n'),
#  ('el_corpora/neel2015.tsv',
#   'Watford',
#   'http://dbpedia.org/resource/Watford\n'),
#  ('el_corpora/wes2015.tsv',
#   'English',
#   'http://dbpedia.org/resource/Britishness\n'),
#  ('el_corpora/wes2015.tsv',
#   'Margaret',
#   'http://dbpedia.org/resource/Margaret,_Maid_of_Norway\n'),
#  ('el_corpora/wes2015.tsv', 'Ray', 'http://dbpedia.org/resource/Man_Ray\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Lorenzo',
#   'http://dbpedia.org/resource/San_Lorenzo,_California\n'),
#  ('el_corpora/neel2015-test.tsv',
#   'Dallas',
#   'http://dbpedia.org/resource/Dallas\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Devers',
#   'http://en.wikipedia.org/wiki/Gail_Devers\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Kenya',
#   'http://en.wikipedia.org/wiki/Kenya\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Brooks',
#   'http://dbpedia.org/resource/Rebekah_Brooks\n'),
#  ('el_corpora/neel2014.tsv',
#   'English',
#   'http://dbpedia.org/resource/English_language\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Roman',
#   'http://en.wikipedia.org/wiki/Rome\n'),
#  ('el_corpora/neel2015-test.tsv',
#   'Rudolph',
#   'http://dbpedia.org/resource/Rudolph_the_Red-Nosed_Reindeer\n'),
#  ('el_corpora/neel2015.tsv', 'Jacobs', 'NIL149\n'),
#  ('el_corpora/neel2015.tsv', 'Michael', 'NIL571\n'),
#  ('el_corpora/rss500-unicode.tsv',
#   'Brooklyn',
#   'http://dbpedia.org/resource/Brooklyn\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'York',
#   'http://en.wikipedia.org/wiki/York_City_F.C.\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Edgar', 'NIL\n'),
#  ('el_corpora/neel2014-test.tsv',
#   'Lloyd',
#   'http://dbpedia.org/resource/Carli_Lloyd\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Chad', 'NIL\n'),
#  ('el_corpora/neel2014.tsv', 'Summer', 'http://dbpedia.org/resource/Summer\n'),
#  ('el_corpora/wes2015.tsv',
#   'English',
#   'http://dbpedia.org/resource/England\n'),
#  ('el_corpora/neel2015.tsv',
#   'Williams',
#   'http://dbpedia.org/resource/Williams_Grand_Prix_Engineering\n'),
#  ('el_corpora/neel2014.tsv',
#   'Hamilton',
#   'http://dbpedia.org/resource/Lewis_Hamilton\n'),
#  ('el_corpora/neel2014.tsv',
#   'Lorenzo',
#   'http://dbpedia.org/resource/San_Lorenzo,_California\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Brooke',
#   'http://en.wikipedia.org/wiki/Zinzan_Brooke\n'),
#  ('el_corpora/neel2015.tsv', 'Steve', 'NIL732\n'),
#  ('el_corpora/neel2015-test.tsv', 'Emma', 'NIL316\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Holland',
#   'http://dbpedia.org/resource/Fran%C3%A7ois_Hollande\n'),
#  ('el_corpora/rss500-unicode.tsv',
#   'Chelsea',
#   'http://dbpedia.org/resource/Chelsea_F.C.\n'),
#  ('el_corpora/neel2015.tsv',
#   'Mata',
#   'http://dbpedia.org/resource/Juan_Mata\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'China',
#   'http://dbpedia.org/resource/China\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Lane',
#   'http://dbpedia.org/resource/Jani_Lane\n'),
#  ('el_corpora/neel2015.tsv', 'Bob', 'NIL71\n'),
#  ('el_corpora/rss500.tsv',
#   'Chelsea',
#   'http://dbpedia.org/resource/Chelsea_F.C.\n'),
#  ('el_corpora/neel2015.tsv',
#   'Harris',
#   'http://dbpedia.org/resource/Richard_Harris\n'),
#  ('el_corpora/wes2015.tsv',
#   'Brittany',
#   'http://dbpedia.org/resource/Brittany\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Jackson',
#   'http://en.wikipedia.org/wiki/Darren_Jackson\n'),
#  ('el_corpora/wes2015.tsv',
#   'Louis',
#   'http://dbpedia.org/resource/Louisville,_Kentucky\n'),
#  ('el_corpora/wes2015.tsv',
#   'Rutherford',
#   'http://dbpedia.org/resource/Ernest_Rutherford\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Dallas',
#   'http://dbpedia.org/resource/Dallas\n'),
#  ('el_corpora/neel2015.tsv',
#   'Watson',
#   'http://dbpedia.org/resource/Tom_Watson_(golfer)\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Noah',
#   'http://dbpedia.org/resource/Noah\n'),
#  ('el_corpora/neel2014.tsv',
#   'Wayne',
#   'http://dbpedia.org/resource/Lil_Wayne\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Frederick', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Ross',
#   'http://en.wikipedia.org/wiki/Dennis_Ross\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Walsh',
#   'http://en.wikipedia.org/wiki/Courtney_Walsh\n'),
#  ('el_corpora/wikinews.tsv',
#   'Henderson',
#   'http://dbpedia.org/resource/Frederick_Henderson\n'),
#  ('el_corpora/rss500.tsv', 'Foote', 'http://aksw.org/notInWiki/Harry_Foote\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Durham',
#   'http://en.wikipedia.org/wiki/Durham_County_Cricket_Club\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Wayne',
#   'http://dbpedia.org/resource/Lil_Wayne\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Harper',
#   'http://en.wikipedia.org/wiki/Laurie_Harper\n'),
#  ('el_corpora/rss500-unicode.tsv',
#   'Milton',
#   'http://dbpedia.org/resource/Milton,_Massachusetts\n'),
#  ('el_corpora/wes2015.tsv',
#   'Alexandria',
#   'http://dbpedia.org/resource/Alexandria\n'),
#  ('el_corpora/wes2015.tsv',
#   'Briggs',
#   'http://dbpedia.org/resource/Henry_Briggs_(mathematician)\n'),
#  ('el_corpora/neel2015-train.tsv', 'Campbell', 'NIL81\n'),
#  ('el_corpora/oke.tsv', 'Mario', 'NIL\n'),
#  ('el_corpora/wes2015.tsv',
#   'English',
#   'http://dbpedia.org/resource/English_people\n'),
#  ('el_corpora/neel2015.tsv', 'Hannah', 'NIL285\n'),
#  ('el_corpora/wes2015.tsv', 'German', 'http://dbpedia.org/resource/Germany\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Preston', 'NIL\n'),
#  ('el_corpora/neel2015-test.tsv', 'Alex', 'NIL140\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'London',
#   'http://en.wikipedia.org/wiki/London\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Will',
#   'http://dbpedia.org/resource/Will_Sheehey\n'),
#  ('el_corpora/neel2015.tsv', 'Bob', 'NIL206\n'),
#  ('el_corpora/rss500-unicode.tsv',
#   'Jones',
#   'http://dbpedia.org/resource/Thomas_David_Jones\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Roberts',
#   'http://en.wikipedia.org/wiki/Julia_Roberts\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Martinez',
#   'http://en.wikipedia.org/wiki/Pedro_Martínez\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Albert',
#   'http://en.wikipedia.org/wiki/Albert_II,_Prince_of_Monaco\n'),
#  ('el_corpora/neel2014.tsv',
#   'Mark',
#   'http://dbpedia.org/resource/Death_of_Mark_Duggan\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Brady',
#   'http://en.wikipedia.org/wiki/Sarah_Brady\n'),
#  ('el_corpora/neel2015.tsv',
#   'Harry',
#   'http://dbpedia.org/resource/Harry_Potter_(character)\n'),
#  ('el_corpora/wes2015.tsv',
#   'Charlotte',
#   'http://dbpedia.org/resource/Charlotte,_North_Carolina\n'),
#  ('el_corpora/neel2015-test.tsv', 'Jake', 'NIL408\n'),
#  ('el_corpora/neel2015.tsv', 'Dallas', 'http://dbpedia.org/resource/Dallas\n'),
#  ('el_corpora/neel2014.tsv',
#   'Henderson',
#   'http://dbpedia.org/resource/Jordan_Henderson\n'),
#  ('el_corpora/neel2015-test.tsv',
#   'Hancock',
#   'http://dbpedia.org/resource/Hancock,_Michigan\n'),
#  ('el_corpora/neel2015-test.tsv', 'Harry', 'NIL375\n'),
#  ('el_corpora/neel2015-train.tsv', 'Gary', 'NIL123\n'),
#  ('el_corpora/neel2015.tsv', 'Juan', 'NIL161\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Clarke',
#   'http://en.wikipedia.org/wiki/Kenneth_Clarke\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Sutton',
#   'http://en.wikipedia.org/wiki/Chris_Sutton\n'),
#  ('el_corpora/rss500.tsv', 'London', 'http://dbpedia.org/resource/London\n'),
#  ('el_corpora/neel2015.tsv',
#   'Paige',
#   'http://dbpedia.org/resource/Paige_(band)\n'),
#  ('el_corpora/wes2015.tsv',
#   'Nicholas',
#   'http://dbpedia.org/resource/Nicholas_Culpeper\n'),
#  ('el_corpora/neel2015.tsv', 'Dan', 'NIL268\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Trinidad',
#   'http://en.wikipedia.org/wiki/Trinidad\n'),
#  ('el_corpora/wes2015.tsv',
#   'Bell',
#   'http://dbpedia.org/resource/Alexander_Graham_Bell\n'),
#  ('el_corpora/wikinews.tsv', 'Ford', 'http://dbpedia.org/resource/Ford\n'),
#  ('el_corpora/neel2015.tsv',
#   'Ramos',
#   'http://dbpedia.org/resource/Humberto_Ramos\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Marshall', 'NIL\n'),
#  ('el_corpora/neel2014.tsv',
#   'Dunn',
#   'http://dbpedia.org/resource/Adam_Dunn\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Sanders',
#   'http://dbpedia.org/resource/Bernie_Sanders\n'),
#  ('el_corpora/neel2015-dev.tsv',
#   'Billie',
#   'http://dbpedia.org/resource/Billie_Piper\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Mark',
#   'http://dbpedia.org/resource/Death_of_Mark_Duggan\n'),
#  ('el_corpora/neel2015-test.tsv',
#   'Paris',
#   'http://dbpedia.org/resource/Paris\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Brown',
#   'http://dbpedia.org/resource/Cleveland_Browns\n'),
#  ('el_corpora/oke-trainingset.tsv',
#   'Roosevelt',
#   'http://dbpedia.org/resource/Franklin_D._Roosevelt\n'),
#  ('el_corpora/rss500-unicode.tsv',
#   'English',
#   'http://dbpedia.org/resource/England_cricket_team\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Roman',
#   'http://en.wikipedia.org/wiki/Roman_Empire\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Norman',
#   'http://en.wikipedia.org/wiki/Greg_Norman\n'),
#  ('el_corpora/neel2014-test.tsv',
#   'Houston',
#   'http://dbpedia.org/resource/Houston\n'),
#  ('el_corpora/neel2015-train.tsv', 'Alex', 'NIL58\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Thompson',
#   'http://en.wikipedia.org/wiki/Tommy_Thompson\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Lindsay',
#   'http://en.wikipedia.org/wiki/Lindsay_Davenport\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Matthew', 'NIL\n'),
#  ('el_corpora/neel2015.tsv', 'Paris', 'http://dbpedia.org/resource/Paris\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Washington',
#   'http://en.wikipedia.org/wiki/MaliVai_Washington\n'),
#  ('el_corpora/neel2015.tsv', 'Maria', 'NIL545\n'),
#  ('el_corpora/neel2015.tsv',
#   'Dayton',
#   'http://dbpedia.org/resource/Dayton,_Ohio\n'),
#  ('el_corpora/wes2015.tsv',
#   'Frederick',
#   'http://dbpedia.org/resource/Frederick_I,_Holy_Roman_Emperor\n'),
#  ('el_corpora/neel2014.tsv', 'Dallas', 'http://dbpedia.org/resource/Dallas\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Wall',
#   'http://en.wikipedia.org/wiki/Donne_Wall\n'),
#  ('el_corpora/neel2015.tsv', 'London', 'http://dbpedia.org/resource/London\n'),
#  ('el_corpora/wes2015.tsv', 'child', 'http://dbpedia.org/resource/Child\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Washington',
#   'http://dbpedia.org/resource/Washington,_D.C.\n'),
#  ('el_corpora/neel2015-dev.tsv',
#   'Winslow',
#   'http://dbpedia.org/resource/Winslow,_Buckinghamshire\n'),
#  ('el_corpora/neel2015.tsv', 'Kim', 'NIL490\n'),
#  ('el_corpora/neel2015-test.tsv',
#   'Hughes',
#   'http://dbpedia.org/resource/Phillip_Hughes\n'),
#  ('el_corpora/wes2015.tsv',
#   'Alfred',
#   'http://dbpedia.org/resource/Alfred_Adler\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Will',
#   'http://dbpedia.org/resource/Prince_William,_Duke_of_Cambridge\n'),
#  ('el_corpora/neel2015-dev.tsv',
#   'Connor',
#   'http://dbpedia.org/resource/Sarah_Connor_(singer)\n'),
#  ('el_corpora/neel2015-test.tsv', 'Cory', 'NIL259\n'),
#  ('el_corpora/neel2014-test.tsv',
#   'Chris',
#   'http://dbpedia.org/resource/Chris_Griffin\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Ball',
#   'http://en.wikipedia.org/wiki/Alan_Ball,_Jr.\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Guerrero',
#   'http://en.wikipedia.org/wiki/Guerrero\n'),
#  ('el_corpora/neel2014-test.tsv',
#   'Kenya',
#   'http://dbpedia.org/resource/Kenya\n'),
#  ('el_corpora/neel2015-test.tsv', 'Anthony', 'NIL167\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Sanders', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Washington',
#   'http://en.wikipedia.org/wiki/Washington_(U.S._state)\n'),
#  ('el_corpora/neel2014-test.tsv',
#   'Manning',
#   'http://dbpedia.org/resource/Peyton_Manning\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Chelsea',
#   'http://dbpedia.org/resource/Chelsea_F.C.\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Daniel',
#   'http://dbpedia.org/resource/Daniel_Radcliffe\n'),
#  ('el_corpora/neel2015.tsv', 'Lawrence', 'NIL169\n'),
#  ('el_corpora/rss500.tsv', 'Cain', 'http://aksw.org/notInWiki/Brandon_Cain\n'),
#  ('el_corpora/wes2015.tsv',
#   'Princeton',
#   'http://dbpedia.org/resource/Princeton_University\n'),
#  ('el_corpora/wes2015.tsv',
#   'General',
#   'http://dbpedia.org/resource/General_officer\n'),
#  ('el_corpora/neel2015-test.tsv', 'Sara', 'NIL697\n'),
#  ('el_corpora/wes2015.tsv',
#   'Fletcher',
#   'http://dbpedia.org/resource/Fletcher_(surname)\n'),
#  ('el_corpora/neel2015.tsv', 'Sam', 'NIL691\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Roosevelt', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Tan', 'NIL\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Cameron',
#   'http://dbpedia.org/resource/David_Cameron\n'),
#  ('el_corpora/neel2015.tsv',
#   'Chelsea',
#   'http://dbpedia.org/resource/Chelsea_F.C.\n'),
#  ('el_corpora/wes2015.tsv',
#   'Baily',
#   'http://dbpedia.org/resource/Francis_Baily\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'English',
#   'http://en.wikipedia.org/wiki/England\n'),
#  ('el_corpora/neel2015.tsv',
#   'Kenya',
#   'http://dbpedia.org/resource/Kenya_Under-19_cricket_team\n'),
#  ('el_corpora/wes2015.tsv',
#   'Mann',
#   'http://dbpedia.org/resource/Heinrich_Mann\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Chelsea',
#   'http://en.wikipedia.org/wiki/Chelsea_F.C.\n'),
#  ('el_corpora/neel2015.tsv', 'Steve', 'NIL183\n'),
#  ('el_corpora/neel2014.tsv', 'China', 'http://dbpedia.org/resource/China\n'),
#  ('el_corpora/neel2015.tsv',
#   'Enrique',
#   'http://dbpedia.org/resource/José_Enrique_(footballer)\n'),
#  ('el_corpora/neel2015.tsv',
#   'Ferguson',
#   'http://dbpedia.org/resource/Ferguson,_Missouri\n'),
#  ('el_corpora/neel2015-test.tsv', 'Alexis', 'NIL147\n'),
#  ('el_corpora/neel2015-dev.tsv', 'Tiffany', 'NIL10\n'),
#  ('el_corpora/neel2015-test.tsv', 'Tom', 'NIL767\n'),
#  ('el_corpora/neel2014.tsv',
#   'Smith',
#   'http://dbpedia.org/resource/Tom_Smith_(cricketer_born_1985)\n'),
#  ('el_corpora/neel2015.tsv',
#   'Jordan',
#   'http://dbpedia.org/resource/Air_Jordan\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Christian',
#   'http://en.wikipedia.org/wiki/Christian_theology\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Justin',
#   'http://dbpedia.org/resource/Justin_Bieber\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Woods',
#   'http://dbpedia.org/resource/Tiger_Woods\n'),
#  ('el_corpora/neel2015-test.tsv',
#   'English',
#   'http://dbpedia.org/resource/England\n'),
#  ('el_corpora/wes2015.tsv',
#   'Carl',
#   'http://dbpedia.org/resource/Charles_Darwin\n'),
#  ('el_corpora/neel2014.tsv',
#   'Washington',
#   'http://dbpedia.org/resource/Federal_government_of_the_United_States\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Charles',
#   'http://en.wikipedia.org/wiki/Charles,_Prince_of_Wales\n'),
#  ('el_corpora/rss500-unicode.tsv',
#   'Holloway',
#   'http://aksw.org/notInWiki/Corrie_Holloway\n'),
#  ('el_corpora/neel2015.tsv',
#   'John',
#   'http://dbpedia.org/resource/John_Boehner\n'),
#  ('el_corpora/rss500-unicode.tsv',
#   'Jenkins',
#   'http://aksw.org/notInWiki/Jenkins\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Karen',
#   'http://en.wikipedia.org/wiki/Karen_people\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Sheffield',
#   'http://dbpedia.org/resource/Sheffield\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Houston',
#   'http://en.wikipedia.org/wiki/Houston_Cougars_football\n'),
#  ('el_corpora/neel2014.tsv', 'London', 'http://dbpedia.org/resource/London\n'),
#  ('el_corpora/neel2015.tsv', 'Robbie', 'NIL230\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Trinidad', 'NIL\n'),
#  ('el_corpora/neel2015-test.tsv', 'Bob', 'NIL206\n'),
#  ('el_corpora/wes2015.tsv', 'China', 'http://dbpedia.org/resource/China\n'),
#  ('el_corpora/wikinews.tsv', 'China', 'http://dbpedia.org/resource/China\n'),
#  ('el_corpora/neel2015.tsv',
#   'Jason',
#   'http://dbpedia.org/resource/Jason_Robinson\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Ingram', 'NIL\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Duke',
#   'http://dbpedia.org/resource/Duke_Nukem_Forever\n'),
#  ('el_corpora/neel2015.tsv', 'Christian', 'NIL89\n'),
#  ('el_corpora/rss500.tsv',
#   'Holloway',
#   'http://aksw.org/notInWiki/Corrie_Holloway\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Max',
#   'http://en.wikipedia.org/wiki/Martin_Max\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Currie',
#   'http://en.wikipedia.org/wiki/Currie_RFC\n'),
#  ('el_corpora/neel2015-test.tsv', 'Nadia', 'NIL598\n'),
#  ('el_corpora/oke-testset.tsv',
#   'German',
#   'http://dbpedia.org/resource/Germans\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Collins',
#   'http://en.wikipedia.org/wiki/Michael_Collins_(Irish_leader)\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Howard',
#   'http://en.wikipedia.org/wiki/John_Howard\n'),
#  ('el_corpora/wes2015.tsv',
#   'Hutton',
#   'http://dbpedia.org/resource/James_Hutton\n'),
#  ('el_corpora/rss500-unicode.tsv',
#   'Yang',
#   'http://aksw.org/notInWiki/Yang_Mei-ling\n'),
#  ('el_corpora/neel2014.tsv',
#   'Houston',
#   'http://dbpedia.org/resource/Houston_Astros\n'),
#  ('el_corpora/neel2015-test.tsv',
#   'London',
#   'http://dbpedia.org/resource/London\n'),
#  ('el_corpora/wes2015.tsv',
#   'Simpson',
#   'http://dbpedia.org/resource/James_Young_Simpson\n'),
#  ('el_corpora/neel2014.tsv',
#   'Lily',
#   'http://dbpedia.org/resource/Order_of_the_Phoenix_(fiction)\n'),
#  ('el_corpora/neel2014-test.tsv',
#   'Dayton',
#   'http://dbpedia.org/resource/Dayton,_Ohio\n'),
#  ('el_corpora/neel2015-dev.tsv',
#   'Lambert',
#   'http://dbpedia.org/resource/Constant_Lambert\n'),
#  ('el_corpora/neel2015.tsv',
#   'Washington',
#   'http://dbpedia.org/resource/Federal_government_of_the_United_States\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Mohammed', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Norton',
#   'http://en.wikipedia.org/wiki/Gale_Norton\n'),
#  ('el_corpora/neel2015-dev.tsv',
#   'German',
#   'http://dbpedia.org/resource/Germans\n'),
#  ('el_corpora/neel2015.tsv', 'Jake', 'NIL408\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Fernandez', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Ivanov',
#   'http://en.wikipedia.org/wiki/Igor_Ivanov\n'),
#  ('el_corpora/neel2015.tsv',
#   'Howard',
#   'http://dbpedia.org/resource/Howard_Kendall\n'),
#  ('el_corpora/neel2015-test.tsv', 'Dave', 'NIL280\n'),
#  ('el_corpora/neel2014.tsv', 'Moon', 'http://dbpedia.org/resource/Moon\n'),
#  ('el_corpora/wes2015.tsv',
#   'Roland',
#   'http://dbpedia.org/resource/Roland_Corporation\n'),
#  ('el_corpora/wes2015.tsv',
#   'Wheeler',
#   'http://dbpedia.org/resource/John_Archibald_Wheeler\n'),
#  ('el_corpora/neel2014.tsv',
#   'Camden',
#   'http://dbpedia.org/resource/Camden,_New_Jersey\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Bernard',
#   'http://en.wikipedia.org/wiki/Bernard_Collomb\n'),
#  ('el_corpora/neel2014.tsv',
#   'Phoenix',
#   'http://dbpedia.org/resource/Phoenix_Park\n'),
#  ('el_corpora/neel2015-dev.tsv', 'Ben', 'NIL91\n'),
#  ('el_corpora/neel2015-test.tsv', 'Mark', 'NIL547\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Will',
#   'http://dbpedia.org/resource/Prince_William,_Duke_of_Cambridge\n'),
#  ('el_corpora/rss500-unicode.tsv',
#   'Gene',
#   'http://aksw.org/notInWiki/Gene_Griffiss\n'),
#  ('el_corpora/rss500.tsv', 'Clark', 'http://aksw.org/notInWiki/Rick_Clark\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Diana',
#   'http://en.wikipedia.org/wiki/Diana,_Princess_of_Wales\n'),
#  ('el_corpora/oke-testset.tsv', 'Michael', 'NIL\n'),
#  ('el_corpora/rss500-unicode.tsv',
#   'Cain',
#   'http://aksw.org/notInWiki/Brandon_Cain\n'),
#  ('el_corpora/rss500.tsv',
#   'Hernandez',
#   'http://dbpedia.org/resource/F%C3%A9lix_Hern%C3%A1ndez\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Valencia',
#   'http://en.wikipedia.org/wiki/Valencia,_Spain\n'),
#  ('el_corpora/neel2015-test.tsv',
#   'Mike',
#   'http://dbpedia.org/resource/Mike_Tyson\n'),
#  ('el_corpora/neel2015-test.tsv', 'Katie', 'NIL476\n'),
#  ('el_corpora/wes2015.tsv',
#   'Green',
#   'http://dbpedia.org/resource/Charles_Green_(balloonist)\n'),
#  ('el_corpora/neel2015-test.tsv',
#   'Hamilton',
#   'http://dbpedia.org/resource/Lewis_Hamilton\n'),
#  ('el_corpora/wes2015.tsv',
#   'Rutherford',
#   'http://dbpedia.org/resource/Daniel_Rutherford\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Hall',
#   'http://en.wikipedia.org/wiki/Tony_P._Hall\n'),
#  ('el_corpora/neel2015.tsv', 'Moon', 'http://dbpedia.org/resource/Moon\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Hinton',
#   'http://dbpedia.org/resource/Les_Hinton\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Allen', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Rosado',
#   'http://en.wikipedia.org/wiki/José_Rosado\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Mills', 'NIL\n'),
#  ('el_corpora/neel2014-test.tsv',
#   'Osborne',
#   'http://dbpedia.org/resource/George_Osborne\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Ferguson',
#   'http://dbpedia.org/resource/Alex_Ferguson\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Oscar',
#   'http://en.wikipedia.org/wiki/Academy_Award_for_Best_Actor\n'),
#  ('el_corpora/neel2015.tsv', 'Jeremy', 'NIL141\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Norris', 'NIL\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Brown',
#   'http://dbpedia.org/resource/Cleveland_Browns\n'),
#  ('el_corpora/neel2015.tsv', 'Ben', 'NIL91\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Lyman',
#   'http://en.wikipedia.org/wiki/Princeton_N._Lyman\n'),
#  ('el_corpora/neel2015.tsv', 'Jake', 'NIL15\n'),
#  ('el_corpora/oke.tsv',
#   'Rutherford',
#   'http://dbpedia.org/resource/Ernest_Rutherford\n'),
#  ('el_corpora/wes2015.tsv', 'Karl', 'http://dbpedia.org/resource/Karl_Marx\n'),
#  ('el_corpora/neel2014.tsv',
#   'Amy',
#   'http://dbpedia.org/resource/Amy_Winehouse\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Mitchell',
#   'http://en.wikipedia.org/wiki/Dennis_Mitchell\n'),
#  ('el_corpora/neel2015-dev.tsv',
#   'Justin',
#   'http://dbpedia.org/resource/Justin_Timberlake\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Amy',
#   'http://dbpedia.org/resource/Amy_Winehouse\n'),
#  ('el_corpora/neel2015-test.tsv', 'Dania', 'NIL270\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Woods',
#   'http://en.wikipedia.org/wiki/Tiger_Woods\n'),
#  ('el_corpora/wes2015.tsv',
#   'Maria',
#   'http://dbpedia.org/resource/Mary_the_Jewess\n'),
#  ('el_corpora/neel2015.tsv',
#   'Alan',
#   'http://dbpedia.org/resource/Alan_Carr\n'),
#  ('el_corpora/neel2014-test.tsv',
#   'China',
#   'http://dbpedia.org/resource/China\n'),
#  ('el_corpora/wes2015.tsv',
#   'Cook',
#   'http://dbpedia.org/resource/Cook_(surname)\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Silva', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'London',
#   'http://en.wikipedia.org/wiki/London_Wasps\n'),
#  ('el_corpora/wikinews.tsv', 'Paris', 'http://dbpedia.org/resource/Paris\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Fischer',
#   'http://en.wikipedia.org/wiki/Sven_Fischer\n'),
#  ('el_corpora/wes2015.tsv',
#   'Charles',
#   'http://dbpedia.org/resource/Charles_I_of_England\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Kenya',
#   'http://dbpedia.org/resource/Kenya\n'),
#  ('el_corpora/neel2015-dev.tsv', 'Angelo', 'NIL80\n'),
#  ('el_corpora/neel2015.tsv', 'Harry', 'NIL375\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Sheffield',
#   'http://en.wikipedia.org/wiki/Sheffield_Eagles\n'),
#  ('el_corpora/neel2015.tsv',
#   'Floyd',
#   'http://dbpedia.org/resource/Floyd_Patterson\n'),
#  ('el_corpora/neel2015-train.tsv', 'Jeremy', 'NIL141\n'),
#  ('el_corpora/neel2015.tsv',
#   'Brown',
#   'http://dbpedia.org/resource/Cleveland_Browns\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Harris',
#   'http://en.wikipedia.org/wiki/Chris_Harris_(cricketer)\n'),
#  ('el_corpora/wes2015.tsv',
#   'Hawkins',
#   'http://dbpedia.org/resource/Gerald_Hawkins\n'),
#  ('el_corpora/neel2015.tsv', 'Emma', 'NIL316\n'),
#  ('el_corpora/neel2015-test.tsv',
#   'Martinez',
#   'http://dbpedia.org/resource/A_Martinez\n'),
#  ('el_corpora/wes2015.tsv',
#   'Burroughs',
#   'http://dbpedia.org/resource/William_S._Burroughs\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'China',
#   'http://en.wikipedia.org/wiki/Qing_Dynasty\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Council', 'NIL\n'),
#  ('el_corpora/wes2015.tsv',
#   'Hardy',
#   'http://dbpedia.org/resource/Hardy_(surname)\n'),
#  ('el_corpora/neel2014.tsv',
#   'Watson',
#   'http://dbpedia.org/resource/Tom_Watson_(golfer)\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Jordan', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Atherton',
#   'http://en.wikipedia.org/wiki/Mike_Atherton\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Alan',
#   'http://dbpedia.org/resource/Alan_Carr\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'White',
#   'http://dbpedia.org/resource/Chicago_White_Sox\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Sanchez', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Houston',
#   'http://en.wikipedia.org/wiki/Houston_Astros\n'),
#  ('el_corpora/wes2015.tsv',
#   'Joseph',
#   'http://dbpedia.org/resource/Joseph_(son_of_Jacob)\n'),
#  ('el_corpora/neel2015-test.tsv', 'Ashley', 'NIL176\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Carlton',
#   'http://en.wikipedia.org/wiki/Carlton_Football_Club\n'),
#  ('el_corpora/neel2014.tsv', 'York', 'http://dbpedia.org/resource/York\n'),
#  ('el_corpora/oke-testset.tsv', 'Frank', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Berry',
#   'http://en.wikipedia.org/wiki/Sean_Berry\n'),
#  ('el_corpora/neel2015-dev.tsv',
#   'Angelina',
#   'http://dbpedia.org/resource/Angelina_Jolie\n'),
#  ('el_corpora/neel2015.tsv', 'James', 'NIL412\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Orlando',
#   'http://dbpedia.org/resource/Orlando,_Florida\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'York',
#   'http://dbpedia.org/resource/York\n'),
#  ('el_corpora/neel2014-train.tsv',
#   '22',
#   'http://dbpedia.org/resource/22_(number)\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Hendrix',
#   'http://en.wikipedia.org/wiki/Jimi_Hendrix\n'),
#  ('el_corpora/neel2015-test.tsv', 'Michael', 'NIL571\n'),
#  ('el_corpora/rss500.tsv', 'China', 'http://dbpedia.org/resource/China\n'),
#  ('el_corpora/neel2014-test.tsv',
#   'Justin',
#   'http://dbpedia.org/resource/Justin_Bieber\n'),
#  ('el_corpora/neel2015-test.tsv', 'Lia', 'NIL511\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Jasper', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Alvarado', 'NIL\n'),
#  ('el_corpora/rss500-unicode.tsv',
#   'Lawrence',
#   'http://aksw.org/notInWiki/Lawrence_Vikings_football\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Jones', 'NIL\n'),
#  ('el_corpora/neel2015-test.tsv', 'Cary', 'NIL232\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Washington',
#   'http://dbpedia.org/resource/Federal_government_of_the_United_States\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Hill', 'NIL\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Hinton',
#   'http://dbpedia.org/resource/Les_Hinton\n'),
#  ('el_corpora/rss500.tsv',
#   'Kenny',
#   'http://aksw.org/notInWiki/Kenny_the_Clown\n'),
#  ('el_corpora/wes2015.tsv',
#   'Mann',
#   'http://dbpedia.org/resource/Mann_(surname)\n'),
#  ('el_corpora/neel2015-test.tsv',
#   'Williams',
#   'http://dbpedia.org/resource/Williams_Grand_Prix_Engineering\n'),
#  ('el_corpora/wes2015.tsv',
#   'Barrow',
#   'http://dbpedia.org/resource/Bonnie_and_Clyde\n'),
#  ('el_corpora/neel2015.tsv',
#   'Duke',
#   'http://dbpedia.org/resource/Duke_Nukem_Forever\n'),
#  ('el_corpora/wes2015.tsv',
#   'English',
#   'http://dbpedia.org/resource/English_language\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Chelsea',
#   'http://dbpedia.org/resource/Chelsea,_Manhattan\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Chase',
#   'http://dbpedia.org/resource/Chase_for_the_Sprint_Cup\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Andre', 'NIL\n'),
#  ('el_corpora/neel2015.tsv', 'Cary', 'NIL232\n'),
#  ('el_corpora/wes2015.tsv',
#   'Karl',
#   'http://dbpedia.org/resource/Karl_Popper\n'),
#  ('el_corpora/neel2014.tsv',
#   'Orlando',
#   'http://dbpedia.org/resource/Orlando,_Florida\n'),
#  ('el_corpora/neel2014.tsv',
#   'King',
#   'http://dbpedia.org/resource/Rodney_King\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Watson',
#   'http://dbpedia.org/resource/Tom_Watson_(golfer)\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Stanley', 'NIL\n'),
#  ('el_corpora/neel2015-test.tsv',
#   'Stafford',
#   'http://dbpedia.org/resource/Stafford\n'),
#  ('el_corpora/neel2015.tsv',
#   'White',
#   'http://dbpedia.org/resource/Chicago_White_Sox\n'),
#  ('el_corpora/wes2015.tsv',
#   'Mann',
#   'http://dbpedia.org/resource/Thomas_Mann\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'London',
#   'http://dbpedia.org/resource/London\n'),
#  ('el_corpora/rss500-unicode.tsv',
#   'Kayla',
#   'http://dbpedia.org/resource/Kayla_Harrison\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Enrique',
#   'http://dbpedia.org/resource/José_Enrique_(footballer)\n'),
#  ('el_corpora/wes2015.tsv',
#   'Stanford',
#   'http://dbpedia.org/resource/Stanford_University\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Graf',
#   'http://en.wikipedia.org/wiki/Steffi_Graf\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Brady', 'NIL\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Reid',
#   'http://dbpedia.org/resource/Harry_Reid\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Justice', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Wilson',
#   'http://en.wikipedia.org/wiki/Jeff_Wilson_(sportsman)\n'),
#  ('el_corpora/neel2015.tsv',
#   'Chelsea',
#   'http://dbpedia.org/resource/Chelsea,_Manhattan\n'),
#  ('el_corpora/neel2015-test.tsv', 'Reeves', 'NIL659\n'),
#  ('el_corpora/neel2015-train.tsv', 'Christian', 'NIL89\n'),
#  ('el_corpora/neel2015.tsv', 'China', 'http://dbpedia.org/resource/China\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Lily',
#   'http://dbpedia.org/resource/Order_of_the_Phoenix_(fiction)\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Jesus',
#   'http://dbpedia.org/resource/Jesus\n'),
#  ('el_corpora/wes2015.tsv',
#   'Thompson',
#   'http://dbpedia.org/resource/Ken_Thompson\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Emily',
#   'http://dbpedia.org/resource/Tropical_Storm_Emily_(2011)\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Teresa',
#   'http://en.wikipedia.org/wiki/Teresa\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Berger',
#   'http://en.wikipedia.org/wiki/Gerhard_Berger\n'),
#  ('el_corpora/neel2015-test.tsv',
#   'Valencia',
#   'http://dbpedia.org/resource/Valencia_CF\n'),
#  ('el_corpora/neel2015-test.tsv',
#   'Mercedes',
#   'http://dbpedia.org/resource/Mercedes-Benz_in_Formula_One\n'),
#  ('el_corpora/neel2015.tsv', 'Alex', 'NIL143\n'),
#  ('el_corpora/neel2015.tsv', 'Alex', 'NIL140\n'),
#  ('el_corpora/neel2015.tsv',
#   'Griffin',
#   'http://dbpedia.org/resource/Nick_Griffin\n'),
#  ('el_corpora/neel2015-test.tsv',
#   'Rogers',
#   'http://dbpedia.org/resource/Sportsnet\n'),
#  ('el_corpora/neel2014.tsv',
#   'Dayton',
#   'http://dbpedia.org/resource/Dayton,_Ohio\n'),
#  ('el_corpora/rss500-unicode.tsv',
#   'China',
#   'http://dbpedia.org/resource/China\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Mueller',
#   'http://dbpedia.org/resource/Brooke_Mueller\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Pendleton',
#   'http://en.wikipedia.org/wiki/Pendleton,_Oregon\n'),
#  ('el_corpora/neel2015.tsv', 'York', 'http://dbpedia.org/resource/York\n'),
#  ('el_corpora/neel2015-test.tsv',
#   'Ferguson',
#   'http://dbpedia.org/resource/Ferguson,_Missouri\n'),
#  ('el_corpora/neel2014.tsv',
#   'Kenya',
#   'http://dbpedia.org/resource/Kenya_Under-19_cricket_team\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Ford',
#   'http://en.wikipedia.org/wiki/Ford_World_Rally_Team\n'),
#  ('el_corpora/neel2015.tsv', 'Paige', 'NIL200\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'McEwen',
#   'http://en.wikipedia.org/wiki/Robbie_McEwen\n'),
#  ('el_corpora/rss500.tsv',
#   'Brooklyn',
#   'http://dbpedia.org/resource/Brooklyn\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Greer',
#   'http://en.wikipedia.org/wiki/Rusty_Greer\n'),
#  ('el_corpora/wes2015.tsv',
#   'Dante',
#   'http://dbpedia.org/resource/Dante_Alighieri\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Valencia',
#   'http://dbpedia.org/resource/Valencia_CF\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Tony',
#   'http://en.wikipedia.org/wiki/Tony_Roche\n'),
#  ('el_corpora/wes2015.tsv', 'April', 'http://dbpedia.org/resource/April\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Calderon', 'NIL\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Duke',
#   'http://dbpedia.org/resource/Duke_Nukem_Forever\n'),
#  ('el_corpora/neel2014.tsv', 'Paris', 'http://dbpedia.org/resource/Paris\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Chelsea',
#   'http://en.wikipedia.org/wiki/Chelsea_Clinton\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Chris',
#   'http://dbpedia.org/resource/Chris_Griffin\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Beck',
#   'http://en.wikipedia.org/wiki/Rod_Beck\n'),
#  ('el_corpora/neel2015.tsv', 'David', 'NIL108\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Burke',
#   'http://en.wikipedia.org/wiki/Matt_Burke\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Kevin',
#   'http://dbpedia.org/resource/Kevin_Woo\n'),
#  ('el_corpora/neel2014.tsv',
#   'Manning',
#   'http://dbpedia.org/resource/Peyton_Manning\n'),
#  ('el_corpora/neel2015.tsv',
#   'Suarez',
#   'http://dbpedia.org/resource/Luis_Suárez\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Stewart',
#   'http://en.wikipedia.org/wiki/Alec_Stewart\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'China',
#   'http://en.wikipedia.org/wiki/China_PR_national_football_team\n'),
#  ('el_corpora/wes2015.tsv',
#   'Bradford',
#   'http://dbpedia.org/resource/Bradford\n'),
#  ('el_corpora/wes2015.tsv',
#   'Francis',
#   'http://dbpedia.org/resource/Francis_Baily\n'),
#  ('el_corpora/neel2015.tsv', 'Justin', 'NIL154\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Springer', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Jeffrey',
#   'http://en.wikipedia.org/wiki/Michael_Jeffrey\n'),
#  ('el_corpora/neel2015-test.tsv', 'Jake', 'NIL15\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Noah',
#   'http://dbpedia.org/resource/Noah\n'),
#  ('el_corpora/neel2015.tsv', 'Johnson', 'NIL454\n'),
#  ('el_corpora/wes2015.tsv',
#   'Sullivan',
#   'http://dbpedia.org/resource/Louis_Sullivan\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', "O'Neal", 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Valencia',
#   'http://en.wikipedia.org/wiki/Valencia_CF\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Vaughan',
#   'http://en.wikipedia.org/wiki/Justin_Vaughan\n'),
#  ('el_corpora/neel2015-dev.tsv',
#   'Williams',
#   'http://dbpedia.org/resource/Williams_Grand_Prix_Engineering\n'),
#  ('el_corpora/neel2015-dev.tsv', 'Robbie', 'NIL230\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Dallas',
#   'http://dbpedia.org/resource/Dallas\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Holmes',
#   'http://dbpedia.org/resource/Santonio_Holmes\n'),
#  ('el_corpora/neel2015.tsv',
#   'Owen',
#   'http://dbpedia.org/resource/Owen_(musician)\n'),
#  ('el_corpora/neel2015.tsv',
#   'Daniel',
#   'http://dbpedia.org/resource/Daniel_Radcliffe\n'),
#  ('el_corpora/neel2014.tsv',
#   'Vela',
#   'http://dbpedia.org/resource/Carlos_Vela\n'),
#  ('el_corpora/neel2015.tsv', 'Lily', 'NIL4\n'),
#  ('el_corpora/neel2014.tsv',
#   'Alan',
#   'http://dbpedia.org/resource/Alan_Carr\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Houston',
#   'http://dbpedia.org/resource/Houston_Astros\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'English',
#   'http://en.wikipedia.org/wiki/English_language\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Lara',
#   'http://en.wikipedia.org/wiki/Brian_Lara\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Clayton',
#   'http://dbpedia.org/resource/Mark_Jermaine_Clayton\n'),
#  ('el_corpora/neel2014-test.tsv',
#   'John',
#   'http://dbpedia.org/resource/Gospel_of_John\n'),
#  ('el_corpora/neel2015.tsv', 'Victoria', 'NIL262\n'),
#  ('el_corpora/neel2014.tsv',
#   'Watford',
#   'http://dbpedia.org/resource/Watford\n'),
#  ('el_corpora/neel2015-dev.tsv',
#   'Porter',
#   'http://dbpedia.org/resource/Porter_(beer)\n'),
#  ('el_corpora/oke.tsv', 'Michael', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Salamanca',
#   'http://en.wikipedia.org/wiki/UD_Salamanca\n'),
#  ('el_corpora/rss500-unicode.tsv',
#   'Justin',
#   'http://aksw.org/notInWiki/Justin_Ford\n'),
#  ('el_corpora/neel2015-test.tsv',
#   'China',
#   'http://dbpedia.org/resource/China\n'),
#  ('el_corpora/wes2015.tsv',
#   'Leslie',
#   'http://dbpedia.org/resource/Leslie_(name)\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Burke', 'NIL\n'),
#  ('el_corpora/wikinews.tsv', 'London', 'http://dbpedia.org/resource/London\n'),
#  ('el_corpora/neel2015.tsv', 'Katie', 'NIL476\n'),
#  ('el_corpora/wes2015.tsv', 'May', 'http://dbpedia.org/resource/May\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'James', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Little', 'NIL\n'),
#  ('el_corpora/wes2015.tsv', 'Von', 'http://dbpedia.org/resource/Von\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Saeed', 'NIL\n'),
#  ('el_corpora/neel2015.tsv',
#   'Christian',
#   'http://dbpedia.org/resource/Christian\n'),
#  ('el_corpora/rss500.tsv', 'Mary', 'http://aksw.org/notInWiki/Mary\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Sarah',
#   'http://en.wikipedia.org/wiki/Sarah_Brady\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Armstrong',
#   'http://en.wikipedia.org/wiki/Lance_Armstrong\n'),
#  ('el_corpora/wes2015.tsv',
#   'German',
#   'http://dbpedia.org/resource/German_language\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Dayton',
#   'http://en.wikipedia.org/wiki/Dayton,_Ohio\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Justin',
#   'http://en.wikipedia.org/wiki/Paul_Justin\n'),
#  ('el_corpora/neel2015.tsv',
#   'Paul',
#   'http://dbpedia.org/resource/Paul_Stephenson_(police_officer)\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Fleming', 'NIL\n'),
#  ('el_corpora/neel2014.tsv',
#   'Harry',
#   'http://dbpedia.org/resource/Harry_Potter_(character)\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Orlando',
#   'http://en.wikipedia.org/wiki/Orlando_Magic\n'),
#  ('el_corpora/neel2015-test.tsv', 'Andy', 'NIL159\n'),
#  ('el_corpora/wes2015.tsv', 'Moses', 'http://dbpedia.org/resource/Moses\n'),
#  ('el_corpora/neel2015.tsv', 'Cory', 'NIL259\n'),
#  ('el_corpora/rss500.tsv',
#   'Casey',
#   'http://aksw.org/notInWiki/Casey_Guerrero\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Robert',
#   'http://en.wikipedia.org/wiki/Robert_Rubin\n'),
#  ('el_corpora/neel2015.tsv', 'Ashley', 'NIL176\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Victoria',
#   'http://en.wikipedia.org/wiki/Victorian_Bushrangers\n'),
#  ('el_corpora/wes2015.tsv', 'Dalton', 'http://dbpedia.org/resource/Daltoni\n'),
#  ('el_corpora/wes2015.tsv',
#   'Princeton',
#   'http://dbpedia.org/resource/Princeton,_New_Jersey\n'),
#  ('el_corpora/neel2014.tsv',
#   'Jordan',
#   'http://dbpedia.org/resource/Air_Jordan\n'),
#  ('el_corpora/neel2014.tsv',
#   'Suarez',
#   'http://dbpedia.org/resource/Luis_Su%C3%A1rez\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Watford',
#   'http://en.wikipedia.org/wiki/Watford_F.C.\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Arnold', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Thompson', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Ferguson',
#   'http://en.wikipedia.org/wiki/Ian_Ferguson_(footballer_born_1967)\n'),
#  ('el_corpora/neel2014-test.tsv',
#   'Ford',
#   'http://dbpedia.org/resource/Ford_Motor_Company\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Woods',
#   'http://dbpedia.org/resource/Tiger_Woods\n'),
#  ('el_corpora/neel2015.tsv',
#   'German',
#   'http://dbpedia.org/resource/Germans\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Jimmy', 'NIL\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Suarez',
#   'http://dbpedia.org/resource/Luis_Su%C3%A1rez\n'),
#  ('el_corpora/neel2015.tsv',
#   'Morgan',
#   'http://dbpedia.org/resource/Piers_Morgan\n'),
#  ('el_corpora/neel2015.tsv',
#   'Washington',
#   'http://dbpedia.org/resource/Washington,_D.C.\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Cleveland',
#   'http://dbpedia.org/resource/Cleveland\n'),
#  ('el_corpora/neel2014.tsv',
#   'Valencia',
#   'http://dbpedia.org/resource/Valencia_CF\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Watford',
#   'http://dbpedia.org/resource/Watford\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Joey',
#   'http://dbpedia.org/resource/Joey_Tribbiani\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'English',
#   'http://dbpedia.org/resource/English_language\n'),
#  ('el_corpora/neel2015.tsv',
#   'Princeton',
#   'http://dbpedia.org/resource/Princeton_University\n'),
#  ('el_corpora/rss500.tsv',
#   'Yang',
#   'http://aksw.org/notInWiki/Yang_Mei-ling\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Rocky',
#   'http://en.wikipedia.org/wiki/Rocky\n'),
#  ('el_corpora/neel2014-test.tsv',
#   'Chelsea',
#   'http://dbpedia.org/resource/Chelsea_F.C.\n'),
#  ('el_corpora/neel2015-test.tsv',
#   'Suarez',
#   'http://dbpedia.org/resource/Luis_Suárez\n'),
#  ('el_corpora/neel2015.tsv', 'Andrea', 'NIL158\n'),
#  ('el_corpora/neel2015.tsv',
#   'Emily',
#   'http://dbpedia.org/resource/Tropical_Storm_Emily_(2011)\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Turner', 'NIL\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Chelsea',
#   'http://dbpedia.org/resource/Chelsea_F.C.\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Camden',
#   'http://dbpedia.org/resource/Camden,_New_Jersey\n'),
#  ('el_corpora/neel2015-test.tsv',
#   'Gray',
#   'http://dbpedia.org/resource/Vincent_C._Gray\n'),
#  ('el_corpora/wes2015.tsv',
#   'Constantine',
#   'http://dbpedia.org/resource/Constantine_the_Great\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Princeton',
#   'http://dbpedia.org/resource/Princeton_University\n'),
#  ('el_corpora/neel2015.tsv', 'Gary', 'NIL123\n'),
#  ('el_corpora/oke.tsv',
#   'Roosevelt',
#   'http://dbpedia.org/resource/Franklin_D._Roosevelt\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Ponce', 'NIL\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Orlando',
#   'http://dbpedia.org/resource/Orlando,_Florida\n'),
#  ('el_corpora/neel2015-test.tsv',
#   'Kendra',
#   'http://dbpedia.org/resource/Kendra_Wilkinson\n'),
#  ('el_corpora/wes2015.tsv',
#   'Dalton',
#   'http://dbpedia.org/resource/John_Dalton\n'),
#  ('el_corpora/neel2015-dev.tsv', 'Jacobs', 'NIL149\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Thomas',
#   'http://en.wikipedia.org/wiki/Frank_Thomas_(baseball,_born_1968)\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Preston',
#   'http://en.wikipedia.org/wiki/Preston\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Salamanca', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Gore',
#   'http://en.wikipedia.org/wiki/Al_Gore\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Jean',
#   'http://en.wikipedia.org/wiki/Jean_Carlo_Witte\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Paris',
#   'http://en.wikipedia.org/wiki/Euronext_Paris\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'China',
#   "http://en.wikipedia.org/wiki/People's_Republic_of_China\n"),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Green', 'NIL\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Holmes',
#   'http://dbpedia.org/resource/Santonio_Holmes\n'),
#  ('el_corpora/wes2015.tsv',
#   'Mercer',
#   'http://dbpedia.org/resource/John_Mercer_(scientist)\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Hamilton',
#   'http://en.wikipedia.org/wiki/Joey_Hamilton\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Moore', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Hooper',
#   'http://en.wikipedia.org/wiki/Carl_Hooper\n'),
#  ('el_corpora/neel2014.tsv',
#   'Chelsea',
#   'http://dbpedia.org/resource/Chelsea,_Manhattan\n'),
#  ('el_corpora/neel2015-dev.tsv', 'Juan', 'NIL161\n'),
#  ('el_corpora/rss500.tsv',
#   'Ferguson',
#   'http://aksw.org/notInWiki/Bobby_Ferguson\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Paris',
#   'http://en.wikipedia.org/wiki/Paris_Saint_Germain_(rugby_league_team)\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Montoya', 'NIL\n'),
#  ('el_corpora/neel2015-test.tsv',
#   'Lewis',
#   'http://dbpedia.org/resource/Lewis_Hamilton\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Powell',
#   'http://en.wikipedia.org/wiki/Chris_Powell\n'),
#  ('el_corpora/rss500-unicode.tsv',
#   'Ryan',
#   'http://dbpedia.org/resource/Paul_Ryan\n'),
#  ('el_corpora/wes2015.tsv', 'del', 'http://dbpedia.org/resource/Del\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'English',
#   'http://en.wikipedia.org/wiki/United_Kingdom\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Joey',
#   'http://dbpedia.org/resource/Joey_Tribbiani\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Nicole', 'NIL\n'),
#  ('el_corpora/neel2014.tsv',
#   'Cleveland',
#   'http://dbpedia.org/resource/Cleveland\n'),
#  ('el_corpora/neel2015.tsv',
#   'English',
#   'http://dbpedia.org/resource/England\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Kelly',
#   'http://en.wikipedia.org/wiki/Shane_Kelly\n'),
#  ('el_corpora/neel2015.tsv', 'Nicole', 'NIL607\n'),
#  ('el_corpora/neel2015-test.tsv', 'Alan', 'NIL138\n'),
#  ('el_corpora/neel2015.tsv', 'Joe', 'NIL443\n'),
#  ('el_corpora/rss500.tsv',
#   'Marshall',
#   'http://dbpedia.org/resource/Marshall_Thundering_Herd_football\n'),
#  ('el_corpora/wes2015.tsv',
#   'Warren',
#   'http://dbpedia.org/resource/Warren_Commission\n'),
#  ('el_corpora/neel2015.tsv', 'Anthony', 'NIL167\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'McGrath',
#   'http://en.wikipedia.org/wiki/Glenn_McGrath\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Bertram', 'NIL\n'),
#  ('el_corpora/neel2014-test.tsv',
#   'Paige',
#   'http://dbpedia.org/resource/Paige_(band)\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Ferguson',
#   'http://dbpedia.org/resource/Alex_Ferguson\n'),
#  ('el_corpora/neel2015.tsv',
#   'Gray',
#   'http://dbpedia.org/resource/Vincent_C._Gray\n'),
#  ('el_corpora/neel2015.tsv', 'Dania', 'NIL270\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Bailey',
#   'http://en.wikipedia.org/wiki/Donovan_Bailey\n'),
#  ('el_corpora/oke.tsv', 'German', 'http://dbpedia.org/resource/Germans\n'),
#  ('el_corpora/rss500.tsv',
#   'Heard',
#   'http://aksw.org/notInWiki/Robert_Stefan_Heard\n'),
#  ('el_corpora/rss500.tsv', 'Karin', 'http://aksw.org/notInWiki/Karin\n'),
#  ('el_corpora/wes2015.tsv',
#   'Roman',
#   'http://dbpedia.org/resource/Roman_Empire\n'),
#  ('el_corpora/neel2015.tsv', 'Hannah', 'NIL368\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Miller',
#   'http://en.wikipedia.org/wiki/Nate_Miller\n'),
#  ('el_corpora/neel2015-dev.tsv',
#   'Lindsey',
#   'http://dbpedia.org/resource/Lindsey_Butterfield\n'),
#  ('el_corpora/neel2015-train.tsv', 'Jaden', 'NIL137\n'),
#  ('el_corpora/neel2015.tsv', 'Andy', 'NIL159\n'),
#  ('el_corpora/wikinews.tsv',
#   'Douglas',
#   'http://dbpedia.org/resource/McDonnell_Aircraft\n'),
# ...
#  ('el_corpora/wes2015.tsv',
#   'Emily',
#   'http://dbpedia.org/resource/Emily_Dickinson\n'),
#  ('el_corpora/neel2015.tsv', 'Jesus', 'http://dbpedia.org/resource/Jesus\n'),
#  ('el_corpora/neel2015.tsv', 'Curry', 'http://dbpedia.org/resource/Currys\n'),
#  ('el_corpora/rss500.tsv',
#   'Bustos',
#   'http://aksw.org/notInWiki/Ilda_Bustos\n'),
#  ('el_corpora/neel2015.tsv',
#   'Phoenix',
#   'http://dbpedia.org/resource/Phoenix_Park\n'),
#  ('el_corpora/neel2014-test.tsv',
#   'Wayne',
#   'http://dbpedia.org/resource/Lil_Wayne\n'),
#  ('el_corpora/wes2015.tsv',
#   'Wilkins',
#   'http://dbpedia.org/resource/Maurice_Wilkins\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Stephanie', 'NIL\n'),
#  ('el_corpora/wes2015.tsv',
#   'Henry',
#   'http://dbpedia.org/resource/Henry_IV_of_France\n'),
#  ('el_corpora/neel2015-dev.tsv',
#   'Ramsey',
#   'http://dbpedia.org/resource/Ramsey_Abbey\n'),
#  ('el_corpora/neel2015-test.tsv', 'Luke', 'NIL528\n'),
#  ('el_corpora/neel2015-test.tsv',
#   'Floyd',
#   'http://dbpedia.org/resource/Floyd_Patterson\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Karen',
#   'http://dbpedia.org/resource/Plankton_(character)\n'),
#  ('el_corpora/neel2015.tsv',
#   'Samantha',
#   'http://dbpedia.org/resource/Samantha_Lewthwaite\n'),
#  ('el_corpora/neel2015.tsv', 'John', 'NIL448\n'),
#  ('el_corpora/neel2015.tsv',
#   'Mike',
#   'http://dbpedia.org/resource/Mike_Tyson\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Salvador', 'NIL\n'),
#  ('el_corpora/neel2015-dev.tsv', 'Victoria', 'NIL262\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Perry',
#   'http://en.wikipedia.org/wiki/Ruth_Perry\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Reid',
#   'http://dbpedia.org/resource/Harry_Reid\n'),
#  ('el_corpora/neel2014.tsv',
#   'Holmes',
#   'http://dbpedia.org/resource/Santonio_Holmes\n'),
#  ('el_corpora/neel2014.tsv',
#   'Chase',
#   'http://dbpedia.org/resource/Chase_for_the_Sprint_Cup\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Ron',
#   'http://dbpedia.org/resource/Ron_Weasley\n'),
#  ('el_corpora/rss500.tsv', 'Emma', 'http://aksw.org/notInWiki/Emma_Veary\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Sorensen', 'NIL\n'),
#  ('el_corpora/neel2015.tsv',
#   'Dunn',
#   'http://dbpedia.org/resource/Adam_Dunn\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'David', 'NIL\n'),
#  ('el_corpora/neel2015.tsv', 'Nadia', 'NIL598\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Jesus',
#   'http://dbpedia.org/resource/Jesus\n'),
#  ('el_corpora/rss500-unicode.tsv',
#   'Tan',
#   'http://aksw.org/notInWiki/Tan_Ching-ting\n'),
#  ('el_corpora/neel2014.tsv', 'II', 'http://dbpedia.org/resource/2_(number)\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Madison', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Paris',
#   'http://en.wikipedia.org/wiki/Paris,_Arkansas\n'),
#  ('el_corpora/neel2015-test.tsv', 'Andrea', 'NIL158\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'John',
#   'http://dbpedia.org/resource/Gospel_of_John\n'),
#  ('el_corpora/wes2015.tsv',
#   'Jackson',
#   'http://dbpedia.org/resource/William_Henry_Jackson\n'),
#  ('el_corpora/neel2015-test.tsv',
#   'Jason',
#   'http://dbpedia.org/resource/Jason_Robinson\n'),
#  ('el_corpora/neel2014-test.tsv',
#   'Camden',
#   'http://dbpedia.org/resource/Camden,_New_Jersey\n'),
#  ('el_corpora/neel2015-dev.tsv',
#   'English',
#   'http://dbpedia.org/resource/English_language\n'),
#  ('el_corpora/neel2014.tsv',
#   'Chris',
#   'http://dbpedia.org/resource/Chris_Griffin\n'),
#  ('el_corpora/neel2015.tsv',
#   'Houston',
#   'http://dbpedia.org/resource/Houston\n'),
#  ('el_corpora/neel2015.tsv', 'Michael', 'NIL180\n'),
#  ('el_corpora/neel2014-test.tsv',
#   'Stephenson',
#   'http://dbpedia.org/resource/Paul_Stephenson_(police_officer)\n'),
#  ('el_corpora/neel2015.tsv',
#   'Chris',
#   'http://dbpedia.org/resource/Chris_Griffin\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Rene',
#   'http://en.wikipedia.org/wiki/René_(novella)\n'),
#  ('el_corpora/neel2014.tsv',
#   'Enrique',
#   'http://dbpedia.org/resource/Jos%C3%A9_Enrique_S%C3%A1nchez\n'),
#  ('el_corpora/neel2015-test.tsv', 'Steve', 'NIL732\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Smith', 'NIL\n'),
#  ('el_corpora/neel2014-test.tsv',
#   'Jesus',
#   'http://dbpedia.org/resource/Jesus\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Tiffany',
#   'http://dbpedia.org/resource/Tiffany_(South_Korean_singer)\n'),
#  ('el_corpora/neel2014.tsv',
#   'Emily',
#   'http://dbpedia.org/resource/Tropical_Storm_Emily_(2011)\n'),
#  ('el_corpora/neel2015-test.tsv', 'Graham', 'NIL358\n'),
#  ('el_corpora/wes2015.tsv',
#   'Edward',
#   'http://dbpedia.org/resource/Edward_Drinker_Cope\n'),
#  ('el_corpora/wes2015.tsv',
#   'Hayden',
#   'http://dbpedia.org/resource/Ferdinand_Vandeveer_Hayden\n'),
#  ('el_corpora/wes2015.tsv',
#   'Joseph',
#   'http://dbpedia.org/resource/Joseph_Merrick\n'),
#  ('el_corpora/neel2014-test.tsv',
#   'York',
#   'http://dbpedia.org/resource/York\n'),
#  ('el_corpora/neel2015-test.tsv',
#   'Owen',
#   'http://dbpedia.org/resource/Owen_(musician)\n'),
#  ('el_corpora/rss500.tsv',
#   'Washington',
#   'http://dbpedia.org/resource/Washington,_D.C.\n'),
#  ('el_corpora/wes2015.tsv',
#   'Trenton',
#   'http://dbpedia.org/resource/Trenton,_New_Jersey\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Houston',
#   'http://dbpedia.org/resource/Houston\n'),
#  ('el_corpora/rss500-unicode.tsv',
#   'Clark',
#   'http://aksw.org/notInWiki/Rick_Clark\n'),
#  ('el_corpora/wes2015.tsv',
#   'Cornell',
#   'http://dbpedia.org/resource/Eric_Allin_Cornell\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Manning',
#   'http://dbpedia.org/resource/Peyton_Manning\n'),
#  ('el_corpora/neel2015.tsv',
#   'Joe',
#   'http://dbpedia.org/resource/Joe_Spencer_(Hollyoaks)\n'),
#  ('el_corpora/neel2015.tsv',
#   'Porter',
#   'http://dbpedia.org/resource/Porter_(beer)\n'),
#  ('el_corpora/neel2015.tsv',
#   'Hughes',
#   'http://dbpedia.org/resource/Phillip_Hughes\n'),
#  ('el_corpora/neel2015-test.tsv', 'David', 'NIL284\n'),
#  ('el_corpora/neel2015-test.tsv', 'Hannah', 'NIL368\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Washington',
#   'http://dbpedia.org/resource/Federal_government_of_the_United_States\n'),
#  ('el_corpora/neel2014.tsv',
#   'Will',
#   'http://dbpedia.org/resource/Prince_William,_Duke_of_Cambridge\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Rashid', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Oldham',
#   'http://en.wikipedia.org/wiki/Oldham_Athletic_A.F.C.\n'),
#  ('el_corpora/neel2014-test.tsv',
#   'II',
#   'http://dbpedia.org/resource/2_(number)\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Ramos',
#   'http://en.wikipedia.org/wiki/Fidel_V._Ramos\n'),
#  ('el_corpora/neel2015.tsv',
#   'Lewis',
#   'http://dbpedia.org/resource/Lewis_Hamilton\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Branch',
#   'http://en.wikipedia.org/wiki/Michael_Branch\n'),
#  ('el_corpora/neel2015-test.tsv',
#   'Kenya',
#   'http://dbpedia.org/resource/Kenya\n'),
#  ('el_corpora/neel2015.tsv',
#   'Ramsey',
#   'http://dbpedia.org/resource/Ramsey_Abbey\n'),
#  ('el_corpora/neel2015.tsv',
#   'Houston',
#   'http://dbpedia.org/resource/Houston_Astros\n'),
#  ('el_corpora/rss500-unicode.tsv', 'Lee', 'http://aksw.org/notInWiki/Lee\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Kingston',
#   'http://en.wikipedia.org/wiki/Kingston_Technology\n'),
#  ('el_corpora/neel2014-test.tsv',
#   'Heaven',
#   'http://dbpedia.org/resource/Heaven\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Lorenzo',
#   'http://dbpedia.org/resource/San_Lorenzo,_California\n'),
#  ('el_corpora/neel2014.tsv',
#   'Ron',
#   'http://dbpedia.org/resource/Ron_Weasley\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Campbell',
#   'http://dbpedia.org/resource/Joel_Campbell\n'),
#  ('el_corpora/neel2015-test.tsv', 'Sheldon', 'NIL708\n'),
#  ('el_corpora/neel2014.tsv', 'Stan', 'http://dbpedia.org/resource/Stan_Lee\n'),
#  ('el_corpora/wes2015.tsv',
#   'Stokes',
#   'http://dbpedia.org/resource/Sir_George_Stokes,_1st_Baronet\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Stephenson',
#   'http://dbpedia.org/resource/Paul_Stephenson_(police_officer)\n'),
#  ('el_corpora/wes2015.tsv', 'Bruce', 'http://dbpedia.org/resource/Bruce\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Williams', 'NIL\n'),
#  ('el_corpora/rss500.tsv',
#   'Lawrence',
#   'http://aksw.org/notInWiki/Lawrence_Vikings_football\n'),
#  ('el_corpora/rss500-unicode.tsv',
#   'Bustos',
#   'http://aksw.org/notInWiki/Ilda_Bustos\n'),
#  ('el_corpora/neel2014.tsv',
#   'Duke',
#   'http://dbpedia.org/resource/Duke_Nukem_Forever\n'),
#  ('el_corpora/neel2014.tsv',
#   'Houston',
#   'http://dbpedia.org/resource/Houston\n'),
#  ('el_corpora/neel2015.tsv', 'Lee', 'NIL503\n'),
#  ('el_corpora/wes2015.tsv',
#   'William',
#   'http://dbpedia.org/resource/William_the_Conqueror\n'),
#  ('el_corpora/neel2014.tsv',
#   'Harris',
#   'http://dbpedia.org/resource/Richard_Harris\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Brooklyn',
#   'http://dbpedia.org/resource/Brooklyn\n'),
#  ('el_corpora/neel2015.tsv',
#   'Angelina',
#   'http://dbpedia.org/resource/Angelina_Jolie\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Cunningham',
#   'http://en.wikipedia.org/wiki/Randall_Cunningham\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Johnson', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Brent', 'NIL\n'),
#  ('el_corpora/neel2015.tsv', 'Wilson', 'NIL788\n'),
#  ('el_corpora/neel2015.tsv',
#   'Karen',
#   'http://dbpedia.org/resource/Plankton_(character)\n'),
#  ('el_corpora/wes2015.tsv',
#   'Clark',
#   'http://dbpedia.org/resource/Clark_University\n'),
#  ('el_corpora/neel2015.tsv',
#   'Hamilton',
#   'http://dbpedia.org/resource/Lewis_Hamilton\n'),
#  ('el_corpora/neel2015.tsv', 'Alan', 'NIL138\n'),
#  ('el_corpora/neel2015-test.tsv', 'Wilson', 'NIL788\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Guzman', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Lisa', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Randall',
#   'http://en.wikipedia.org/wiki/Randall_Cunningham\n'),
#  ('el_corpora/rss500.tsv', 'Lee', 'http://aksw.org/notInWiki/Lee\n'),
#  ('el_corpora/neel2014-test.tsv',
#   'Cameron',
#   'http://dbpedia.org/resource/David_Cameron\n'),
#  ('el_corpora/rss500-unicode.tsv',
#   'Cornell',
#   'http://dbpedia.org/resource/Cornell_University\n'),
#  ('el_corpora/wes2015.tsv',
#   'Taylor',
#   'http://dbpedia.org/resource/Brooke_Taylor\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Gonzalez', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'German',
#   'http://en.wikipedia.org/wiki/Germany\n'),
#  ('el_corpora/neel2015.tsv',
#   'Joey',
#   'http://dbpedia.org/resource/Joey_Tribbiani\n'),
#  ('el_corpora/oke-testset.tsv',
#   'Rutherford',
#   'http://dbpedia.org/resource/Ernest_Rutherford\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Tony', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Santa',
#   'http://en.wikipedia.org/wiki/Santa_Claus\n'),
#  ('el_corpora/neel2014-test.tsv',
#   'Smith',
#   'http://dbpedia.org/resource/DeMaurice_Smith\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Dunn',
#   'http://dbpedia.org/resource/Adam_Dunn\n'),
#  ('el_corpora/rss500-unicode.tsv',
#   'Council',
#   'http://aksw.org/notInWiki/Council_on_American-Islamic_Relations-Michigan\n'),
#  ('el_corpora/rss500.tsv',
#   'Gayle',
#   'http://dbpedia.org/resource/Chris_Gayle\n'),
#  ('el_corpora/neel2015.tsv', 'Omar', 'NIL620\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Kevin',
#   'http://dbpedia.org/resource/Kevin_Woo\n'),
#  ('el_corpora/neel2015-test.tsv',
#   'Cameron',
#   'http://dbpedia.org/resource/David_Cameron\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Jordan',
#   'http://dbpedia.org/resource/Air_Jordan\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Watts', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Jim', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Baker',
#   'http://en.wikipedia.org/wiki/James_Baker\n'),
#  ('el_corpora/wes2015.tsv', 'Lyons', 'http://dbpedia.org/resource/Lyon\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Camacho',
#   'http://en.wikipedia.org/wiki/Héctor_Camacho\n'),
#  ('el_corpora/neel2015.tsv',
#   'James',
#   'http://dbpedia.org/resource/James_(band)\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Fernandez',
#   'http://en.wikipedia.org/wiki/Mary_Joe_Fernandez\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Kennedy', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Christian',
#   'http://en.wikipedia.org/wiki/Catholicism\n'),
#  ('el_corpora/neel2014.tsv',
#   'Princeton',
#   'http://dbpedia.org/resource/Princeton_University\n'),
#  ('el_corpora/neel2014-test.tsv',
#   'Princeton',
#   'http://dbpedia.org/resource/Princeton_University\n'),
#  ('el_corpora/neel2014.tsv',
#   'Ford',
#   'http://dbpedia.org/resource/Ford_Motor_Company\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Hill',
#   'http://en.wikipedia.org/wiki/Ken_Hill_(baseball)\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Lewis',
#   'http://en.wikipedia.org/wiki/Lewis_Gunn\n'),
#  ('el_corpora/neel2015.tsv', 'Lia', 'NIL511\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Karen',
#   'http://dbpedia.org/resource/Plankton_(SpongeBob_SquarePants)\n'),
#  ('el_corpora/neel2015-train.tsv', 'Erik', 'NIL117\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Thon',
#   'http://en.wikipedia.org/wiki/Olaf_Thon\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Sergio', 'NIL\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Kennedy',
#   'http://en.wikipedia.org/wiki/Mark_Kennedy_(footballer)\n'),
#  ('el_corpora/wes2015.tsv',
#   'Francis',
#   'http://dbpedia.org/resource/Francis_II_of_France\n'),
#  ('el_corpora/rss500.tsv', 'Kyle', 'http://aksw.org/notInWiki/Thomas_Kyle\n'),
#  ('el_corpora/neel2015.tsv', 'Megan', 'NIL191\n'),
#  ('el_corpora/neel2015-dev.tsv', 'Lawrence', 'NIL169\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Geneva',
#   'http://en.wikipedia.org/wiki/Geneva\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Washington', 'NIL\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Harry',
#   'http://dbpedia.org/resource/Harry_Potter_(character)\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Young',
#   'http://en.wikipedia.org/wiki/Doug_Young\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Enrique',
#   'http://dbpedia.org/resource/Jos%C3%A9_Enrique_S%C3%A1nchez\n'),
#  ('el_corpora/rss500.tsv',
#   'John',
#   'http://dbpedia.org/resource/John_Calipari\n'),
#  ('el_corpora/rss500.tsv',
#   'Cornell',
#   'http://dbpedia.org/resource/Cornell_University\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Burns',
#   'http://en.wikipedia.org/wiki/R._Nicholas_Burns\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Brady',
#   'http://en.wikipedia.org/wiki/James_Brady\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Phoenix',
#   'http://dbpedia.org/resource/Phoenix_Park\n'),
#  ('el_corpora/wes2015.tsv',
#   'Hector',
#   'http://dbpedia.org/resource/Tim_Hector\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'McCullough', 'NIL\n'),
#  ('el_corpora/oke-trainingset.tsv', 'Paul', 'NIL\n'),
#  ('el_corpora/rss500.tsv',
#   'Milton',
#   'http://dbpedia.org/resource/Milton,_Massachusetts\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Monica',
#   'http://en.wikipedia.org/wiki/Monica_Seles\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Simpson',
#   'http://en.wikipedia.org/wiki/O._J._Simpson\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Quinn',
#   'http://en.wikipedia.org/wiki/Niall_Quinn\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv',
#   'Bradford',
#   'http://en.wikipedia.org/wiki/Bradford_City_A.F.C.\n'),
#  ('el_corpora/neel2014.tsv',
#   'Brown',
#   'http://dbpedia.org/resource/Cleveland_Browns\n'),
#  ('el_corpora/neel2015-test.tsv',
#   'Christian',
#   'http://dbpedia.org/resource/Christian\n'),
#  ('el_corpora/neel2015-train.tsv',
#   'Campbell',
#   'http://dbpedia.org/resource/Joel_Campbell\n'),
#  ('el_corpora/neel2015.tsv', 'Eric', 'NIL121\n'),
#  ('el_corpora/neel2014-train.tsv',
#   'Henderson',
#   'http://dbpedia.org/resource/Jordan_Henderson\n'),
#  ('el_corpora/AIDA-YAGO2_entities_and_links.tsv', 'Edwards', 'NIL\n'),
#  ...}

# %%
print(len(result))
print(len(result2))
# Out:
# 36
# 1239

# %% [markdown]
# # Locations

# %%
freq_locations = Counter([tuple([row['address'], row['city_or_county'], row['state']]) for index, row in df.iterrows()])
freq_locations
# Out:
# Counter({('Ada Street', 'Lansing', 'Michigan'): 1,
#          ('600 block of Oak Hill Cemetery Road', 'Bastrop', 'Texas'): 1,
#          ('4900 block of W Hubbard', 'Chicago', 'Illinois'): 1,
#          ('5103 Bunkhum Rd', 'East Saint Louis', 'Illinois'): 1,
#          ('East Church and South Gearhart Avenues', 'Fresno', 'California'): 1,
#          ('1200 block of Susan Avenue', 'Fort Worth', 'Texas'): 2,
#          ('245 Joline Avenue', 'Long Branch', 'New Jersey'): 1,
#          ('55 Curtis', 'Providence', 'Rhode Island'): 1,
#          ('N/A', 'Dayton (Trotwood)', 'Ohio'): 1,
#          ('700 block of Sims Avenue', 'Saint Paul', 'Minnesota'): 1,
#          ('Clinton and Marks Avenue', 'Fresno', 'California'): 1,
#          ('Leonard Street', 'Chetek', 'Wisconsin'): 1,
#          ('1600 block of North Austin Boulevard', 'Chicago', 'Illinois'): 1,
#          ('700 block of Thornhill', 'Cleveland', 'Ohio'): 1,
#          ('900 block of West Fayette Street', 'Baltimore', 'Maryland'): 1,
#          ('18600 block of East 49th Street', 'Tulsa', 'Oklahoma'): 1,
#          ('South Bedford Avenue', 'Evansville', 'Indiana'): 1,
#          ('Hampton Street', 'Nashville', 'Tennessee'): 2,
#          ('Blue Road and South Jeffs Road',
#           'Missaukee (county)',
#           'Michigan'): 1,
#          ('NE 23rd St and Martin Luther King Ave',
#           'Oklahoma City',
#           'Oklahoma'): 1,
#          ('Garner Road', 'Aynor', 'South Carolina'): 3,
#          ('1200 block of Pennsylvania Avenue NW',
#           'Washington',
#           'District of Columbia'): 1,
#          ('Hedges at Peach and Olive', 'Fresno', 'California'): 1,
#          ('400 block of West Baltimore Street',
#           'Greencastle',
#           'Pennsylvania'): 3,
#          ('The Long Ln and Myrtle Grove Ln', 'Bohannon', 'Virginia'): 1,
#          ('2700 block of Newton Avenue', 'Indianapolis', 'Indiana'): 1,
#          ('Nelson Court', 'Benton', 'Arkansas'): 2,
#          ('4702 West Magnum Rd.', 'Houston', 'Texas'): 1,
#          ('1400 North 5th Street', 'Grand Junction', 'Colorado'): 1,
#          ('6000 block of Virginia Avenue', 'Saint Louis', 'Missouri'): 1,
#          ('4000 block of Snowbird Drive', 'Smyrna', 'Tennessee'): 2,
#          ('Broadway Road and Priest Drive', 'Tempe', 'Arizona'): 1,
#          ('Hallandale Beach Blvd',
#           'Hallandale (Hallandale Beach)',
#           'Florida'): 1,
#          ('Commerce Road', 'Athens', 'Georgia'): 1,
#          ('2700 block of Faircrest Drive', 'Rockwall', 'Texas'): 1,
#          ('5500 block of Avenue D', 'Fairfield', 'Alabama'): 1,
#          ('N/A', 'Johnson Corner', 'Georgia'): 1,
#          ('800 block of Calvert St', 'Detroit', 'Michigan'): 1,
#          ('N/A', 'Caruthersville', 'Missouri'): 1,
#          ('6100 block of South Kimbark Avenue', 'Chicago', 'Illinois'): 1,
#          ('900 block of Almond Dr', 'Aurora', 'Illinois'): 1,
#          ('100 block of Lakeside Hills Loop', 'Auburndale', 'Florida'): 3,
#          ('Broadway and Pike', 'Seattle', 'Washington'): 2,
#          ('5300 block of Patton Ave', 'Saint Louis (St Louis)', 'Missouri'): 1,
#          ('22000 block of East Avenue North',
#           'Pennfield Township',
#           'Michigan'): 1,
#          ('800 block of La Mesa Lane', 'Los Banos', 'California'): 1,
#          ('5700 block of South Lowe Avenue',
#           'Chicago (Englewood)',
#           'Illinois'): 1,
#          ('5700 block of E 28th St', 'Tucson', 'Arizona'): 1,
#          ('10921 Estate Lane', 'Dallas', 'Texas'): 1,
#          ('4200 block of West 103 Street', 'Inglewood', 'California'): 1,
#          ('Kostner and Jackson', 'Chicago', 'Illinois'): 1,
#          ('216 E Mountain View Drive', 'Flagstaff', 'Arizona'): 1,
#          ('Robinwood Park', 'Columbus', 'Ohio'): 1,
#          ('Rue Labeau Circle and Fargo Drive', 'Fort Myers', 'Florida'): 1,
#          ('2030 NW 29th Ter', 'Fort Lauderdale', 'Florida'): 1,
#          ('6630 Frontage Road', 'Greenville', 'South Carolina'): 1,
#          ('300 block of Figueroa Drive', 'Altadena', 'California'): 1,
#          ('9400 block of North Government Way', 'Hayden', 'Idaho'): 1,
#          ('5300 block of Whetsel Avenue', 'Cincinnati', 'Ohio'): 1,
#          ('Federal Boulevard and 16th Avenue', 'Denver', 'Colorado'): 1,
#          ('6200 block of Towngate Circle', 'Katy', 'Texas'): 1,
#          ('Coit Road', 'Dallas', 'Texas'): 1,
#          ('2000 block of Genesee Street',
#           'Trenton (Hamilton Township)',
#           'New Jersey'): 1,
#          ('8504 Old Kentucky Rd', 'Sparta', 'Tennessee'): 1,
#          ('N/A', 'Baconton', 'Georgia'): 1,
#          ('2520 US Hwy 92 West', 'Winter Haven', 'Florida'): 3,
#          ('400 block of Morgan Street', 'Houma', 'Louisiana'): 1,
#          ('3000 block of Mountainwood Circle', 'Juneau', 'Alaska'): 3,
#          ('1700 block of Summit Avenue', 'Pasadena', 'California'): 1,
#          ('600 block of Hillcrest Street', 'Memphis', 'Tennessee'): 1,
#          ('11129 Saint Charles Rd', 'Cassville', 'Wisconsin'): 1,
#          ('N/A', 'Lake Waccamaw', 'North Carolina'): 1,
#          ('Seventh Street', 'Campbell', 'Ohio'): 1,
#          ('110 Calhoun Street', 'Charleston', 'South Carolina'): 1,
#          ('Highway 98 East', 'Mccomb', 'Mississippi'): 2,
#          ('W Thornton St and Laurel Ave', 'Akron', 'Ohio'): 1,
#          ('400 block of N. 34th Street', 'Louisville', 'Kentucky'): 2,
#          ('Blue Sewanee Rd', 'Dunlap', 'Tennessee'): 1,
#          ('2600 Americare Ct NW', 'Albuquerque', 'New Mexico'): 1,
#          ('1100 block of Graystone Drive', 'Dayton (Trotwood)', 'Ohio'): 1,
#          ('700 block of E. 11th Street', 'Wilmington', 'Delaware'): 1,
#          ('Davis Avenue', 'Pass Christian', 'Mississippi'): 1,
#          ('1100 block of Kansas Avenue', 'Modesto', 'California'): 1,
#          ('1287 Hebron Road', 'Heath', 'Ohio'): 1,
#          ('1100 block of South State Ave', 'Freeport', 'Illinois'): 2,
#          ('East Side Drive', 'Yankton', 'South Dakota'): 2,
#          ('3800 block of Reynosa Street', 'Corpus Christi', 'Texas'): 1,
#          ('707 S Interstate 35 E', 'Denton', 'Texas'): 1,
#          ('5500 block of Etiwanda Avenue',
#           'Riverside (Jurupa Valley)',
#           'California'): 1,
#          ('Drane Field Rd', 'Polk (county)', 'Florida'): 1,
#          ('811 Port Street', 'Saint Joseph', 'Michigan'): 2,
#          ('1100 Block of Thermo Village Rd', 'New Stanton', 'Pennsylvania'): 1,
#          ('600 block of South Fulton Avenue', 'Baltimore', 'Maryland'): 1,
#          ('2400 block of Mardi Gras Boulevard', 'New Orleans', 'Louisiana'): 1,
#          ('Highway 30', 'Stokes', 'North Carolina'): 2,
#          ('1600 block of Bellevue Avenue', 'Syracuse', 'New York'): 1,
#          ('6000 block of Middleburg Road',
#           'Henderson (county)',
#           'Tennessee'): 2,
#          ('CR 6853', 'Medina (county)', 'Texas'): 1,
#          ('300 block of Gaston Avenue', 'Memphis', 'Tennessee'): 1,
#          ('Great Bend Drive and Lime Street', 'Durham', 'North Carolina'): 1,
#          ('Bethel Road', 'Beckley', 'West Virginia'): 2,
#          ('Martin Luther King Drive', 'Marksville', 'Louisiana'): 1,
#          ('600 block of Reservoir Street', 'Durham', 'North Carolina'): 1,
#          ('2500 block of Independence Avenue', 'Kansas City', 'Missouri'): 1,
#          ('1300 block of 22nd Street', 'Orlando', 'Florida'): 1,
#          ('3400 block of Oxford', 'Alvin', 'Texas'): 3,
#          ('N/A', 'Dallas', 'Texas'): 2,
#          ('3600 block of Callaghan Road', 'San Antonio', 'Texas'): 3,
#          ('1400 block of McCulloch Street', 'Fort Wayne', 'Indiana'): 1,
#          ('1300 block of South Homan', 'Chicago', 'Illinois'): 2,
#          ('1500 block of Butler St. SE',
#           'Washington',
#           'District of Columbia'): 1,
#          ('Northwest 173rd Terrace and 27th Avenue',
#           'Miami Gardens',
#           'Florida'): 1,
#          ('5200 block of South Sangamon', 'Chicago', 'Illinois'): 1,
#          ('Unit block of Weatherstone Lane', 'Felton', 'Delaware'): 1,
#          ('6900 block of South Paxton Avenue', 'Chicago', 'Illinois'): 1,
#          ('N/A', 'Clinton', 'Mississippi'): 1,
#          ('4700 block of Fowler Avenue', 'Omaha', 'Nebraska'): 1,
#          ('4126 N Teutonia Ave', 'Milwaukee', 'Wisconsin'): 1,
#          ('Singleton and Hampton', 'Dallas', 'Texas'): 1,
#          ('4233 Warren Street', 'Davenport', 'Iowa'): 1,
#          ('Pecan Drive', 'Kilmichael', 'Mississippi'): 1,
#          ('3400 block of Old Brandon Road', 'Pearl', 'Mississippi'): 1,
#          ('Pineturn Lane', 'Gaston', 'South Carolina'): 1,
#          ('95th Avenue and 120 Street', 'Corona (Queens)', 'New York'): 1,
#          ('800 Steven B Tanger Blvd', 'Commerce', 'Georgia'): 1,
#          ('300 block of 18th street', 'Des Moines', 'Iowa'): 1,
#          ('1800 block of West McCormick', 'Wichita', 'Kansas'): 1,
#          ('N/A', 'Cedaredge (Grand Mesa)', 'Colorado'): 1,
#          ('8500 block of Riverview Blvd', 'Saint Louis', 'Missouri'): 1,
#          ('5600 block of Red Maple Drive', 'New Orleans', 'Louisiana'): 2,
#          ('334 Main Street', 'Pinetown', 'North Carolina'): 3,
#          ('Daisy Dean Road', 'Park (county)', 'Montana'): 1,
#          ('100 block of W Claremont St', 'Pasadena', 'California'): 1,
#          ('300 block of Apsley Street', 'Philadelphia', 'Pennsylvania'): 1,
#          ('Robertson Bridge Road', 'Merlin', 'Oregon'): 3,
#          ('Interstate 64 and Raliegh Street',
#           'Rocky Mount',
#           'North Carolina'): 1,
#          ('Cezanne Drive', 'Baton Rouge', 'Louisiana'): 1,
#          ('800 block of South Kirkman Road', 'Orlando', 'Florida'): 2,
#          ('2500 block of Pomeroy Road, SE',
#           'Washington',
#           'District of Columbia'): 1,
#          ('4000 block of Morris Street', 'Alexandria', 'Virginia'): 1,
#          ('4500 block of South Wood', 'Chicago', 'Illinois'): 1,
#          ('11100 block of West 95th Street South',
#           'Sedgwick (county)',
#           'Kansas'): 1,
#          ('900block of East 79th Street', 'Chicago', 'Illinois'): 1,
#          ('Perez Cove Road', 'Rankin (county)', 'Mississippi'): 1,
#          ('232 2nd Ave N', 'Twin Falls', 'Idaho'): 1,
#          ('N/A', 'Rice', 'Texas'): 2,
#          ('4812 West Sunnyside Ave', 'Glendale', 'Arizona'): 2,
#          ('N/A', 'Starkville', 'Mississippi'): 1,
#          ('Florida 20 and Rowland Ave', 'Palatka', 'Florida'): 1,
#          ('4000 block of West Southern Avenue', 'Phoenix', 'Arizona'): 2,
#          ('6500 block of Narcissus', 'Houston', 'Texas'): 1,
#          ('1700 block of La Casa Drive', 'Odessa', 'Texas'): 1,
#          ('1700 block of West Highland Avenue', 'Aransas Pass', 'Texas'): 1,
#          ('200 Bowser Cir', 'Terrell', 'Texas'): 2,
#          ('1300 block of Coalter Street', 'Richmond', 'Virginia'): 1,
#          ('Temple Street', 'Abington', 'Massachusetts'): 1,
#          ('Laguna and Page streets', 'San Francisco', 'California'): 1,
#          ('7 North Broad Street', 'Johnson City', 'New York'): 1,
#          ('Lake Tahoe Blvd', 'Lake Tahoe', 'California'): 1,
#          ('5604 Graham Ave', 'Sumner', 'Washington'): 1,
#          ('500 block of North Helm Street', 'Paoli', 'Indiana'): 1,
#          ('555 N Heliotrope Drive',
#           'Los Angeles (Hollywood)',
#           'California'): 1,
#          ('1100 block of Holt Street', 'Norfolk', 'Virginia'): 1,
#          ('18400 block of Algonac', 'Detroit', 'Michigan'): 1,
#          ('5100 block of Sansom Street', 'Philadelphia', 'Pennsylvania'): 1,
#          ('10000 block of Republic Ln', 'Little Rock', 'Arkansas'): 1,
#          ('Peregrine Park', 'Sacramento', 'California'): 1,
#          ('200 block of Holly Avenue', 'Compton', 'California'): 1,
#          ('1041 Martin Street SE', 'Atlanta', 'Georgia'): 2,
#          ('8607 E 61st Terrace', 'Kansas City', 'Missouri'): 2,
#          ('2400 block of 47th Street', 'Sarasota', 'Florida'): 1,
#          ('1123 Fourth Avenue', 'Ford City', 'Pennsylvania'): 1,
#          ('1910 South Pine Avenue', 'Ocala', 'Florida'): 1,
#          ('1041 Tiffany Street', 'Bronx', 'New York'): 1,
#          ('N/A', 'Chattanooga', 'Tennessee'): 1,
#          ('13915 Road 3', 'Pandora', 'Ohio'): 1,
#          ('300 block of S. Outlook Rd.', 'Granger', 'Washington'): 1,
#          ('Baintree Rd', 'Cleveland (University Heights)', 'Ohio'): 1,
#          ('411 East 2nd Street', 'Jamestown', 'New York'): 1,
#          ('1600 block of Selden Avenue', 'Norfolk', 'Virginia'): 1,
#          ('3704 Fannin Street', 'Houston', 'Texas'): 1,
#          ('311th Avenue', 'Buckeye', 'Arizona'): 1,
#          ('2900 Block of South Gordon Street', 'Alvin', 'Texas'): 1,
#          ('3200 block of Montrose Avenue', 'Rockford', 'Illinois'): 2,
#          ('Mission Ridge Road and Johnson Road', 'Rossville', 'Georgia'): 1,
#          ('2000 block of Jaden Lane', 'Greenwood', 'Indiana'): 3,
#          ('1100 To Lani Farm Road', 'Stone Mountain', 'Georgia'): 1,
#          ('600 block of Turner Road',
#           'Darlington County',
#           'South Carolina'): 1,
#          ('30700 block of S Marian St', 'Molalla', 'Oregon'): 1,
#          ('60th and Market', 'Philadelphia', 'Pennsylvania'): 1,
#          ('Laurel and Linden avenues', 'Hempstead', 'New York'): 1,
#          ('9100 block of Sparklewood Court', 'Las Vegas', 'Nevada'): 1,
#          ('6th Street and Stewart Avenue', 'Kansas City', 'Kansas'): 1,
#          ('3900 block of Graceland Avenue', 'Indianapolis', 'Indiana'): 2,
#          ('Beaver Slide Loop', 'Lewis And Clark (county)', 'Montana'): 1,
#          ('Turk and Taylor', 'San Francisco', 'California'): 1,
#          ('947 West Lake Mead Boulevard', 'Las Vegas', 'Nevada'): 1,
#          ('3300 block of Bill Gardner Parkway', 'Locust Grove', 'Georgia'): 1,
#          ('1447 Grandville Ave. SW', 'Grand Rapids', 'Michigan'): 1,
#          ('2600 block of Wealthy Street ', 'Mobile', 'Alabama'): 1,
#          ('13859 8 Mile Road', 'Warren', 'Michigan'): 1,
#          ('201 Neel St', 'Bluefield', 'West Virginia'): 3,
#          ('2600 block of Arthurs Court', 'Clarksville', 'Tennessee'): 1,
#          ('4300 Sunset Road', 'Charlotte', 'North Carolina'): 1,
#          ('5300 block of South Maryland', 'Chicago', 'Illinois'): 1,
#          ('N/A', 'Berlin', 'Georgia'): 1,
#          ('700 block of East Hilton Street',
#           'Philadelphia',
#           'Pennsylvania'): 1,
#          ('3800 block of 10th Street Court East', 'Bradenton', 'Florida'): 1,
#          ('200 block of West Hudson Street', 'Elmira', 'New York'): 3,
#          ('Gilbert Drive and Washington Street', 'Shreveport', 'Louisiana'): 1,
#          ('Law Street', 'Pelzer', 'South Carolina'): 1,
#          ('2405 North Flora', 'Peoria', 'Illinois'): 1,
#          ('5321 NW 27th Place', 'Hollywood', 'Florida'): 1,
#          ('500 block of East 28th Street', 'Pine Bluff', 'Arkansas'): 1,
#          ('318 Maujer St', 'Brooklyn', 'New York'): 1,
#          ('5700 block of Port Lillian Dr.', 'Indianapolis', 'Indiana'): 1,
#          ('South Van Buren and Elm streets', 'Wilmington', 'Delaware'): 1,
#          ('4333 Home Avenue', 'San Diego', 'California'): 1,
#          ('200 block of Elm Street', 'Bessemer', 'Alabama'): 1,
#          ('32-14 106th St', 'Queens', 'New York'): 1,
#          ('500 block of North Fairmont Avenue', 'Kankakee', 'Illinois'): 1,
#          ('5500 block of West Corcoran', 'Chicago', 'Illinois'): 1,
#          ('340 1st Avenue North',
#           'Saint Petersburg (St Petersburg)',
#           'Florida'): 1,
#          ('County Road 237', 'Laurel', 'Mississippi'): 2,
#          ('3000 block of Woodley Road', 'Montgomery', 'Alabama'): 1,
#          ('511 N. Miller St.', 'Toledo', 'Ohio'): 1,
#          ('N/A', 'Lawrenceburg', 'Tennessee'): 2,
#          ('3400 Richmond Parkway', 'Richmond', 'California'): 1,
#          ('200 block of South Kostner Avenue', 'Chicago', 'Illinois'): 1,
#          ('800 block of East Crosier Street', 'Akron', 'Ohio'): 1,
#          ('1300 block of Reddington Lane', 'Norcross', 'Georgia'): 1,
#          ('224 E. Vantana Court', 'Salt Lake City (Murray)', 'Utah'): 1,
#          ('1300 block of South Millard', 'Chicago', 'Illinois'): 1,
#          ('3619 Falling Springs Road', 'Columbia', 'South Carolina'): 1,
#          ('Pinebay Circle N', 'Jacksonville', 'Florida'): 1,
#          ('Belmont Drive', 'Lexington', 'Kentucky'): 1,
#          ('600 block of North Long', 'Chicago', 'Illinois'): 1,
#          ('1580 Aqua Road', 'Madison', 'Georgia'): 1,
#          ('1000 Ross Municipal Dr', 'Saylorsburg', 'Pennsylvania'): 1,
#          ('3700 block of Eureka Drive', 'Studio City', 'California'): 1,
#          ('3100 block of Prial Avenue', 'Rockford', 'Illinois'): 1,
#          ('Cedar Lake Road', 'Hodgen', 'Oklahoma'): 1,
#          ('2700 block of Hydes Ferry Road', 'Nashville', 'Tennessee'): 1,
#          ('Arlington Street', 'Haverhill', 'Massachusetts'): 1,
#          ('County Road 1610', 'Pontotoc (county)', 'Oklahoma'): 3,
#          ('400 block of East Markison Avenue', 'Columbus', 'Ohio'): 3,
#          ('4300 Flat Shoals Road', 'Union City', 'Georgia'): 1,
#          ('5200 block of Evergreen Forest Way',
#           'Raleigh',
#           'North Carolina'): 1,
#          ('7800 block of Clyo Circle', 'Savannah', 'Georgia'): 1,
#          ('6800 block of South Calumet', 'Chicago', 'Illinois'): 1,
#          ('B St SW and 6th St', 'Ardmore', 'Oklahoma'): 1,
#          ('300 block of De Haven St', 'Houston', 'Texas'): 2,
#          ('2868 Bamberg Road', 'Orangeburg', 'South Carolina'): 1,
#          ('Destrehan Avenue and River Road', 'Harvey', 'Louisiana'): 2,
#          ('600 block of East 100th Place',
#           'Chicago (Roseland)',
#           'Illinois'): 1,
#          ('200 block of New Moon Lane', 'Bessemer City', 'North Carolina'): 3,
#          ('22nd Street and Forest Avenue', 'Niagara Falls', 'New York'): 1,
#          ('2900 block of Michigan Avenue', 'Saint Cloud', 'Florida'): 2,
#          ('5200 block of Gulfway Drive', 'Port Arthur', 'Texas'): 1,
#          ('3916 South Hanover Street', 'Baltimore', 'Maryland'): 1,
#          ('5405 N. Lincoln Blvd', 'Oklahoma City', 'Oklahoma'): 1,
#          ('1800 block of Cathy Street', 'San Diego', 'California'): 1,
#          ('Cornwall Ave and Sussex St', 'Buffalo', 'New York'): 1,
#          ('Golden Park and Sandy Park', 'Memphis', 'Tennessee'): 1,
#          ('15th and Castle Streets', 'Wilmington', 'North Carolina'): 1,
#          ('1300 block of May Street', 'Danville', 'Illinois'): 1,
#          ('15200 block of Hazelridge', 'Detroit', 'Michigan'): 1,
#          ('194 C Mays Rd', 'Greensburg', 'Kentucky'): 1,
#          ('Straus Rd and McAlister St', 'Cedar Hill', 'Texas'): 1,
#          ('1900 block of Choctaw St', 'New Orleans', 'Louisiana'): 1,
#          ('1100 block of Lafayette County Road 41', 'Buckner', 'Arkansas'): 1,
#          ('515 W Exchange St', 'Akron', 'Ohio'): 1,
#          ('19000 block of Puget Lane', 'Spring', 'Texas'): 2,
#          ('21st Street and Medary Avenue', 'Philadelphia', 'Pennsylvania'): 1,
#          ('N/A', 'Orange County', 'Florida'): 1,
#          ('N/A', 'Woodward', 'Oklahoma'): 1,
#          ('Bardin Rd and S Providence Church Rd', 'Palatka', 'Florida'): 1,
#          ('300 block of Breckenridge Street', 'Texarkana', 'Texas'): 2,
#          ('1200 block of West 32nd Street',
#           'Palm Beach Gardens (Riviera Beach)',
#           'Florida'): 3,
#          ('2900 block of Perris Boulevard', 'Perris', 'California'): 1,
#          ('4608 Bradley Street', 'Baton Rouge', 'Louisiana'): 1,
#          ('Highway C', 'Senath', 'Missouri'): 1,
#          ('3562 320th Ave', 'Foxhome', 'Minnesota'): 1,
#          ('West Chestnut Street', 'Washington', 'Pennsylvania'): 1,
#          ('7395 Highway 105', 'Beaumont', 'Texas'): 1,
#          ('3700 block of West 13th Street', 'Chicago', 'Illinois'): 2,
#          ('Lynn and Michigan', 'Indianapolis', 'Indiana'): 1,
#          ('600 block of Hulbert Avenue', 'Dayton', 'Ohio'): 1,
#          ('6900 block of North Starr Road', 'Campbellsburg', 'Indiana'): 3,
#          ('559 Fifth Avenue', 'Wallkill', 'New York'): 1,
#          ('1100 block of East 15th Street', 'Jacksonville', 'Florida'): 1,
#          ('N/A', 'Drew (county)', 'Arkansas'): 1,
#          ('1159 Main St', 'Johnstown', 'Pennsylvania'): 2,
#          ('900 block of East Simcoe Street', 'Lafayette', 'Louisiana'): 1,
#          ('E. Natures Trail', 'Itasca (county)', 'Minnesota'): 1,
#          ('2800 block of  Venetian Drive', 'Key West', 'Florida'): 1,
#          ('1025 Blue Ridge Road', 'Raleigh', 'North Carolina'): 1,
#          ('300 block of Andover Road', 'Billerica', 'Massachusetts'): 1,
#          ('S. 248th Street and Lake Fenwick Road', 'Kent', 'Washington'): 1,
#          ('Cleveland Avenue and Old Hapeville Road', 'Atlanta', 'Georgia'): 1,
#          ('1200 block of 40th Street', 'Silver City', 'New Mexico'): 1,
#          ('348 S Orange Ave', 'Newark', 'New Jersey'): 1,
#          ('Broad River', 'Madison County', 'Georgia'): 1,
#          ('East 70th Street and Wade Park Avenue', 'Cleveland', 'Ohio'): 1,
#          ('Monroe Street', 'Little Rock', 'Arkansas'): 1,
#          ('126 Front Street', 'Dowagiac', 'Michigan'): 1,
#          ('2100 block of South Etting Terr',
#           'Philadelphia',
#           'Pennsylvania'): 1,
#          ('3000 block of Miami St', 'Saint Louis', 'Missouri'): 2,
#          ('5100 block of Idaho Street', 'Houston', 'Texas'): 2,
#          ('1300 North Mason Avenue', 'Chicago', 'Illinois'): 1,
#          ('1215 Tuscarawas St W', 'Canton', 'Ohio'): 1,
#          ('2200 block of East 38th Street', 'Cleveland', 'Ohio'): 1,
#          ('2300 block of West McMillan Road',
#           'Fruitland Township',
#           'Michigan'): 1,
#          ('3000 block of West Lexington', 'Chicago', 'Illinois'): 1,
#          ('Plumtree Lane', 'Willingboro', 'New Jersey'): 2,
#          ('200 block of Hampstead Avenue', 'Savannah', 'Georgia'): 1,
#          ('3700 block of Wisconsin', 'Saint Louis', 'Missouri'): 1,
#          ('1000 block of Feliz Drive', 'Bakersfield', 'California'): 1,
#          ('Avenue 208 and Road 148', 'Poplar', 'California'): 1,
#          ('7900 block of Florin Road', 'Sacramento', 'California'): 2,
#          ('6660 Mableton Pkwy SE', 'Mableton', 'Georgia'): 4,
#          ('Impala Drive', 'Colerain Township', 'Ohio'): 1,
#          ('North 3rd and Hamilton Street', 'Newark', 'New Jersey'): 1,
#          ('3800 block of Boston Avenue', 'San Diego', 'California'): 1,
#          ('100 block of East 23rd Street', 'Larose', 'Louisiana'): 1,
#          ('300 block of Eighth Street', 'Pleasant Grove', 'Alabama'): 1,
#          ('12400 block of Admiralty Way', 'Everett', 'Washington'): 2,
#          ('6900 block of South Stewart', 'Chicago (Englewood)', 'Illinois'): 1,
#          ('Conley and 7 Mile', 'Detroit', 'Michigan'): 1,
#          ('3116 Acorn Street', 'Alton', 'Illinois'): 1,
#          ('2 Independent Dr', 'Jacksonville', 'Florida'): 2,
#          ('34th and Meredith', 'Omaha', 'Nebraska'): 1,
#          ('452 Moss Trail', 'Goodlettsville', 'Tennessee'): 2,
#          ('308 6th Avenue North', 'Billings', 'Montana'): 3,
#          ('Van Horne Street', 'Jersey City', 'New Jersey'): 1,
#          ('Marconi St', 'Providence', 'Rhode Island'): 1,
#          ('N/A', 'Wrightsville', 'Georgia'): 1,
#          ('18th St and Main St', 'Jacksonville', 'Florida'): 1,
#          ('8000 block of School Way', 'Kinloch', 'Missouri'): 1,
#          ('Ray Street', 'Saginaw', 'Michigan'): 1,
#          ('I-43', 'Milwaukee (Glendale)', 'Wisconsin'): 1,
#          ('28th Street and Capitol Drive', 'Milwaukee', 'Wisconsin'): 1,
#          ('700 block of Willow Glen Road', 'Alexandria', 'Louisiana'): 1,
#          ('3100 block of Oakland Boulevard NW', 'Roanoke', 'Virginia'): 1,
#          ('24 Libby Lane', 'Jonesboro', 'Georgia'): 2,
#          ('900 block of Pebblestone Drive', 'Durham', 'North Carolina'): 1,
#          ('1800 block of Convent Ave', 'Laredo', 'Texas'): 1,
#          ('2600 block of Forest Hill Boulevard', 'Palm Beach', 'Florida'): 1,
#          ('Booger Hollow Road', 'Dadeville', 'Alabama'): 1,
#          ('6500 block of South Green Street',
#           'Chicago (Englewood)',
#           'Illinois'): 1,
#          ('8200 block of Northwest 10th Street',
#           'Pembroke Pines',
#           'Florida'): 1,
#          ('11000 block of Midland', 'Carlsbad', 'Texas'): 2,
#          ('7th Avenue and 13th Terrace',
#           'Homestead (Florida City)',
#           'Florida'): 1,
#          ('N/A', 'Bethel', 'Alaska'): 2,
#          ('1600 block of West 205th Street', 'Los Angeles', 'California'): 1,
#          ('N/A', 'Lauderdale (county)', 'Mississippi'): 1,
#          ('3727 Ulloa Street', 'New Orleans', 'Louisiana'): 1,
#          ('State Road 408', 'Orlando (Pine Hills)', 'Florida'): 1,
#          ('900 block of Zinnia Avenue', 'Metairie', 'Louisiana'): 1,
#          ('1600 block of Brashear Drive', 'Louisville', 'Kentucky'): 3,
#          ('1629 SW Central Park,', 'Topeka', 'Kansas'): 1,
#          ('60 Glenmore Ave', 'Brooklyn', 'New York'): 1,
#          ('2400 block of F Street', 'Auburn', 'Washington'): 1,
#          ('4500 block of Cabbage Palm Dr', 'Valrico', 'Florida'): 1,
#          ('13412 Crennell Ave', 'Cleveland', 'Ohio'): 1,
#          ('County Road 865', 'Gaylesville', 'Alabama'): 3,
#          ('Treeland Drive', 'Clarksville', 'Tennessee'): 1,
#          ('2600 block of Mesa Drive SE', 'Albuquerque', 'New Mexico'): 1,
#          ('2100 block of Springbrook Lane',
#           'New Orleans (Algiers)',
#           'Louisiana'): 1,
#          ('1212 Forest Circle Drive', 'Corbin', 'Kentucky'): 1,
#          ('N/A', 'Battle Creek', 'Michigan'): 1,
#          ('Sulgar Road', 'Jersey Mills (Pine Creek)', 'Pennsylvania'): 1,
#          ('Broad Ripple Avenue', 'Indianapolis', 'Indiana'): 1,
#          ('311 East Carlton Avenue', 'Elkhart', 'Indiana'): 4,
#          ('13th Street and Jackson Avenue SW', 'Roanoke', 'Virginia'): 1,
#          ('2400 block of East Madison Street', 'Oklahoma City', 'Oklahoma'): 1,
#          ('3100 block of West 64th Street', 'Chicago', 'Illinois'): 1,
#          ('N/A', 'Williston', 'North Dakota'): 3,
#          ('904 West Jefferson Street', 'Kokomo', 'Indiana'): 1,
#          ('West 53rd Street', 'Savannah', 'Georgia'): 1,
#          ('14395 Jefferson Davis Highway', 'Woodford', 'Virginia'): 1,
#          ('N/A', 'Wichita', 'Kansas'): 1,
#          ('102  Zelmer Street', 'Buffalo', 'New York'): 1,
#          ('N/A', 'Orem', 'Utah'): 1,
#          ('105 Lindsey Lee Ln', 'Shelby', 'North Carolina'): 3,
#          ('Rose Garden Drive', 'Baton Rouge', 'Louisiana'): 2,
#          ('2005 Michelham Drive', 'Kingsport', 'Tennessee'): 2,
#          ('51st Avenue and Thomas Road', 'Phoenix', 'Arizona'): 1,
#          ('2100 block of Morton Avenue', 'Elkhart', 'Indiana'): 2,
#          ('3300 block of Aden Street', 'Memphis', 'Tennessee'): 1,
#          ('6201 Newberry Rd', 'Indianapolis', 'Indiana'): 1,
#          ('700 block of Hayes Ave', 'Virginia Beach', 'Virginia'): 1,
#          ('Treva Road', 'Sandston', 'Virginia'): 1,
#          ('1100 block of North Harding Avenue', 'Chicago', 'Illinois'): 1,
#          ('4614 Alrix Drive', 'Orlando', 'Florida'): 2,
#          ('3500 block of Madison Street', 'Riverside', 'California'): 1,
#          ('748 N Madison St', 'Stockton', 'California'): 1,
#          ('975 Red Mile Rd', 'Lexington', 'Kentucky'): 1,
#          ('191 Lake Road', 'Webster', 'New York'): 1,
#          ('400 block of Orchard Avenue', 'Des Moines', 'Iowa'): 1,
#          ('1416 Meadowlane Terrace', 'Fort Worth', 'Texas'): 2,
#          ('420 North Garvin Street', 'Evansville', 'Indiana'): 1,
#          ('10235 Almeda Genoa', 'Houston', 'Texas'): 1,
#          ('Winston Street', 'Redford', 'Michigan'): 2,
#          ('1103 E. Church Street', 'Fort Valley', 'Georgia'): 1,
#          ('209 Neel St', 'Bluefield', 'Virginia'): 1,
#          ('18th Street and Baseline Road', 'Phoenix', 'Arizona'): 1,
#          ('2500 Block of Walnut St',
#           'Harrisburg (Penbrook)',
#           'Pennsylvania'): 1,
#          ('7000 block of Burlingame Boulevard', 'Shreveport', 'Louisiana'): 1,
#          ('1723 E Wayne St', 'Fort Wayne', 'Indiana'): 1,
#          ('9th and Locust', 'Long Beach', 'California'): 1,
#          ('2700 block of Noe Bixby', 'Columbus', 'Ohio'): 3,
#          ('2400 block of Crescent Drive', 'Hazel Crest', 'Illinois'): 1,
#          ('345 Burning Tree Dr', 'Hermitage', 'Tennessee'): 1,
#          ('3300 block of Garden Oaks Drive', 'New Orleans', 'Louisiana'): 2,
#          ('Durham Drive', 'Hedgesville', 'West Virginia'): 2,
#          ('3100 Airport Road', 'Boca Raton', 'Florida'): 1,
#          ('6200 block of Minnock', 'Detroit', 'Michigan'): 1,
#          ('8200 block of South Ingleside', 'Chicago', 'Illinois'): 1,
#          ('414 E Hill Ave', 'Valdosta', 'Georgia'): 1,
#          ('Bluehaven Ct', 'San Diego', 'California'): 1,
#          ('4200 block of S Talman', 'Chicago', 'Illinois'): 1,
#          ('2272 Scottwood Ave', 'Toledo', 'Ohio'): 1,
#          ('1600 block of Watervliet Avenue', 'Dayton', 'Ohio'): 1,
#          ('700 Block of  Central Street', 'Shreveport', 'Louisiana'): 1,
#          ('Baxter Street', 'Enterprise', 'Alabama'): 1,
#          ('1575 Galena Street', 'Aurora', 'Colorado'): 4,
#          ('6200 block of Eads Street', 'New Orleans', 'Louisiana'): 1,
#          ('4500 block of West Congress Parkway', 'Chicago', 'Illinois'): 3,
#          ('Westhaven Drive', 'Oshkosh', 'Wisconsin'): 1,
#          ('954 Highland Ave', 'Montgomery', 'Alabama'): 1,
#          ('Englestad Street', 'North Las Vegas', 'Nevada'): 1,
#          ('1300 block of South Shirley Oaks Drive',
#           'Jacksonville',
#           'Florida'): 3,
#          ('8000 block of South Escanaba', 'Chicago', 'Illinois'): 1,
#          ('14000 block of Glenside Road', 'Cleveland', 'Ohio'): 1,
#          ('Fred Connor Street', 'Avon Park', 'Florida'): 1,
#          ('1260 Allston Way', 'Berkeley', 'California'): 1,
#          ('500 block of Freeman Drive', 'Kansas City', 'Kansas'): 1,
#          ('Pvt Rd 934', 'Georgetown', 'Texas'): 1,
#          ('1501 Dodds Ave.', 'Chattanooga', 'Tennessee'): 1,
#          ('Bergen Street', 'Paterson', 'New Jersey'): 1,
#          ('8500 block of South Carpenter', 'Chicago', 'Illinois'): 1,
#          ('221 SE Lawrence St', 'Topeka', 'Kansas'): 1,
#          ('5200 West Quincy Street', 'Chicago', 'Illinois'): 1,
#          ('3060 Sandpiper Avenue',
#           'Grand Junction (Fruitvale)',
#           'Colorado'): 3,
#          ('N/A', 'Spotsylvania Courthouse', 'Virginia'): 1,
#          ('400 block of Mississippi Avenue', 'Joliet', 'Illinois'): 1,
#          ('5200 block of W. Fullerton Avenue', 'Chicago', 'Illinois'): 1,
#          ('Wallace Avenue', 'Bronx', 'New York'): 1,
#          ('2806 Long Lane', 'Albuquerque', 'New Mexico'): 1,
#          ('1600 block of West Missouri Avenue', 'Phoenix', 'Arizona'): 3,
#          ('4800 block of South Ada', 'Chicago', 'Illinois'): 1,
#          ('Wells St', 'Atoka', 'Oklahoma'): 1,
#          ('561 N. Center Street', 'Salt Lake City', 'Utah'): 1,
#          ('700 block of 35th Street', 'Newport News', 'Virginia'): 1,
#          ('4200 block of Cloverfield Trail', 'Florissant', 'Missouri'): 2,
#          ('29th Street and Renshaw Avenue', 'East Saint Louis', 'Illinois'): 1,
#          ('2100 block of Florida Avenue', 'Savannah', 'Georgia'): 1,
#          ('1900 block of West Boulevard', 'Charlotte', 'North Carolina'): 1,
#          ('3700 block of 37th Street', 'Milwaukee', 'Wisconsin'): 1,
#          ('45 Living Oak Lane', 'Winchester', 'Tennessee'): 1,
#          ('351 McLean Street', 'Wilkes Barre', 'Pennsylvania'): 1,
#          ('Anna Street', 'Elizabeth', 'New Jersey'): 1,
#          ('N/A', 'Cotton Plant', 'Arkansas'): 2,
#          ('100 block of Honey Lane', 'Estill Springs', 'Tennessee'): 1,
#          ('2600 block of Cedar and 2600 block of 18th Avenue South',
#           'Minneapolis',
#           'Minnesota'): 1,
#          ('Natomas', 'Sacramento', 'California'): 1,
#          ('Pine Tract Road', 'Butler (county)', 'Pennsylvania'): 1,
#          ('215 4th St.', 'Columbus', 'Georgia'): 1,
#          ('6800 block of Buck Trail Dr', 'Harrison', 'Tennessee'): 1,
#          ('5600 block of Rustic Way', 'Louisville', 'Kentucky'): 2,
#          ('3541 South California', 'Chicago', 'Illinois'): 2,
#          ('12th Street and College Street', 'Charlotte', 'North Carolina'): 1,
#          ('116 Lathrop Avenue', 'River Forest', 'Illinois'): 1,
#          ('Mark Twain Drive and Ebbetts Way', 'Antioch', 'California'): 1,
#          ('Terrace Lane', 'Altamonte Springs', 'Florida'): 1,
#          ('500 block of West College Street', 'Oberlin', 'Ohio'): 1,
#          ('4669 Bell Road SE', 'Conyers', 'Georgia'): 1,
#          ('400 block of Fairview Drive', 'Dallas', 'Georgia'): 3,
#          ('1200 block of Rosedale Drive', 'Dayton', 'Ohio'): 2,
#          ('N/A', 'Mc Farland', 'California'): 1,
#          ('1400 block of West 84th Street', 'Chicago', 'Illinois'): 1,
#          ('Jim Hanna Lane', 'Anson County', 'North Carolina'): 1,
#          ('3500 block of Wayne Avenue', 'Baton Rouge', 'Louisiana'): 2,
#          ('500 block of Kentucky Street', 'Helena', 'Arkansas'): 1,
#          ('60th Street and Baltimore Avenue',
#           'Philadelphia',
#           'Pennsylvania'): 1,
#          ('12015 Southwest Walden Lane', 'Beaverton', 'Oregon'): 1,
#          ('300 block of South Seventh Street', 'Richmond', 'Indiana'): 1,
#          ('26th Street and Avenue J', 'Council Bluffs', 'Iowa'): 1,
#          ('1643 Cleveland Rd', 'Sandusky', 'Ohio'): 1,
#          ('Buck Creek Road', 'Bokoshe', 'Oklahoma'): 2,
#          ('1000 block of North Francisco Avenue', 'Chicago', 'Illinois'): 2,
#          ('16000 block of Mark Twain Street', 'Detroit', 'Michigan'): 1,
#          ('6000 block of Elm Street', 'Houston', 'Texas'): 2,
#          ('5700 block of South Racine', 'Chicago (Englewood)', 'Illinois'): 1,
#          ('Westchester Dr and Brookdale Dr', 'Nashville', 'Tennessee'): 1,
#          ('2000 block of South Western Avenue', 'Chicago', 'Illinois'): 1,
#          ('2000 block of West 68th Place',
#           'Chicago (Englewood)',
#           'Illinois'): 1,
#          ('850 Spartan Avenue', 'Berthoud', 'Colorado'): 1,
#          ('200 block of North Mount Street', 'Baltimore', 'Maryland'): 1,
#          ('8600 block of Ardith Drive', 'Sacramento', 'California'): 2,
#          ('1600 block of South Ninth', 'Lebanon', 'Oregon'): 1,
#          ('East 131st', 'Cleveland', 'Ohio'): 2,
#          ('1033 Whitaker', 'Memphis', 'Tennessee'): 1,
#          ('4000 block of East Texas 6', 'Alvin', 'Texas'): 2,
#          ('600 block of Woodlawn Avenue', 'Rockford', 'Illinois'): 1,
#          ('9000 South Isom Road', 'Casa Grande', 'Arizona'): 1,
#          ('Boulder Creek Road', 'Deer Lodge', 'Montana'): 2,
#          ('525 E Harrison Dr', 'Avondale', 'Arizona'): 3,
#          ('84th and Q', 'Omaha', 'Nebraska'): 1,
#          ('5700 block of South Morgan', 'Chicago (Englewood)', 'Illinois'): 1,
#          ('2201 Moore Road; Dalton Farmer Drive; County Road 664',
#           'Jonesboro',
#           'Arkansas'): 1,
#          ('1717 Plymouth Avenue North', 'Minneapolis', 'Minnesota'): 1,
#          ('600 block of N. Franklin Street', 'Lancaster', 'Pennsylvania'): 1,
#          ('1094 Misty Hollow Lane', 'Tarpon Springs', 'Florida'): 2,
#          ('County Road 9055', 'Dekalb (county)', 'Georgia'): 1,
#          ('1700 block of Yarborough Street', 'Montgomery', 'Alabama'): 2,
#          ('5300 block of Mossfield Street', 'Pittsburgh', 'Pennsylvania'): 1,
#          ('299th Avenue and Roosevelt', 'Tonopah', 'Arizona'): 1,
#          ('200 block of South Bancroft Street', 'San Diego', 'California'): 1,
#          ('North Market Street and North Spring Avenue',
#           'Saint Louis',
#           'Missouri'): 1,
#          ('3634 Shenandoah Ave NW', 'Roanoke', 'Virginia'): 1,
#          ('7201 Aaron Aronov Drive', 'Fairfield', 'Alabama'): 1,
#          ('Woods Brothers Road and Segunada Road',
#           'Rio Grande City',
#           'Texas'): 1,
#          ('3200 block of Colfax Avenue', 'Pueblo', 'Colorado'): 1,
#          ('Airport Road', 'Indiana', 'Pennsylvania'): 3,
#          ('3400 block of Beech Street', 'Rowlett', 'Texas'): 1,
#          ('1000 Block of Myers St', 'Sikeston', 'Missouri'): 1,
#          ('Toddville Road', 'Charlotte', 'North Carolina'): 1,
#          ('1100 block of highway 31', 'Kilgore', 'Texas'): 1,
#          ('3100 block of North Harding Street', 'Indianapolis', 'Indiana'): 1,
#          ('700 block of S Fountain', 'Wichita', 'Kansas'): 2,
#          ('1600 block of North Avenue', 'Port Norris', 'New Jersey'): 1,
#          ('Strathmoor Street', 'Detroit', 'Michigan'): 1,
#          ('2555 N. Glenstone', 'Springfield', 'Missouri'): 1,
#          ('3500 block of North Temple Avenue', 'Indianapolis', 'Indiana'): 1,
#          ('4400 block of West Wilcox Street', 'Chicago', 'Illinois'): 1,
#          ('N/A', 'Delta', 'Missouri'): 1,
#          ('6600 South Michigan Ave', 'Chicago', 'Illinois'): 1,
#          ('9100 block of Wine Cellar Avenue', 'Las Vegas', 'Nevada'): 1,
#          ('Rancho Drive 3400 block ', 'Las Vegas', 'Nevada'): 1,
#          ('149 Ottawa Ave', 'Muskego', 'Michigan'): 1,
#          ('ND 53', 'Butte', 'North Dakota'): 1,
#          ('West Prospect Avenue', 'Pittsburgh', 'Pennsylvania'): 1,
#          ('7724 Ludington Lane', 'Birmingham', 'Alabama'): 1,
#          ('2000 block East John Avenue', 'Saint Louis', 'Missouri'): 1,
#          ('6900 block of Forrest Terrace Drive',
#           'Hyattsville (Landover)',
#           'Maryland'): 1,
#          ('3300 Bridge House Street', 'Las Vegas', 'Nevada'): 1,
#          ('7300 block of Enchanted Creek Drive', 'Cypress', 'Texas'): 1,
#          ('1500 block Avalon Avenue', 'Albany', 'Georgia'): 1,
#          ('57-091 Kamehameha Hwy', 'Kahuku', 'Hawaii'): 1,
#          ('Chadwick Drive and Richfield Lane', 'Fort Wayne', 'Indiana'): 1,
#          ('Second Avenue', 'Conway', 'South Carolina'): 1,
#          ('12339 Cuming', 'Omaha', 'Nebraska'): 1,
#          ('North 15th Street and West Meinecke Avenue',
#           'Milwaukee',
#           'Wisconsin'): 1,
#          ('340 Rowe St.', 'Spartanburg', 'South Carolina'): 2,
#          ('260 Oxford Drive', 'Winchester', 'Kentucky'): 1,
#          ('13600 block of 12th Street Northeast',
#           'Lake Stevens',
#           'Washington'): 1,
#          ('3000 block of South La Cholla', 'Tucson', 'Arizona'): 1,
#          ('1900 block of West 11th', 'Jacksonville', 'Florida'): 1,
#          ('Dorris Drive', 'Elma', 'New York'): 1,
#          ('8900 block of Yvonne Ave', 'Baltimore', 'Maryland'): 1,
#          ('3200 block of North Sheridan Street',
#           'Philadelphia',
#           'Pennsylvania'): 1,
#          ('6000 block of Thekla Ave', 'Saint Louis', 'Missouri'): 1,
#          ('673 Flatbush Avenue', 'Brooklyn', 'New York'): 1,
#          ('Timber Knoll Drive', 'Chattanooga', 'Tennessee'): 1,
#          ('8300 block of South Halsted Street', 'Chicago', 'Illinois'): 1,
#          ('7208 US 68', 'West Liberty', 'Ohio'): 1,
#          ('Augustine Maze Street', 'Franklin', 'Louisiana'): 1,
#          ('600 block of Moccasin Gap Road', 'Jackson', 'Georgia'): 1,
#          ('200 block of Colt Drive', 'Waxahachie', 'Texas'): 1,
#          ('N/A', 'Brown (county)', 'South Dakota'): 1,
#          ('4115 N. Tryon Street', 'Charlotte', 'North Carolina'): 2,
#          ('N/A', 'Baton Rouge', 'Louisiana'): 2,
#          ('351 60th Avenue', 'Meridian', 'Mississippi'): 1,
#          ('Liberty Street and Benkard Avenue', 'Newburgh', 'New York'): 1,
#          ('Bellows and Baker Street W.', 'Saint Paul', 'Minnesota'): 1,
#          ('820 W Airline Hwy', 'La Place (Laplace)', 'Louisiana'): 1,
#          ('10600 Block of Douglas Drive SW', 'Lakewood', 'Washington'): 1,
#          ('13000 block of North Rosser Road', 'Tuscaloosa', 'Alabama'): 2,
#          ('Cutter Road', 'Douglas', 'Georgia'): 1,
#          ('County Road 9055', 'Albertville', 'Alabama'): 1,
#          ('5143 Kingston Drive', 'Wichita Falls', 'Texas'): 1,
#          ('3200 block of Chandler Hwy', 'Tyler', 'Texas'): 2,
#          ('1200 block of 22nd Ave. N.', 'Minneapolis', 'Minnesota'): 1,
#          ('4900 block of South First Street', 'Louisville', 'Kentucky'): 1,
#          ('1100 block of Wilkinson Street', 'Shreveport', 'Louisiana'): 2,
#          ('2nd Avenue South and South Main Street',
#           'Seattle',
#           'Washington'): 1,
#          ('7000 block of South Harper Avenue', 'Chicago', 'Illinois'): 1,
#          ('3806 Adkins Road', 'Atlanta', 'Georgia'): 1,
#          ('Garden Street', 'Montgomery', 'Alabama'): 1,
#          ('5000 block of Durant Ave', 'Saint Louis', 'Missouri'): 1,
#          ('861 W. 36th Street', 'Norfolk', 'Virginia'): 1,
#          ('Calumet Avenue and East 18th Street', 'Chicago', 'Illinois'): 1,
#          ('NW 25th Ave and 102nd St', 'Miami', 'Florida'): 1,
#          ('29200 block of Garnet', 'Riverside (county)', 'California'): 1,
#          ('Skywae Drive', 'Columbus', 'Ohio'): 1,
#          ('400 block of Stuyvesant Avenue', 'Trenton', 'New Jersey'): 1,
#          ('2331 Vixen Street NW', 'North Canton', 'Ohio'): 1,
#          ('100 Drexel Place', 'Charleston (Cross Lanes)', 'West Virginia'): 1,
#          ('1140 Umpqua College Rd', 'Roseburg', 'Oregon'): 1,
#          ('2400 block of McKinley Road', 'Columbia', 'South Carolina'): 1,
#          ('Fountain Avenue', 'Brooklyn', 'New York'): 1,
#          ('300 W 1st St', 'Alturas', 'California'): 1,
#          ('123 Old Chigger Trail', 'Franklin (Watauga)', 'North Carolina'): 1,
#          ('441 N Perry St', 'Pontiac', 'Michigan'): 1,
#          ('5902 Storer Ave', 'Cleveland', 'Ohio'): 1,
#          ('4100 block of East 16th Street', 'Indianapolis', 'Indiana'): 1,
#          ('205 Greenville Blvd SW', 'Greenville', 'North Carolina'): 1,
#          ('2514 Mount Moriah', 'Memphis', 'Tennessee'): 1,
#          ('102 Baltic Haus Drive', 'Baltic', 'Ohio'): 1,
#          ('2136 North Lobdell Avenue', 'Baton Rouge', 'Louisiana'): 1,
#          ('200 block of 12th Street', 'Springfield', 'Illinois'): 1,
#          ('Clinard Road', 'Springfield', 'Tennessee'): 1,
#          ('91 West Street', 'Manchester', 'New Hampshire'): 1,
#          ('12000 block of Sherman Drive', 'Charlotte', 'North Carolina'): 1,
#          ('2800 block of Hope Street', 'Philadelphia', 'Pennsylvania'): 1,
#          ('638 ENE Loop 323', 'Tyler', 'Texas'): 1,
#          ('1500 West Main Street', 'Loveland', 'Ohio'): 1,
#          ('2700 Block of Glen Mawr St', 'Pittsburgh', 'Pennsylvania'): 1,
#          ('4611 E Whiteway Drive', 'Tampa', 'Florida'): 1,
#          ('Linden and S. Van Buren', 'Wilmington', 'Delaware'): 1,
#          ('2600 block of Kenview Road South', 'Columbus', 'Ohio'): 2,
#          ('8000 block of NW 14th Ave', 'Miami', 'Florida'): 2,
#          ('2501 Carter Homestead Rd.', 'Vancleave', 'Mississippi'): 1,
#          ('3262 Tulsa Court', 'Cincinnati', 'Ohio'): 1,
#          ('3162 Johnson Drive', 'Appling', 'Georgia'): 1,
#          ('6300 block of Dardanella Ave', 'Saint Louis', 'Missouri'): 1,
#          ('700 block of Oakley Avenue', 'Rockford', 'Illinois'): 1,
#          ('2300 W 7th St', 'Chester', 'Pennsylvania'): 1,
#          ('400 block of Vandegrift Boulevard', 'Oceanside', 'California'): 3,
#          ('1500 block of Porter Road', 'Nashville', 'Tennessee'): 1,
#          ('1021 High Point St', 'Randleman', 'North Carolina'): 1,
#          ('300 block of West 2nd Street', 'San Pedro', 'California'): 2,
#          ('3600 block of Highway 80 W', 'Tallulah', 'Louisiana'): 1,
#          ('1,000 block of FM 2105', 'San Angelo', 'Texas'): 1,
#          ('2600 East Gregory Boulevard', 'Kansas City', 'Missouri'): 1,
#          ('5000 block of Drew Avenue North',
#           'Minneapolis (Brooklyn Center)',
#           'Minnesota'): 1,
#          ('961 King Mill Road', 'Mcdonough', 'Georgia'): 3,
#          ('Lowry Avenue N. and Penn Avenue N.', 'Minneapolis', 'Minnesota'): 2,
#          ('N/A', 'Del Rio', 'Texas'): 1,
#          ('22-04 Collier Avenue', 'Arverne (Queens)', 'New York'): 1,
#          ('Hudson Chapel Road', 'Catawba', 'North Carolina'): 1,
#          ('Upton and North Poe', 'San Angelo', 'Texas'): 1,
#          ('300 block of Vintage Road', 'Albany', 'Georgia'): 1,
#          ('700 block of North St. Louis Avenue', 'Chicago', 'Illinois'): 1,
#          ('2106 W. 4750 South', 'Roy', 'Utah'): 1,
#          ('82 Chester Place', 'Yonkers', 'New York'): 1,
#          ('20549 Southwest 93rd Avenue', 'Miami (Cutler Bay)', 'Florida'): 1,
#          ('90 Worthington St.', 'Springfield', 'Massachusetts'): 1,
#          ('2nd St Southwest', 'Perham', 'Minnesota'): 1,
#          ('400 block of Lowell Avenue', 'Campbellsville', 'Kentucky'): 1,
#          ('2300 Block of Skyview Lane', 'Colorado Springs', 'Colorado'): 1,
#          ('400 block of McCloud Avenue', 'Stockton', 'California'): 1,
#          ('Germann Road and Alma School Road', 'Chandler', 'Arizona'): 1,
#          ('400 block of East Thomas Street', 'Atlanta', 'Texas'): 1,
#          ('200 block of Bonnymede Road', 'Pueblo', 'Colorado'): 1,
#          ('4985 S. Stockton Ave', 'Salt Lake City (Kearns)', 'Utah'): 1,
#          ('Northwest Fourth Street and Eighth Avenue ',
#           'Homestead',
#           'Florida'): 1,
#          ('15 Sunflower Circle', 'Burlington', 'New Jersey'): 1,
#          ('700-block of East McHaney Drive', 'Blytheville', 'Arkansas'): 1,
#          ('45th Avenue and National Street', 'Corona (Queens)', 'New York'): 1,
#          ('240 Woodland Street', 'Bristol', 'Connecticut'): 1,
#          ('4700 block of Guerley Road', 'Cincinnati (Price Hill)', 'Ohio'): 3,
#          ('3182 Airport Road', 'Barre (Berlin)', 'Vermont'): 1,
#          ('8600 block of South Maryland Avenue', 'Chicago', 'Illinois'): 1,
#          ('300 block Fairburn Road SW', 'Atlanta', 'Georgia'): 1,
#          ('4600 block of Downman Road', 'New Orleans', 'Louisiana'): 1,
#          ('3100 block of Sunshine Avenue', 'Cincinnati (Westwood)', 'Ohio'): 1,
#          ('3600 block of Altadena Avenue', 'San Diego', 'California'): 1,
#          ('14000 block of Hope Street', 'Garden Grove', 'California'): 1,
#          ('514 E 156th St', 'Bronx', 'New York'): 1,
#          ('2800 block of South Central Park', 'Chicago', 'Illinois'): 2,
#          ('122 Pierpont Avenue', 'Salt Lake City', 'Utah'): 1,
#          ('39 Montego Circle', 'Riverdale', 'Georgia'): 1,
#          ('8300 block of Shoal Creek', 'San Antonio', 'Texas'): 1,
#          ('Welcome Home Church Road', 'Horton', 'Alabama'): 3,
#          ('1743 Mitchell Rd.', 'Tupelo', 'Mississippi'): 1,
#          ('616 E. 52nd Street', 'Brooklyn', 'New York'): 1,
#          ('1000 block of Blossom Lane', 'Benton Harbor', 'Michigan'): 1,
#          ('800 block of Dogwood Avenue', 'Lemoore', 'California'): 3,
#          ('Fern Street and Olive Street', 'New Orleans', 'Louisiana'): 1,
#          ('1200 block of Lee Road 83', 'Auburn', 'Alabama'): 1,
#          ('100 block of Bourbon Street', 'New Orleans', 'Louisiana'): 1,
#          ('2900 block of La Salle Drive', 'Concord', 'California'): 1,
#          ('West Bradford Road', 'Midland', 'Michigan'): 1,
#          ('1400 block of Dewees Drive', 'Memphis', 'Tennessee'): 1,
#          ('9700 block of Shady Tree Ln', 'Houston', 'Texas'): 3,
#          ('700 block of Mulberry Street', 'Millville', 'New Jersey'): 1,
#          ('1846 Western Ave', 'Guilderland', 'New York'): 2,
#          ('1217 West Fayette Street', 'Syracuse', 'New York'): 1,
#          ('85 Saint John St', 'New Haven', 'Connecticut'): 1,
#          ('1800 block of South Lawndale', 'Chicago', 'Illinois'): 1,
#          ('Stuyvesant and Hoffman avenues', 'Trenton', 'New Jersey'): 1,
#          ('13450 N.W. 30th Ave', 'Opa Locka', 'Florida'): 1,
#          ('12536 Tinsley Cir', 'Tampa', 'Florida'): 3,
#          ('509 N. Chestnut Street', 'Tallulah', 'Louisiana'): 1,
#          ('7550 Dorchester Road', 'North Charleston', 'South Carolina'): 1,
#          ('Grove Street', 'Brooklyn', 'New York'): 1,
#          ('N/A', 'Roseville', 'California'): 1,
#          ('2400 block of Martin Luther King Boulevard',
#           'Flint',
#           'Michigan'): 1,
#          ('13400 block of Crennell Avenue', 'Cleveland', 'Ohio'): 1,
#          ('114 Pershing Court', 'Uniontown', 'Pennsylvania'): 1,
#          ('6000 block of High Point Drive SW', 'Seattle', 'Washington'): 2,
#          ('Conley Street and South Ivey Lane', 'Orlando', 'Florida'): 1,
#          ('1500 block of E. 9th Street', 'Stockton', 'California'): 1,
#          ('200 block of Newton Street', 'New Orleans', 'Louisiana'): 1,
#          ('44th Street and Southern Avenue', 'Phoenix', 'Arizona'): 1,
# ...
#           'North Carolina'): 1,
#          ('3100 block of North Rosewood Street',
#           'Philadelphia',
#           'Pennsylvania'): 1,
#          ('4271 Sidco Drive', 'Nashville', 'Tennessee'): 1,
#          ('200 block of  Brownsville Road',
#           'Pittsburgh (Mount Oliver)',
#           'Pennsylvania'): 2,
#          ('East 13th Avenue', 'Columbus', 'Ohio'): 1,
#          ('100 block of Warren Avenue', 'Buffalo', 'New York'): 1,
#          ('2036 Yorkshire Avenue', 'Santa Monica', 'California'): 1,
#          ('Bartlett and Fuller', 'Brockton', 'Massachusetts'): 1,
#          ('175 Willow Street', 'Yonkers', 'New York'): 1,
#          ('W Michael Dr and Oxford Dr',
#           'Oklahoma City (Midwest City)',
#           'Oklahoma'): 1,
#          ('5800 Block of Attaway Street', 'Shreveport', 'Louisiana'): 3,
#          ('2600 Douglas Place SE', 'Washington', 'District of Columbia'): 1,
#          ('200 block of Cedar Street', 'Vacaville', 'California'): 1,
#          ('400 block of Pecan Avenue', 'Crosby', 'Texas'): 1,
#          ('Robinwood Drive', 'Aiken', 'South Carolina'): 3,
#          ('6718 Cold River Road', 'Cuttingsville (Shrewsbury)', 'Vermont'): 1,
#          ('4006 NW 417th Street', 'Woodland', 'Washington'): 1,
#          ('N/A', 'Union (county)', 'South Carolina'): 2,
#          ('700 block of Craig Street', 'Norfolk', 'Virginia'): 1,
#          ('5800 block of South Sunset Hill Avenue',
#           'Baton Rouge',
#           'Louisiana'): 1,
#          ('28th Street and Camden Avenue', 'Omaha', 'Nebraska'): 1,
#          ('N/A', 'Des Moines', 'Iowa'): 1,
#          ('12526 Ironton Cut Off Road', 'Little Rock', 'Arkansas'): 1,
#          ('700 block of Trinity Court', 'Chapel Hill', 'North Carolina'): 1,
#          ('1400 block of North Massasoit', 'Chicago', 'Illinois'): 1,
#          ('6000 block of Downman Road', 'New Orleans', 'Louisiana'): 3,
#          ('Macon Street and Washington ', 'Durham', 'North Carolina'): 2,
#          ('21630 Southwest 120th Avenue', 'Miami (Goulds)', 'Florida'): 2,
#          ('I 70 and N Broadway St', 'Saint Louis', 'Missouri'): 1,
#          ('648 E. Court St', 'Kankakee', 'Illinois'): 2,
#          ('810 Astor Avenue', 'Bronx', 'New York'): 2,
#          ('6700 block of S. Aberdeen St.',
#           'Chicago (Englewood)',
#           'Illinois'): 3,
#          ('Fourth Street and Hennepin Avenue', 'Minneapolis', 'Minnesota'): 1,
#          ('Grant Avenue', 'Fresno', 'California'): 1,
#          ('San Jacinto at Elgin', 'Houston', 'Texas'): 1,
#          ('5425 Lapalco Boulevard', 'Marrero', 'Louisiana'): 1,
#          ('1020 Orange Ave NE', 'Roanoke', 'Virginia'): 1,
#          ('4300 block of Mellowood Dr', 'Columbia', 'South Carolina'): 2,
#          ('709 Gordon Smith Boulevard', 'Hamilton', 'Ohio'): 2,
#          ('400 block of 14th Street', 'East Moline', 'Illinois'): 1,
#          ('6505 Bannor Lane', 'Peachtree Corners', 'Georgia'): 1,
#          ('N/A', 'Greensboro', 'Alabama'): 1,
#          ('Route 30', 'Box Elder (county)', 'Utah'): 1,
#          ('Irvine Turner Boulevard and West Kinney Street',
#           'Newark',
#           'New Jersey'): 1,
#          ('4600 block of Wildwood Ave', 'Charlotte', 'North Carolina'): 1,
#          ('900 block of McAleer Court', 'Baltimore', 'Maryland'): 1,
#          ('1306 Dewey Ave', 'Rochester', 'New York'): 1,
#          ('11000 block of Highway 71', 'Miller (county)', 'Arkansas'): 3,
#          ('Kentucky 408 East', 'Hickory (Viola)', 'Kentucky'): 3,
#          ('Hawk and Cogswell Street', 'Rockledge', 'Florida'): 1,
#          ('St. Paul Boulevard and Andrews Street', 'Rochester', 'New York'): 1,
#          ('17000 block of North Bank Road', 'Roseburg', 'Oregon'): 1,
#          ('Ballenger Lane', 'Columbia', 'Missouri'): 3,
#          ('9100 Southeast Powell Boulevard', 'Portland', 'Oregon'): 1,
#          ('2973 Middleton Road NW', 'Atlanta', 'Georgia'): 1,
#          ('3577 Dauphin Island Parkway', 'Mobile', 'Alabama'): 1,
#          ('600 block of Canal Street', 'Chubbuck', 'Idaho'): 1,
#          ('County Road 300', 'Pittsboro', 'Mississippi'): 1,
#          ('2000 block of Raspberry Hill Road', 'Las Vegas', 'Nevada'): 1,
#          ('14300 block of Ardmore', 'Detroit', 'Michigan'): 1,
#          ('2400 block of Seaman Street', 'Toledo', 'Ohio'): 3,
#          ('Friendship Trail', 'Menasha', 'Wisconsin'): 2,
#          ('2111 Bragg Street', 'Little Rock', 'Arkansas'): 1,
#          ('500 block of South Alexander Street',
#           'New Orleans',
#           'Louisiana'): 1,
#          ('3006 Holton Avenue', 'Fort Wayne', 'Indiana'): 1,
#          ('100 Terminal Dr', 'Fort Lauderdale', 'Florida'): 1,
#          ('Danielle Lane', 'Lexington', 'Kentucky'): 1,
#          ('300 block of Pearl Street', 'Daytona Beach', 'Florida'): 1,
#          ('1500 block of Homeward Way', 'Summerton', 'South Carolina'): 1,
#          ('619 BIshop Drive', 'Killeen', 'Texas'): 1,
#          ('Douglas Alley and North Virginia Street', 'Reno', 'Nevada'): 1,
#          ('8926 Ledgewood Avenue', 'Stockton', 'California'): 3,
#          ('I 225', 'Aurora', 'Colorado'): 1,
#          ('Lakeview Drive', 'Hartshorne', 'Oklahoma'): 1,
#          ('9500 block of Overton Road', 'Wayne (county)', 'Ohio'): 1,
#          ('Corcoran Road', 'Doe Run', 'Missouri'): 1,
#          ('Lamb Boulevard and Vegas Valley Drive', 'Las Vegas', 'Nevada'): 1,
#          ('2700 block of North Early Street', 'Kansas City', 'Kansas'): 1,
#          ('53 W 79th St', 'Chicago', 'Illinois'): 1,
#          ('3060 Northeast McWilliams Road',
#           'Bremerton (East Bremerton)',
#           'Washington'): 1,
#          ('998 Johnson Corner Road', 'Toombs (county)', 'Georgia'): 1,
#          ('Hughes Avenue', 'Chattanooga', 'Tennessee'): 1,
#          ('Mosshill Lane', 'Willingboro', 'New Jersey'): 1,
#          ('10100 Beechnut St', 'Houston', 'Texas'): 1,
#          ('Bonner Ave', 'Santee', 'South Carolina'): 1,
#          ('1507 Mustang Drive', 'Defiance', 'Ohio'): 1,
#          ('Arlington Avenue', 'Jersey City', 'New Jersey'): 1,
#          ('South Vermont Avenue and West 88th Street',
#           'Los Angeles',
#           'California'): 1,
#          ('100 block of West 38th Street', 'Jacksonville', 'Florida'): 2,
#          ('81st Street and Western Avenue', 'Los Angeles', 'California'): 1,
#          ('15 Swallows Lane', 'Trabuco Canyon', 'California'): 1,
#          ('711 Leaflet Lane', 'Spring', 'Texas'): 1,
#          ('160 Easy Shopping Place', 'Elkhart', 'Indiana'): 1,
#          ('Walton Avenue', 'Saint Louis', 'Missouri'): 1,
#          ('1505 Garden Plaza', 'Columbia', 'South Carolina'): 1,
#          ('Sterling Place', 'Brooklyn', 'New York'): 1,
#          ('2100 block of Arts Street', 'New Orleans', 'Louisiana'): 1,
#          ('Gale and Vermont', 'Indianapolis', 'Indiana'): 3,
#          ('N/A', 'West Sweden', 'Wisconsin'): 1,
#          ('135 Ridge Street', 'New York (Manhattan)', 'New York'): 1,
#          ('2600 block of Greenwood Rd', 'Shreveport', 'Louisiana'): 1,
#          ('Wilson Street', 'Eutaw', 'Alabama'): 1,
#          ('6000 block of Sherwood Glen Way', 'West Palm Beach', 'Florida'): 1,
#          ('6300 block of South Talman',
#           'Chicago (Chicago Lawn)',
#           'Illinois'): 1,
#          ('1100 block of Cleveland Street', 'Hammond', 'Indiana'): 1,
#          ('Reynolds Drive', 'Petaluma', 'California'): 3,
#          ('Poplar and Sutter Streets', 'Stockton', 'California'): 1,
#          ('3400 block of South Parker', 'Indianapolis', 'Indiana'): 1,
#          ('Armwood Court', 'Lexington', 'South Carolina'): 1,
#          ('2300 block of E. Franklin Road', 'Meridian', 'Idaho'): 1,
#          ('200 block of Apollo Street', 'Wedgefield', 'South Carolina'): 1,
#          ('400 block of Elizabeth Street', 'Saltville', 'Virginia'): 1,
#          ('900 block of East 21st Avenue', 'Columbus', 'Ohio'): 1,
#          ('4900 West Race Ave', 'Chicago', 'Illinois'): 1,
#          ('6101 Tullis Drive', 'New Orleans', 'Louisiana'): 1,
#          ('6800 block of South Throop', 'Chicago (Englewood)', 'Illinois'): 1,
#          ('2400 block of River Road', 'Woodburn', 'Indiana'): 1,
#          ('3100 block of General Meyer Avenue', 'New Orleans', 'Louisiana'): 1,
#          ('800 block of B Avenue', 'Norfolk', 'Virginia'): 1,
#          ('4077 Union Hill Road', 'Piketon', 'Ohio'): 1,
#          ('1400 Church Street ', 'Savannah', 'Georgia'): 2,
#          ('North Vine Street', 'Du Quoin', 'Illinois'): 1,
#          ('2220 block of South Broadway Av', 'Gary', 'Indiana'): 1,
#          ('700 block of North Airport Way', 'Stockton', 'California'): 1,
#          ('9611 Airline Highway', 'Baton Rouge', 'Louisiana'): 2,
#          ('4630 Anderson Livsey Lane', 'Snellville', 'Georgia'): 1,
#          ('St. Clair Street', 'Jacksonville', 'Florida'): 1,
#          ('N/A', 'Easton', 'Pennsylvania'): 1,
#          ('600 block of West 47th Street', 'West Palm Beach', 'Florida'): 1,
#          ('5751 N. Kolb Rd', 'Tucson', 'Arizona'): 1,
#          ('1500 block of 4th Street', 'Fort Wayne', 'Indiana'): 1,
#          ('N/A', 'Pollok', 'Texas'): 1,
#          ('2800 block of Daniel Drive', 'Violet', 'Louisiana'): 1,
#          ('1034 Main Street', 'Bean Station', 'Tennessee'): 1,
#          ('2207 Pierce Road', 'Saginaw', 'Michigan'): 1,
#          ('1300 block of Comer Street', 'Savannah', 'Georgia'): 1,
#          ('Monroe and Granberry', 'Saint Louis (Kinloch)', 'Missouri'): 1,
#          ('2000 block of Karanda Street', 'Titusville', 'Florida'): 1,
#          ('4600 block of Columbus Street', 'Virginia Beach', 'Virginia'): 1,
#          ('Lenox Road', 'Brooklyn', 'New York'): 1,
#          ('11900 block of Sproule Avenue', 'San Fernando', 'California'): 1,
#          ('400 block of Lands End Road', 'Fayetteville', 'North Carolina'): 1,
#          ('1300 block of Fruitvale Avenue', 'Oakland', 'California'): 1,
#          ('9541 Flower Street', 'Bellflower', 'California'): 1,
#          ('1214 Labelle St', 'Jacksonville', 'Florida'): 1,
#          ('East 7 Mile Road and Sherwood Street', 'Detroit', 'Michigan'): 1,
#          ('3622 Page Boulevard', 'Saint Louis', 'Missouri'): 1,
#          ('256 Hartford Ave', 'Providence', 'Rhode Island'): 1,
#          ('3500 block of West Roosevelt', 'Chicago', 'Illinois'): 1,
#          ('1700 block of North Broadway', 'Baltimore', 'Maryland'): 1,
#          ('North 1311 County Road KCI', 'Powell Township', 'Michigan'): 1,
#          ('3867 Terrazzo Avenue', 'Las Vegas', 'Nevada'): 1,
#          ('N/A', 'Brownsburg', 'Indiana'): 1,
#          ('3100 Block of Powell Lane', 'Austin', 'Texas'): 1,
#          ('5550 S. Flower Street', 'Los Angeles', 'California'): 2,
#          ('4600 block of Natural Bridge Avenue', 'Saint Louis', 'Missouri'): 1,
#          ('5100 block of Hawaiian Terrace', 'Cincinnati', 'Ohio'): 2,
#          ('201 Eads Street', 'Chattanooga (East Ridge)', 'Tennessee'): 3,
#          ('4700 block of Spottswood Drive', 'Orlando', 'Florida'): 2,
#          ('200 block of Dana Avenue', 'Columbus', 'Ohio'): 3,
#          ('1600 block of Steel Street', 'Detroit', 'Michigan'): 2,
#          ('Hill Road', 'Beaufort (Ladys Island)', 'South Carolina'): 1,
#          ('1809 W 50th St', 'Chicago', 'Illinois'): 1,
#          ('5100 block of Lakeview Court', 'New Orleans', 'Louisiana'): 1,
#          ('2746 Fleur Dr.', 'Des Moines', 'Iowa'): 1,
#          ('Trail Creek Street', 'Athens', 'Georgia'): 1,
#          ('2000 block of Carroll Avenue NW', 'Roanoke', 'Virginia'): 3,
#          ('359 Vestry Dr', 'Saginaw', 'Michigan'): 1,
#          ('Lucas and Hunt Road and West Florissant Avenue',
#           'Saint Ann',
#           'Missouri'): 1,
#          ('Sheridan Road', 'Daytona Beach', 'Florida'): 1,
#          ('Ditchley Road and Gill Lane',
#           'Ware Neck (Gloucester Courthouse)',
#           'Virginia'): 1,
#          ('1600 block of Northwest 7th Lane', 'Pompano Beach', 'Florida'): 1,
#          ('10500 block of Wentworth Springs Road',
#           'El Dorado (county)',
#           'California'): 1,
#          ('17600 block of Faust', 'Detroit', 'Michigan'): 2,
#          ('300 block of New Ballwin Road', 'Ballwin', 'Missouri'): 1,
#          ('Arthur Langford Jr Place', 'Atlanta', 'Georgia'): 1,
#          ('Tully Rd', 'Orange', 'Massachusetts'): 1,
#          ('900 block of Princeton Drive', 'Clarksville', 'Tennessee'): 1,
#          ('Charlie Arthur Lane', 'Asheville', 'North Carolina'): 1,
#          ('3400 block of Wilson Avenue', 'Oakland', 'California'): 1,
#          ('1504 Bouldercrest Road', 'Atlanta', 'Georgia'): 1,
#          ('8351 Northwest 15th Avenue', 'Miami', 'Florida'): 1,
#          ('1200 block of Knowles Rd', 'Phenix City', 'Alabama'): 1,
#          ('2600 block of Ranger Drive',
#           'North Charleston',
#           'South Carolina'): 1,
#          ('105 Townville School Road', 'Townville', 'South Carolina'): 2,
#          ('1705 Charles Avenue', 'Plant City', 'Florida'): 1,
#          ('161 Nautilus Street', 'Aiken', 'South Carolina'): 1,
#          ('1000 block of East Jordan Road',
#           'Isabella (county)',
#           'Michigan'): 1,
#          ('1000 block of Canary Court', 'Suisun City', 'California'): 3,
#          ('Crooked Creek Court', 'Anderson (county)', 'South Carolina'): 1,
#          ('6500 block of Archer Road', 'Knoxville', 'Tennessee'): 1,
#          ('962 14th Ln', 'Vero Beach', 'Florida'): 1,
#          ('2300 block of West Greenacre Avenue', 'Anaheim', 'California'): 1,
#          ('N/A', 'Sanborn', 'North Dakota'): 3,
#          ('100 block of Carroll Street', 'Mandeville', 'Louisiana'): 1,
#          ('2900 block of Aspen Meadow', 'San Antonio', 'Texas'): 1,
#          ('464 32 1/2 Road', 'Clifton', 'Colorado'): 1,
#          ('4400 block of Hampstead Street', 'San Antonio', 'Texas'): 1,
#          ('Patterson Drive and West Third Street',
#           'Bloomington',
#           'Indiana'): 1,
#          ('25th and Lafayette', 'Terre Haute', 'Indiana'): 1,
#          ('2400 block of Bedford Avenue', 'Pittsburgh', 'Pennsylvania'): 1,
#          ('1700 Whiskey Rd', 'Aiken', 'South Carolina'): 1,
#          ('County Road 1603', 'Cullman (county)', 'Alabama'): 1,
#          ('743 Locust Avenue', 'Clarksburg', 'West Virginia'): 1,
#          ('Union Street', 'Lagrange', 'Georgia'): 1,
#          ('24th Street West', 'Jasper', 'Alabama'): 1,
#          ('8639 Apple St', 'New Orleans', 'Louisiana'): 1,
#          ("Jennifer's Lane", 'Rockwell', 'North Carolina'): 1,
#          ('300 Block of South Ave', 'Syracuse', 'New York'): 1,
#          ('Longfellow Court NE', 'Warren', 'Ohio'): 1,
#          ('4200 block of W. Spaulding Place', 'Milwaukee', 'Wisconsin'): 1,
#          ('2000 block of Harrison Avenue', 'Cincinnati (Westwood)', 'Ohio'): 1,
#          ('Happy Hollow Lane', 'Mineral Springs', 'North Carolina'): 1,
#          ('1900 block of Goodman Avenue',
#           'Cincinnati (North College Hill)',
#           'Ohio'): 2,
#          ('Rose and Upland Street', 'Chester', 'Pennsylvania'): 1,
#          ('Mt Moriah Road and Ridgeway Road', 'Memphis', 'Tennessee'): 1,
#          ('1101 Medical Center Blvd', 'Marrero', 'Louisiana'): 1,
#          ('N/A', 'Flint', 'Michigan'): 1,
#          ('7600 block of 62nd Way', 'Pinellas Park', 'Florida'): 2,
#          ('100 block of North Seeley Avenue', 'Chicago', 'Illinois'): 1,
#          ('2500 block of Pinckney Avenue', 'Charlotte', 'North Carolina'): 1,
#          ('1200 block of Marquette Street', 'Racine', 'Wisconsin'): 1,
#          ('N/A', 'Enderlin', 'North Dakota'): 1,
#          ('8th and Humboldt Avenue N.', 'Minneapolis', 'Minnesota'): 1,
#          ('3569 Larkspur Terrace', 'Decatur', 'Georgia'): 2,
#          ('700 Glasgow Road', 'Charlotte', 'North Carolina'): 1,
#          ('1400 block of Devers Road', 'York', 'Pennsylvania'): 1,
#          ('Compass Lake Drive', 'Alford', 'Florida'): 2,
#          ('2600 block of 25th Street West', 'Rosamond', 'California'): 3,
#          ('540 N Percy St', 'Philadelphia', 'Pennsylvania'): 1,
#          ('West 36th Street and President Barack Obama Hwy',
#           'Palm Beach (county)',
#           'Florida'): 1,
#          ('N/A', 'Calhoun', 'Georgia'): 1,
#          ('5500 block of West Adams Street', 'Chicago', 'Illinois'): 1,
#          ('Myers Lane', 'Washington (county)', 'Tennessee'): 1,
#          ...})

# %%
ambiguity_per_address=defaultdict(set)
ambiguity_per_city=defaultdict(set)
for row in freq_locations:
    address=row[0].strip()
    city=row[1].strip()
    state=row[2].strip()
    if address!='N/A':
        ambiguity_per_address[address].add(tuple([city, state]))
    ambiguity_per_city[city].add(state)

# %%
locations_per_address = Counter([len(v) for v in ambiguity_per_address.values()])
print(locations_per_address)
moa_address=len(freq_locations)/sum(locations_per_address.values())
print(moa_address)
# Out:
# Counter({1: 4216, 2: 13, 3: 2})
# 1.0586149846372017

# %%
locations_per_city = Counter([len(v) for v in ambiguity_per_city.values()])
print(locations_per_city)
city_state_combos=0
for k,v in locations_per_city.items():
    city_state_combos+=int(k)*int(v) 
moa_city=city_state_combos/sum(locations_per_city.values())
print(moa_city)
# Out:
# Counter({1: 1569, 2: 94, 3: 17, 4: 10, 5: 4, 7: 1})
# 1.1061946902654867

# %%
result3=utils.check_overlap(ambiguity_per_address.keys()) # are addresses SFs found in EL datasets
result3
# Out:
# set()

# %%
result4=utils.check_overlap(ambiguity_per_city.keys()) # are cities SFs found in EL datasets
len(result4)
# Out:
# 855

# %%
geolocator = Nominatim()
for k,v in ambiguity_per_city.items():
    for state in v:
        location=geolocator.geocode('%s, %s' % (k, state))
        if location:
            print(k,state, location.latitude, location.longitude)
# Out:
# Williston North Dakota 48.1476108 -103.6181383
# Williston Florida 29.38747 -82.4467705
# Montclair New Jersey 40.8259332 -74.2090343
# Middleburg Florida 30.0557025 -81.9036373425886
# Greenacres Florida 26.6293963 -80.1365516115106
# Baltic Ohio 40.440066 -81.6990159
# Crestview Florida 30.7621326 -86.5705083
# Rupert Idaho 42.6190756 -113.6772347
# Hickory (Viola) Kentucky 36.825445 -88.6780289
# Jersey City New Jersey 40.7281575 -74.0776416
# Kokomo Indiana 40.4864444 -86.133635
# Kent Washington 47.3826903 -122.2270271
# Sharpsville Indiana 40.3794822 -86.0886008
# Caruthersville Missouri 36.1931245 -89.6556352
# Delia Kansas 39.240552 -95.9669349
# Berkeley California 37.8708393 -122.2728638
# Aurora Illinois 41.7605849 -88.3200714
# Aurora Colorado 39.729432 -104.8319195
# Kilmichael Mississippi 33.4434573 -89.571743
# Waitsfield Vermont 44.1900592 -72.8248378
# Catskill New York 42.2173102 -73.8645733
# Hollywood Florida 26.0112014 -80.14949
# Palo Alto California 37.442156 -122.1634471
# Winter Haven Florida 28.0222435 -81.7328567
# Belle Glade Florida 26.68837015 -80.6721257680432
# Cincinnati Ohio 39.1014537 -84.5124601
# Henry (county) Indiana 39.9297608 -85.4043541
# Villa Park Illinois 41.8891319 -87.9774853
# Bradenton Florida 27.4989278 -82.5748193
# Saltsburg Pennsylvania 40.4864553 -79.4514298
# King North Carolina 36.280694 -80.3592196
# Thomaston Georgia 32.8881879 -84.3265854
# Horton Alabama 34.3845343 -85.8463592
# New Braunfels Texas 29.7028266 -98.1257347
# Roswell New Mexico 33.3943282 -104.5229517
# Roswell Georgia 34.02332 -84.3600219
# Farmington Pennsylvania 39.8072982 -79.5655971
# Farmington Arkansas 36.0420248 -94.2471514
# Ochopee Florida 25.9014871 -81.3034102
# Indiana Pennsylvania 40.6214551 -79.1525348
# Winston Salem (Winston-salem) North Carolina 36.0998131 -80.2440517
# Homestead Florida 25.4687224 -80.4775568
# Cheyenne Wyoming 41.1399814 -104.8202461
# Salt Lake City (West Valley City) Utah 40.7125457 -111.9339823
# Lake Tahoe California 39.0888982 -120.050511752934
# Hilton New York 43.288116 -77.7933419
# Hayward California 37.6688205 -122.0807963
# Mesa Arizona 33.4153143 -111.831264
# Lake Charles Louisiana 30.2265949 -93.2173758
# Los Angeles (Boyle Heights) California 34.06647765 -118.167203932539
# Cowley (county) Kansas 37.2413155 -96.8675684
# Vevay Indiana 38.7478401 -85.0671724
# Paramount California 33.8984873 -118.1707029
# Capulin Colorado 37.2838961 -106.1114163
# Tarpon Springs Florida 28.1477885 -82.7774085726313
# Manhattan New York 40.7902778 -73.9597221
# Manhattan Kansas 39.1836082 -96.5716693
# Calhoun Georgia 31.5311784 -84.6143279
# Fairborn Ohio 39.8067455 -84.0102331768371
# Wichita Falls Texas 33.9137085 -98.4933872
# Charlottesville Virginia 38.029306 -78.476678
# Latta South Carolina 34.337691 -79.4321948
# Oxnard California 34.1976308 -119.1803817
# Randleman North Carolina 35.817914 -79.8030869
# Dayton (Kettering) Ohio 39.7108469 -84.1413077
# Trabuco Canyon California 33.6626232 -117.5893799
# Lubbock (county) Texas 33.5831241 -101.8185979
# New Orleans (Algiers) Louisiana 29.9510489 -90.082307525389
# Council Bluffs Iowa 41.2621283 -95.8613911
# Bennettsville South Carolina 34.6173803 -79.6847813
# Libby Montana 48.3882861 -115.5559987
# Lawrence Kansas 38.9719384 -95.2359495
# Fort Worth (Benbrook) Texas 32.6672796 -97.4383999
# Byhalia Mississippi 34.8723179 -89.6906395
# Conyers Georgia 33.6676103 -84.0176903
# Marysville Washington 48.0517429 -122.1768208
# Trout Run Pennsylvania 40.3712576 -79.2599225
# Center Point Alabama 33.6456583 -86.6836
# Harvey Illinois 41.6100344 -87.6467131
# Harvey Louisiana 29.9035387 -90.0772943
# Lincoln Nebraska 40.8 -96.6678209
# Lincoln Delaware 38.8698352 -75.4229745
# East Saint Louis Illinois 38.6244952 -90.1509428
# Manassas Virginia 38.744947 -77.4824441252427
# Fort Lauderdale Florida 26.1223084 -80.1433785
# Richmond (county) Georgia 33.3615148 -82.0778166
# Dallas Oregon 44.9189206 -123.3158694
# Dallas Texas 32.7762719 -96.7968558
# Dallas Georgia 33.9237141 -84.8407731
# Bohannon Virginia 37.3968044 -76.3599442
# Florence Alabama 34.79981 -87.6772509
# Champaign Illinois 40.1164205 -88.2433828
# Wellington Florida 26.6586779 -80.2414356
# Claymont Delaware 39.8006685 -75.4596403
# Birmingham (Hoover) Alabama 33.3799348 -86.8072696
# Branford Connecticut 41.2795414 -72.8150988
# Medford Oregon 42.3264181 -122.8718604
# Medford New York 40.8175985 -73.0001067
# Wallkill New York 41.6056492 -74.1840357
# Lumberton North Carolina 34.6183433 -79.0083992
# Vallejo California 38.1040864 -122.2566366
# Covington Ohio 40.1172727 -84.3538366
# Santa Cruz California 36.9735903 -122.0260569
# Guntown Mississippi 34.4431571 -88.6597757
# Avon Park Florida 27.5960827 -81.5060857
# San Gabriel California 34.0991325 -118.108604
# Beckley West Virginia 37.7781702 -81.1881556
# Beebe Arkansas 35.0706424 -91.8795855
# Madisonville Kentucky 37.3280037 -87.4986988
# Gretna Louisiana 29.9146493 -90.0539603
# Baltimore Maryland 39.2908816 -76.6107589
# Wilkinson Indiana 39.8858775 -85.6088645
# Elizabethton Tennessee 36.3487196 -82.2106875
# Topeka Kansas 39.0490111 -95.6775556
# Plantation Florida 26.1265258 -80.257861137651
# Poway California 32.9628234 -117.0358645
# White Sulphur Springs West Virginia 37.7965149 -80.2975733
# Hutchinson Kansas 38.0608444 -97.9297742
# Snow Hill North Carolina 35.9601194 -82.1398437
# Raymond Mississippi 32.2593146 -90.422595
# Muncie Indiana 40.1936683 -85.3865113
# East Palo Alto California 37.4688273 -122.141075
# Pennfield Michigan 42.3733731 -85.102491
# Pierce County Wisconsin 44.7186568 -92.3786113
# Florissant Missouri 38.789217 -90.3226139
# Caldwell Idaho 43.6678736 -116.6894155
# Rocky Mount North Carolina 35.9423833 -77.7956948
# Compton California 33.8948824 -118.2260433
# Reedley California 36.5963395 -119.4504028
# Haywood (county) Tennessee 35.5675653 -89.2878239
# Aynor South Carolina 33.9998881 -79.1994873
# Clinton Mississippi 32.3415342 -90.3217584
# Tallahassee Florida 30.4380832 -84.2809331
# Faribault Minnesota 44.2949637 -93.2688269
# Williamson (county) Illinois 37.7248502 -88.9143384
# Lagrange Indiana 41.6372578 -85.4216947
# Lagrange Georgia 33.039291 -85.0313268
# Seneca South Carolina 34.6865321 -82.9527287
# Taylor Michigan 42.240872 -83.2696508
# Allison Iowa 42.7527548 -92.7951944
# Kennewick Washington 46.2112458 -119.1372337
# Baconton Georgia 31.379623 -84.1610169
# Lehigh Acres Florida 26.6040585 -81.6581332096742
# Thorne Bay Alaska 55.6877778 -132.5222221
# Caulfield Missouri 36.6145065 -92.1048769
# Crab Orchard Tennessee 35.9092367 -84.8780047
# Brockton Massachusetts 42.0834335 -71.0183786
# Seat Pleasant Maryland 38.8962231 -76.9066398
# Elm Mott Texas 31.6713084 -97.0985624
# Itta Bena Mississippi 33.49512 -90.3198066
# Belgrade Montana 45.773279 -111.1845349
# Branch (county) Michigan 41.916753 -85.0649373
# Allamakee (county) Iowa 43.2961731 -91.3961855
# Bluefield Virginia 37.252617 -81.2712104
# Bluefield West Virginia 37.2698395 -81.2223194
# Berkeley (county) South Carolina 33.1595951 -79.907046
# Merced (county) California 37.1641544 -120.7678601
# Fort Lauderdale (Davie) Florida 26.0705367 -80.3559117388922
# Toombs (county) Georgia 32.1296839 -82.3299927
# Paterson New Jersey 40.9167654 -74.1718109
# Key West Florida 24.5625566 -81.7724367
# Moultrie Georgia 31.1811523 -83.7878808
# Omaha Nebraska 41.2587317 -95.9378731
# Franklin Indiana 39.4806056 -86.0549862
# Franklin Michigan 42.5222567 -83.3060431
# Franklin Louisiana 32.1254252 -91.6778052
# Franklin Pennsylvania 39.9259345 -77.7485515
# Franklin North Carolina 36.1028596 -78.2787228
# Darlington County South Carolina 34.3609331 -79.9438571
# Hartford Connecticut 41.7634935 -72.6830522
# Kahuku Hawaii 21.6844495 -157.941667206639
# Hialeah Florida 25.8575963 -80.2781056
# Highland Heights Kentucky 39.0330902 -84.4521511
# Knoxville Tennessee 35.9603948 -83.921026
# Knoxville Pennsylvania 40.412969 -79.9930023791991
# Mandeville Louisiana 30.3582305 -90.0657476
# Panola County Mississippi 34.3793392 -89.9601924
# Berlin Heights Ohio 41.3253278 -82.493226
# Cypress Texas 29.9691116 -95.6971685
# Bay Saint Louis Mississippi 30.3132823 -89.3343222
# Fort Walton Beach Florida 30.4057552 -86.6188419
# Doe Run Missouri 37.7428288 -90.4976235
# Fresno Texas 29.5388465 -95.4474413
# Fresno California 36.7394421 -119.7848306
# Duncan South Carolina 34.9378962 -82.1451095
# Sacramento California 38.5815719 -121.4943995
# Pittsburg (Bay Point) California 38.0189042 -121.944103
# Waukegan Illinois 42.3636331 -87.8447937
# Iredell County North Carolina 35.8101636 -80.8805592
# Berthoud Colorado 40.3083174 -105.0810923
# Atlantic City New Jersey 39.3642852 -74.422935
# Hudson Florida 28.3617709 -82.6932846
# Tipp City Ohio 39.9583892 -84.1721637
# Suwanee Georgia 34.0514898 -84.0712996
# Effingham Illinois 39.1201433 -88.5434799
# Tullahoma Tennessee 35.3620235 -86.2094341
# Fort Wayne Indiana 41.0799898 -85.1386014
# Four Oaks North Carolina 35.444884 -78.4269489
# Pelzer South Carolina 34.6423372 -82.4559597
# Livermore California 37.6820583 -121.768053
# Owensboro Kentucky 37.7742152 -87.1133303
# Stafford (county) Virginia 38.4167265 -77.4579782
# Drew (county) Arkansas 33.5716907 -91.7160968
# Payson Arizona 34.2308684 -111.3251354
# Loveland Ohio 39.2689562 -84.2638405
# Yakima (Union Gap) Washington 46.5477402 -120.4777881
# Mission Texas 26.2159066 -98.3252931
# Mount Pleasant Pennsylvania 40.1489607 -79.5411496
# Roseville Michigan 42.4972583 -82.9371408
# Roseville California 38.72338 -121.185878161131
# Irvington New Jersey 40.7323235 -74.2348683
# Irvington Alabama 30.5068623 -88.2338924
# Burnet (county) Texas 30.7763939 -98.1700015
# Yakima Washington 46.601557 -120.510842
# Polk (county) Florida 27.9448537 -81.7268788
# Eutaw Alabama 32.8406848 -87.8875143
# Denton Texas 33.1838787 -97.1413416
# Starkville Mississippi 33.4503998 -88.8183871
# Avondale Arizona 33.4359175 -112.340502
# Hilliard Ohio 40.033814 -83.1596107
# Ravenel South Carolina 32.7632321 -80.2500985
# Fort Washington Maryland 38.7125305 -77.0124597
# Helena Montana 46.5927122 -112.0361089
# Helena Arkansas 34.5295471 -90.5917721
# Catawba North Carolina 35.6740563 -81.2107214
# Kissimmee Florida 28.2918995 -81.4075837
# Saginaw (county) Michigan 43.3326882 -84.0468402
# West Sweden Wisconsin 45.7057849 -92.4968666
# Buckeye Arizona 33.3702748 -112.5838672
# Lea (county) New Mexico 32.7448727 -103.3828241
# Letcher South Dakota 43.897207 -98.1386939
# Dallas (county) Alabama 32.3117968 -87.1046642
# New Haven Connecticut 41.3082138 -72.9250517
# Paris Texas 33.6617962 -95.5555129
# Auburn Washington 47.3075369 -122.2301807
# Auburn Michigan 43.603358 -84.0697049
# Auburn Alabama 32.6550905 -85.5036433630996
# Auburn Georgia 34.0137179 -83.8276758
# Fort Valley Georgia 32.5537585 -83.8874083
# South Bend Indiana 41.6833813 -86.2500065
# Houston Texas 29.7589382 -95.3676973
# Sanilac (county) Michigan 43.4150687 -82.8234744
# Crowley Louisiana 30.2140928 -92.374576
# Norlina North Carolina 36.4457016 -78.1983273
# Allapattah Florida 25.8087362 -80.215458
# Rockdale Texas 30.6554759 -97.0013743
# Willingboro New Jersey 40.0278894 -74.8690541
# Meherrin Virginia 37.1032078 -78.3666619
# Warner Robins Georgia 32.598313 -83.6256769145824
# Uniondale New York 40.7003793 -73.5929055
# Brownsville Texas 25.9140256 -97.4890855
# Chatsworth Georgia 34.7659145 -84.7699384
# Pahoa Hawaii 19.4969437 -154.9501535
# Anadarko Oklahoma 35.072562 -98.2436625
# Hopkinsville Kentucky 36.8657651 -87.4889531
# Haw River North Carolina 35.669611 -79.0754119
# Aliquippa Pennsylvania 40.6102386 -80.2677259
# Saint Marys Georgia 30.7305142 -81.5464927
# Roanoke Rapids North Carolina 36.4615395 -77.6541463
# Roseburg Oregon 43.216505 -123.341738
# Shelton Washington 47.2150945 -123.1007065
# Port Arthur Texas 29.8988258 -93.9287814
# Cape Coral Florida 26.6058996 -81.9807339
# New York (Manhattan) New York 40.7484357 -73.9856931
# East Chicago Indiana 41.6397857 -87.4548465
# Altamonte Springs Florida 28.6649055 -81.376268513721
# Mukilteo Washington 47.9474034 -122.3036991
# Delta Junction Alaska 64.0373478 -145.7321571
# Everett Washington 47.9673056 -122.2013997
# Maysville Georgia 34.2528839 -83.5615547
# Graysville Indiana 38.3231237 -85.8021866
# San Tan Valley Arizona 33.1775233 -111.5478924
# Canton Ohio 40.7989522 -81.3784444
# Canton Mississippi 32.6126381 -90.0367511
# Choctaw Oklahoma 34.0246234 -95.5205499
# Carrollton Ohio 40.5728404 -81.0856531
# Carrollton Georgia 33.5801103 -85.0766112
# Mineral Virginia 39.3839905 -78.9416921
# Immokalee Florida 26.4186898 -81.4172992
# Skyway Washington 47.4914884 -122.2542891
# Dyersburg Tennessee 36.0345159 -89.385628
# Quakertown Pennsylvania 40.4417682 -75.3415666
# Phenix City Alabama 32.4709761 -85.0007652
# Waldorf Maryland 38.6263882 -76.910658
# Fort Lauderdale (Lauderhill) Florida 26.1195775 -80.1697736
# Portland Oregon 45.5202471 -122.6741948
# Portland Indiana 40.4344895 -84.9777454
# Opa Locka Florida 25.89673385 -80.2594963085029
# Ocala Florida 29.1871986 -82.1400922
# Chattanooga (East Ridge) Tennessee 34.9917144 -85.2084768
# Billings Montana 45.7874957 -108.4960699
# Grand Junction Iowa 42.0316483 -94.2407966
# Grand Junction Colorado 39.063956 -108.5507316
# Saint Augustine (St Augustine) Florida 29.8946952 -81.3145394
# Brownsburg Indiana 39.8433769 -86.3977735
# Columbus (Whitehall) Ohio 39.9747468 -82.8850699
# Smicksburg Pennsylvania 40.8697871 -79.1708703
# Santee California 32.8383828 -116.9739166
# Santee South Carolina 33.4751634 -80.4864763
# Calumet City Illinois 41.6155909 -87.529487
# Dayton Ohio 39.7589478 -84.1916068
# Kilgore Texas 32.3860733 -94.8758517
# Fairbanks Alaska 64.837845 -147.7166749
# Cassopolis Michigan 41.9117134 -86.0100068
# Moss Point Mississippi 30.4115881 -88.53446
# Defiance Ohio 41.3203058 -84.5084834
# Nicholasville Kentucky 37.8806341 -84.572996
# Fontana California 34.0922335 -117.4350479
# Saylorsburg Pennsylvania 40.8952667 -75.3233922
# Larose Louisiana 29.572438 -90.3817482
# Sherman Texas 33.6360125 -96.6097888
# Winnebago (county) Illinois 42.3255276 -89.1496573
# Fairfield Alabama 33.4859402 -86.9119365
# Fairfield California 38.2493581 -122.0399662
# Mount Vernon Washington 48.4200462 -122.3264199
# Mount Vernon New York 40.9125992 -73.8370785
# Mount Vernon Alabama 31.0851775 -88.0133324
# Barry Illinois 39.6942135 -91.0390245
# Tacoma Washington 47.2495798 -122.4398745
# Crows Landing California 37.3938244 -121.0715975
# Holyoke Colorado 40.584437 -102.3024102
# Kennesaw Georgia 34.0234337 -84.6154896
# New Castle Pennsylvania 41.0036719 -80.347009
# Harrington Delaware 38.9237244 -75.5777032
# Moretown Vermont 44.2508918 -72.7609495
# Bloomington Illinois 40.4731073 -88.9941402
# Bloomington Indiana 39.1670396 -86.534288
# Midwest City Oklahoma 35.4495097 -97.3967024
# Valdosta Georgia 30.8327022 -83.278485
# Kingsport Tennessee 36.550238 -82.5594292
# Southfield Michigan 42.4733689 -83.221873
# New Iberia Louisiana 30.0035365 -91.8187284
# Webster New York 43.212285 -77.4299939
# Webster Minnesota 44.529686 -93.3527229
# Smithtown New York 40.8559314 -73.2006686
# Hatley Wisconsin 44.8874704 -89.3387271
# Littleton Colorado 39.613321 -105.0166497
# Stopover Kentucky 37.5159411 -82.09124
# Coushatta Louisiana 32.0148834 -93.3421164
# La Place (Laplace) Louisiana 30.052871 -90.4651099
# Statesville North Carolina 35.7826363 -80.8872958
# Campbellsville Kentucky 37.3433974 -85.3419068
# Pike (county) Ohio 39.1056387 -83.0611403
# Mc Farland California 33.9619073 -117.4034703
# Inkster Michigan 42.2942045 -83.3099302
# Alford Florida 30.6936569 -85.3918967
# Mansfield Ohio 40.75839 -82.515447
# Ellicott City Maryland 39.2673284 -76.7983066
# Wayne (county) Ohio 40.8615819 -81.9034616
# Mountain View Missouri 36.9953322 -91.7037549
# Mountain View Hawaii 19.557849 -155.1056669
# Hesston Kansas 38.1383437 -97.4314266
# Chicago (Englewood) Illinois 41.7790752 -87.6684426
# Branson Missouri 36.6440399 -93.2171329
# Margate Florida 26.242509 -80.214147708637
# Petersburg Virginia 37.1924594 -77.3677407
# Green River Utah 39.3082805 -110.0598549
# Lincolnton North Carolina 35.473745 -81.254525
# Covington (Claiborne) Louisiana 30.49641185 -90.0990090495076
# Chubbuck Idaho 42.9271949 -112.4659513
# Humble (Atascocita) Texas 30.000256 -95.1582799
# New Port Richey Florida 28.247132 -82.7170237901345
# Carlinville Illinois 39.2797699 -89.8817661
# Lemoore California 36.3007835 -119.7829106
# Plaquemine Louisiana 30.2890833 -91.2342743
# Nashville Tennessee 36.1622296 -86.774353
# Scotch Plains New Jersey 40.65538 -74.3898731
# Waxhaw North Carolina 34.9245935 -80.7434018
# Atoka Oklahoma 34.3284948 -96.0178379
# Bloomfield New Jersey 40.806767 -74.1854225
# Lamesa Texas 32.7376001 -101.950992
# Hollywood (West Park) Florida 26.0121723 -80.1676493
# Leesburg Indiana 41.3319904 -85.849992
# Cave Creek Arizona 33.8333716 -111.9507041
# Leavenworth Kansas 39.3110919 -94.9227995
# Winstonville Mississippi 33.9101113 -90.751488
# Salinas California 36.6744117 -121.6550371
# San Benito Texas 26.1326237 -97.6307909
# Latham New York 42.7470225 -73.7590087
# Salisbury North Carolina 35.6709727 -80.474226
# Lorton Virginia 38.7043397 -77.2203429
# Dickinson North Dakota 46.8791756 -102.7896241
# Orangeburg South Carolina 33.4918203 -80.8556475
# Fort Myers Florida 26.640628 -81.8723083
# Miramar Florida 25.97591145 -80.3347211811522
# Findlay Ohio 41.0413873 -83.6503981
# Lakewood Washington 47.1714085 -122.5163999
# Lakewood Ohio 41.4819932 -81.7981907
# Lakewood New Jersey 40.092024 -74.2121963562147
# Azle Texas 32.910378 -97.5519696144946
# Pinetown North Carolina 35.6104408 -76.8613326
# Cordova Tennessee 35.1556451 -89.7761954
# Woodford Virginia 38.1131886 -77.4088707
# Jasper Alabama 33.8312185 -87.2775052
# Allen Texas 33.1031744 -96.6705502
# Riverside California 33.9533546 -117.3961622
# Spotsylvania Courthouse Virginia 38.1979096 -77.5877651
# Owensville Missouri 38.3456023 -91.5015486
# Tarrant Alabama 33.5950685 -86.7677093155039
# Marrero Louisiana 29.8993723 -90.1003505
# Blountsville Alabama 34.0814863 -86.5911026
# Adel Georgia 31.1371358 -83.4234935
# Pontotoc (county) Oklahoma 34.707331 -96.6814852
# Pontotoc (county) Mississippi 34.2114655 -89.038265
# Lone Tree Colorado 39.5366435 -104.885520850814
# Orosi California 36.5449499 -119.2873383
# Manchester Illinois 39.5422692 -90.3323434
# Manchester New Hampshire 42.9956397 -71.454789
# Lillington North Carolina 35.399121 -78.8155999
# Copiague New York 40.6840538 -73.4008101
# Danielsville Georgia 34.1242771 -83.2212628
# Eutawville South Carolina 33.3946078 -80.3473114
# Saint Louis Missouri 38.6272733 -90.1978888
# Sweet Home Oregon 44.3976247 -122.7361958
# Chattanooga Tennessee 35.0456297 -85.30968
# Crosby Texas 29.9118885 -95.0621511
# White Pine Tennessee 36.1075936 -83.2868327
# Sandy Utah 40.572851 -111.833449531627
# Yacolt Washington 45.8655044 -122.4070313
# Baytown Texas 29.7355047 -94.9774273
# Clarksville Tennessee 36.5277607 -87.3588702
# Puyallup Washington 47.1849009 -122.2921405
# Colchester Connecticut 41.579503 -72.341581149226
# Newburgh New York 41.5034271 -74.0104178
# North Liberty Iowa 41.748868 -91.5972563
# Hermiston Oregon 45.8404101 -119.2894604
# Bridgeport Connecticut 41.1670412 -73.2048347
# Bridgeport Texas 33.2101155 -97.7547551
# Parrottsville Tennessee 36.0092654 -83.0923774
# Appling Georgia 31.7771435 -82.2996273
# Studio City California 34.1483989 -118.3961876
# Dayton (Trotwood) Ohio 39.76382345 -84.3463187441966
# Stamford Connecticut 41.0534302 -73.538734
# Spring (Shenandoah) Texas 30.18026305 -95.4510062135037
# Corona (Queens) New York 40.7469593 -73.8601455
# Hummelstown Pennsylvania 40.2653681 -76.7083032
# Shreveport Louisiana 32.5221828 -93.7651943
# Pocatello Idaho 42.8688613 -112.4401097
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /Users/filipilievski/anaconda/lib/python3.5/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     142         try:
# --> 143             page = requester(req, timeout=(timeout or self.timeout), **kwargs)
#     144         except Exception as error: # pylint: disable=W0703
#
# /Users/filipilievski/anaconda/lib/python3.5/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     162         opener = _opener
# --> 163     return opener.open(url, data, timeout)
#     164
#
# /Users/filipilievski/anaconda/lib/python3.5/urllib/request.py in open(self, fullurl, data, timeout)
#     465
# --> 466         response = self._open(req, data)
#     467
#
# /Users/filipilievski/anaconda/lib/python3.5/urllib/request.py in _open(self, req, data)
#     483         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 484                                   '_open', req)
#     485         if result:
#
# /Users/filipilievski/anaconda/lib/python3.5/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     443             func = getattr(handler, meth_name)
# --> 444             result = func(*args)
#     445             if result is not None:
#
# /Users/filipilievski/anaconda/lib/python3.5/urllib/request.py in https_open(self, req)
#    1296             return self.do_open(http.client.HTTPSConnection, req,
# -> 1297                 context=self._context, check_hostname=self._check_hostname)
#    1298
#
# /Users/filipilievski/anaconda/lib/python3.5/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1256                 raise URLError(err)
# -> 1257             r = h.getresponse()
#    1258         except:
#
# /Users/filipilievski/anaconda/lib/python3.5/http/client.py in getresponse(self)
#    1196             try:
# -> 1197                 response.begin()
#    1198             except ConnectionError:
#
# /Users/filipilievski/anaconda/lib/python3.5/http/client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# /Users/filipilievski/anaconda/lib/python3.5/http/client.py in _read_status(self)
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#
# /Users/filipilievski/anaconda/lib/python3.5/socket.py in readinto(self, b)
#     574             try:
# --> 575                 return self._sock.recv_into(b)
#     576             except timeout:
#
# /Users/filipilievski/anaconda/lib/python3.5/ssl.py in recv_into(self, buffer, nbytes, flags)
#     928                   self.__class__)
# --> 929             return self.read(nbytes, buffer)
#     930         else:
#
# /Users/filipilievski/anaconda/lib/python3.5/ssl.py in read(self, len, buffer)
#     790         try:
# --> 791             return self._sslobj.read(len, buffer)
#     792         except SSLError as x:
#
# /Users/filipilievski/anaconda/lib/python3.5/ssl.py in read(self, len, buffer)
#     574         if buffer is not None:
# --> 575             v = self._sslobj.read(len, buffer)
#     576         else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# <ipython-input-54-1716d86e82ed> in <module>()
#       4 for k,v in ambiguity_per_city.items():
#       5     for state in v:
# ----> 6         location=geolocator.geocode('%s, %s' % (k, state))
#       7         if location:
#       8             print(k,state, location.latitude, location.longitude)
#
# /Users/filipilievski/anaconda/lib/python3.5/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, addressdetails, language, geometry)
#     191         logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     192         return self._parse_json(
# --> 193             self._call_geocoder(url, timeout=timeout), exactly_one
#     194         )
#     195
#
# /Users/filipilievski/anaconda/lib/python3.5/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     165                     raise GeocoderUnavailable('Service not available')
#     166             elif isinstance(error, SocketTimeout):
# --> 167                 raise GeocoderTimedOut('Service timed out')
#     168             elif isinstance(error, SSLError):
#     169                 if "timed out" in message:
#
# GeocoderTimedOut: Service timed out
